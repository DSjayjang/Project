# %%
import math
import numpy as np
import pandas as pd

# %% [markdown]
# # Chemprop

# %%
backbone = 'D-MPNN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [7.754316975751261, 11.470708771953433, 8.492586991918369, 7.167820006843627, 8.870976959476033]
seed200_gcn = [9.241811436930979, 6.27906324732022, 7.075041643277866, 8.458396491103285, 8.213783622698019]
seed300_gcn = [8.292588121309056, 12.292356956662156, 5.103446479857437, 5.863972941721518, 5.7207350148499465]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# 
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
"""
seed100_gcn = 
seed100_egcn_r = 
seed100_egcn_s = 
seed100_egcn = 
seed100_concat_3 = 
seed100_concat_5 = 
seed100_concat_7 = 
seed100_concat_10 = 
seed100_concat_20 = 
seed100_concat_ds = 
seed100_kronecker_3 = 
seed100_kronecker_5 = 
seed100_kronecker_7 = 
seed100_kronecker_10 = 
seed100_kronecker_20 = 
seed100_kronecker_all = 

seed200_gcn = 
seed200_egcn_r = 
seed200_egcn_s = 
seed200_egcn = 
seed200_concat_3 = 
seed200_concat_5 = 
seed200_concat_7 = 
seed200_concat_10 = 
seed200_concat_20 = 
seed200_concat_ds = 
seed200_kronecker_3 = 
seed200_kronecker_5 = 
seed200_kronecker_7 = 
seed200_kronecker_10 = 
seed200_kronecker_20 = 
seed200_kronecker_all =

seed300_gcn = 
seed300_egcn_r = 
seed300_egcn_s = 
seed300_egcn = 
seed300_concat_3 = 
seed300_concat_5 = 
seed300_concat_7 = 
seed300_concat_10 = 
seed300_concat_20 = 
seed300_concat_ds = 
seed300_kronecker_3 = 
seed300_kronecker_5 = 
seed300_kronecker_7 = 
seed300_kronecker_10 = 
seed300_kronecker_20 = 
seed300_kronecker_all = 
"""
# Out:
# '\nseed100_gcn = \nseed100_egcn_r = \nseed100_egcn_s = \nseed100_egcn = \nseed100_concat_3 = \nseed100_concat_5 = \nseed100_concat_7 = \nseed100_concat_10 = \nseed100_concat_20 = \nseed100_concat_ds = \nseed100_kronecker_3 = \nseed100_kronecker_5 = \nseed100_kronecker_7 = \nseed100_kronecker_10 = \nseed100_kronecker_20 = \nseed100_kronecker_all = \n\nseed200_gcn = \nseed200_egcn_r = \nseed200_egcn_s = \nseed200_egcn = \nseed200_concat_3 = \nseed200_concat_5 = \nseed200_concat_7 = \nseed200_concat_10 = \nseed200_concat_20 = \nseed200_concat_ds = \nseed200_kronecker_3 = \nseed200_kronecker_5 = \nseed200_kronecker_7 = \nseed200_kronecker_10 = \nseed200_kronecker_20 = \nseed200_kronecker_all =\n\nseed300_gcn = \nseed300_egcn_r = \nseed300_egcn_s = \nseed300_egcn = \nseed300_concat_3 = \nseed300_concat_5 = \nseed300_concat_7 = \nseed300_concat_10 = \nseed300_concat_20 = \nseed300_concat_ds = \nseed300_kronecker_3 = \nseed300_kronecker_5 = \nseed300_kronecker_7 = \nseed300_kronecker_10 = \nseed300_kronecker_20 = \nseed300_kronecker_all = \n'

# %%
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn =
seed200_kronecker_7 = [1.8388601588451956, 1.1279364458219272, 1.7294435275821236, 1.608887860155481, 1.0028034603322735]
seed200_kronecker_10 = [1.5324412068044106, 0.8938650146244079, 1.665282061719519, 1.1008099383256567, 1.0398333090862244]
seed200_kronecker_20 = [1.736833977887011, 0.8954426697858675, 0.9344700039841058, 0.8945641705370325, 0.9144601021104186]
seed200_kronecker_all =[1.4700963178018884, 0.6813583298930972, 0.702431055504506, 0.9859292638583446, 0.8546250321482884]

seed300_gcn = [8.292588121309056, 12.292356956662156, 5.103446479857437, 5.863972941721518, 5.7207350148499465]
seed300_egcn_r = [7.603845671405942, 9.151252326064222, 4.758424834003598, 4.59127393106776, 5.384233838729276]
seed300_egcn_s = [7.016890998900406, 10.007573405588706, 4.869043245090275, 5.965908020500123, 5.81222021318119]
seed300_egcn = [5.6759715042715, 7.819778202086922, 3.314537829301489, 4.004641675573635, 4.944558344724524]
seed300_concat_3 = [4.938261017085999, 6.486759576271838, 5.168005034679503, 4.25031971368264, 4.285228086791876]
seed300_concat_5 = [2.626222355159249, 2.718063204307256, 1.8675997576375647, 1.454530130221149, 1.817059483748811]
seed300_concat_7 = [2.0163926702784742, 1.7928786991149421, 1.3430952537716843, 1.4781687278447189, 1.738707949755756]
seed300_concat_10 = [1.7807377041794183, 1.3633051894781159, 1.1333893903597134, 1.5136780025452141, 1.66521854528034]
seed300_concat_20 = [1.386663406852662, 1.351950998381367, 0.7763990041777844, 1.1549439317598118, 1.4366154049644033]
seed300_concat_ds = [1.329693381241926, 1.4312979630597933, 0.8054165427140364, 1.254808320773868, 1.0224558542702944]
seed300_kronecker_3 = [3.9173106095922274, 4.111568661186639, 3.1175094964936023, 3.9887878538116697, 3.0519146282254286]
seed300_kronecker_5 = [1.4492584288589598, 2.108375789612297, 0.9353352944681964, 1.228871863658034, 1.3364153146132371]
seed300_kronecker_7 = [1.3085116288793368, 1.4941744766836091, 0.9646866115059439, 1.2346045126126508, 1.0799313519747202]
seed300_kronecker_10 = [1.3932871780996248, 1.7708913247416338, 0.9113128391776498, 1.0729980919304796, 0.9537058076216974]
seed300_kronecker_20 = [1.273777834073765, 1.2222245283952848, 0.7434642070860374, 1.063062262347364, 0.916246586401044]
seed300_kronecker_all = [0.8108303941140963, 1.438417359599917, 0.5422016128780335, 0.8776910286250077, 0.8538641395004651]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# all_seed_GCN_MSE: 8.020
# all_seed_GCN_se: 0.517
#
# all_seed_EGCN_R_MSE: 6.238
# all_seed_EGCN_R_se: 0.384
#
# all_seed_EGCN_S_MSE: 6.360
# all_seed_EGCN_S_se: 0.333
#
# all_seed_EGCN_S_MSE: 5.713
# all_seed_EGCN_S_se: 0.360
#
# all_seed_Concat_3_MSE: 5.070
# all_seed_Concat_3_se: 0.210
#
# all_seed_Concat_5_MSE: 2.002
# all_seed_Concat_5_se: 0.124
#
# all_seed_Concat_7_MSE: 1.664
# all_seed_Concat_7_se: 0.068
#
# all_seed_Concat_10_MSE: 1.516
# all_seed_Concat_10_se: 0.061
#
# all_seed_Concat_20_MSE: 1.262
# all_seed_Concat_20_se: 0.076
#
# all_seed_Concat_ds_MSE: 1.120
# all_seed_Concat_ds_se: 0.069
#
# all_seed_kronecker_3_MSE: 3.498
# all_seed_kronecker_3_se: 0.178
#
# all_seed_kronecker_5_MSE: 1.401
# all_seed_kronecker_5_se: 0.088
#
# all_seed_kronecker_7_MSE: 1.310
# all_seed_kronecker_7_se: 0.073
#
# all_seed_kronecker_10_MSE: 1.230
# all_seed_kronecker_10_se: 0.076
#
# all_seed_kronecker_20_MSE: 1.107
# all_seed_kronecker_20_se: 0.068
#
# all_seed_kronecker_all_MSE: 0.973
# all_seed_kronecker_all_se: 0.072

# %%
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

seed100_gcn = [2.1225758650171476, 2.160499903160756, 2.1130916565422, 1.8576944005770946, 2.1693573198245684]
seed100_egcn_r = [1.4868060134527252, 1.540451710618387, 1.706582497424028, 1.5146351611520361, 1.652503165124937]
seed100_egcn_s = [1.7100763696385182, 1.730960095022607, 1.6997507651021162, 1.8131175003652498, 1.7466232685642389]
seed100_egcn = [1.4806620680441067, 1.5901599793922243, 1.6526050717811884, 1.5979313587579203, 1.6250599313328284]
seed100_concat_3 = [1.556428653987374, 1.7860187019888811, 1.8032208840678057, 1.6783098536213552, 1.6077898140172011]
seed100_concat_5 = [0.9013838580274206, 0.9866863010436531, 1.0793798251414861, 0.9480419309120479, 1.0215602949375415]
seed100_concat_7 = [0.8339727206492987, 0.9297818611925981, 1.0724773406982422, 0.9098336227296844, 0.9871736664808434]
seed100_concat_10 = [0.8079609908456877, 1.0033431466170184, 1.0103191315658449, 0.883361380869948, 0.8688436655597832]
seed100_concat_20 = [0.6533007208756575, 0.8494964359313484, 0.9980611425685132, 0.7726074579193836, 0.8611529128242085]
seed100_concat_ds = [0.5723660761915793, 0.6823418008999562, 0.6998167563611128, 0.6044739325215497, 0.5402137696288014]
seed100_kronecker_3 = [1.1421408765897976, 1.3621862516628476, 1.472956800085353, 1.4170558058370755, 1.2902264995429351]
seed100_kronecker_5 = [0.6571587615125761, 0.9727988355741726, 1.017264734102985, 0.830686989731676, 0.870692508821269]
seed100_kronecker_7 = [0.6686647670475516, 0.9182487698051873, 0.9376746350386012, 0.8587147720216766, 0.8491420472851237]
seed100_kronecker_10 = [0.7126146151324896, 0.809356599342166, 0.8852903561329278, 0.7450133346197173, 0.7830251655505813]
seed100_kronecker_20 = [0.54320978930616, 0.686173491590605, 0.8604684063768763, 0.604646081999531, 0.5809521074513443]
seed100_kronecker_all = [0.5623711563470796, 0.6844754106416477, 0.6968091228815514, 0.617232885886365, 0.5739805013623857]

seed200_gcn = [1.9932198111466535, 1.7092955281415323, 2.1205072478046567, 2.152426021305595, 1.9947511440015022]
seed200_egcn_r = [1.731947590985636, 1.4250175746407097, 1.662349400557871, 1.9140071418341689, 1.5310495827944224]
seed200_egcn_s = [1.9487538375253752, 1.7422962038535772, 1.7785394022783896, 1.8016282029039279, 1.55710093665669]
seed200_egcn = [1.6736489243394748, 1.4980943034014365, 1.666985098771223, 1.6067174776332585, 1.5754345027545027]
seed200_concat_3 = [1.8697735343392439, 1.6557992950199156, 1.7425940506101594, 1.7402518565260519, 1.6823907517294847]



print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Freesolv
# all_seed_GCN_MAE: 2.007
# all_seed_GCN_se: 0.050
#
# all_seed_EGCN_R_MAE: 1.619
# all_seed_EGCN_R_se: 0.039
#
# all_seed_EGCN_S_MAE: 1.745
# all_seed_EGCN_S_se: 0.034
#
# all_seed_EGCN_S_MAE: 1.595
# all_seed_EGCN_S_se: 0.026
#
# all_seed_Concat_3_MAE: 1.698
# all_seed_Concat_3_se: 0.032
#
# all_seed_Concat_5_MAE: 1.007
# all_seed_Concat_5_se: 0.023
#
# all_seed_Concat_7_MAE: 0.963
# all_seed_Concat_7_se: 0.020
#
# all_seed_Concat_10_MAE: 0.909
# all_seed_Concat_10_se: 0.020
#
# all_seed_Concat_20_MAE: 0.777
# all_seed_Concat_20_se: 0.024
#
# all_seed_Concat_ds_MAE: 0.640
# all_seed_Concat_ds_se: 0.018
#
# all_seed_kronecker_3_MAE: 1.340
# all_seed_kronecker_3_se: 0.026
#
# all_seed_kronecker_5_MAE: 0.827
# all_seed_kronecker_5_se: 0.023
#
# all_seed_kronecker_7_MAE: 0.831
# all_seed_kronecker_7_se: 0.024
#
# all_seed_kronecker_10_MAE: 0.765
# all_seed_kronecker_10_se: 0.015
#
# all_seed_kronecker_20_MAE: 0.626
# all_seed_kronecker_20_se: 0.020
#
# all_seed_kronecker_all_MAE: 0.597
# all_seed_kronecker_all_se: 0.014

# %%
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [3.182311276661025, 3.671486456427309, 3.789810605049133, 2.9835344865587023, 3.1201455183491307]
seed100_egcn_r = [1.7657341958582402, 2.0805807597107355, 2.095756355126699, 1.7606259046660528, 1.7703875474598965]
seed100_egcn_s = [0.8693326738145616, 1.15061165438758, 1.0501685639636384, 0.944971205025989, 0.9568252479452394]
seed100_egcn = [0.8186140240563287, 0.8650972165001763, 0.8982036987278197, 1.0353560380803215, 0.9270480409067633]
seed100_concat_3 = [0.6883360793855455, 0.7091455350981818, 0.5803674728185353, 0.6495589660273657, 0.6328288584553723]
seed100_concat_5 = [0.5965538688500722, 0.6647036625941595, 0.5015911460916201, 0.5629281410574913, 0.46777748654592405]
seed100_concat_7 = [0.5411212934388054, 0.6244525205641468, 0.4954153925180435, 0.5215295971847242, 0.5485461454034377]
seed100_concat_10 = [0.6199805080890656, 0.5889943866431713, 0.502904797055655, 0.5360570555511448, 0.5208634946839925]
seed100_concat_20 = [0.5092684307363298, 0.4829204435232613, 0.4923389392428928, 0.4698635623241878, 0.44270417448707616]
seed100_concat_ds = [0.5077599717511071, 0.5406696531455963, 0.5367115394274393, 0.4358647201334437, 0.4352701731715433]
seed100_kronecker_3 = [0.5949651522106595, 0.7449337572521634, 0.6277067918330431, 0.6291522338324123, 0.5769746870721489]
seed100_kronecker_5 = [0.7529419777335392, 0.544129597345988, 0.5267860656024681, 0.5327501924170388, 0.6103509023851235]
seed100_kronecker_7 = [0.6213934251997206, 0.5506710735956828, 0.4761897026333544, 0.38892738461494447, 0.4728676618983567]
seed300_concat_7 = [0.6289721298217773, 0.5250592802739024, 0.5887697254286872, 0.5296671687646045, 0.5897088780802252]
seed300_concat_10 = [0.5504769717322455, 0.5117425111598438, 0.6069749306307899, 0.4934358405901326, 0.5572035194493601]
seed300_concat_20 = [0.4651015832689073, 0.4382752035392655, 0.46744339995914036, 0.4128202708562215, 0.5200250159276214]
seed300_concat_ds = [0.42865617725584243, 0.4205331092245049, 0.4696635013156467, 0.38420453813340927, 0.5095499916748853]
seed300_kronecker_3 = [0.7243327924940322, 0.4796274788180987, 0.6627329738934835, 0.6138967886235979, 0.655103249171757]
seed300_kronecker_5 = [0.5603355889850192, 0.4822500374582079, 0.7174727844203719, 0.5019731633986037, 0.6415186834230296]
seed300_kronecker_7 = [0.4986046335432264, 0.450922549592538, 0.5583985719415877, 0.4424169679560388, 0.4923401383051263]
seed300_kronecker_10 = [0.4656606600019667, 0.4497758007256521, 0.5005669842825996, 0.41118342815173997, 0.43831502572358444]
seed300_kronecker_20 = [0.4569939759042528, 0.3969269789920913, 0.47307554377449884, 0.3194640718566047, 0.5173367126003761]
seed300_kronecker_all = [0.36914045346228197, 0.3586795446442233, 0.348260112007459, 0.4218963747554355, 0.40308668986291085]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# all_seed_GCN_MSE: 3.317
# all_seed_GCN_se: 0.080
#
# all_seed_EGCN_R_MSE: 2.015
# all_seed_EGCN_R_se: 0.077
#
# all_seed_EGCN_S_MSE: 0.960
# all_seed_EGCN_S_se: 0.027
#
# all_seed_EGCN_S_MSE: 0.918
# all_seed_EGCN_S_se: 0.028
#
# all_seed_Concat_3_MSE: 0.686
# all_seed_Concat_3_se: 0.030
#
# all_seed_Concat_5_MSE: 0.606
# all_seed_Concat_5_se: 0.024
#
# all_seed_Concat_7_MSE: 0.554
# all_seed_Concat_7_se: 0.012
#
# all_seed_Concat_10_MSE: 0.569
# all_seed_Concat_10_se: 0.016
#
# all_seed_Concat_20_MSE: 0.470
# all_seed_Concat_20_se: 0.010
#
# all_seed_Concat_ds_MSE: 0.477
# all_seed_Concat_ds_se: 0.015
#
# all_seed_kronecker_3_MSE: 0.637
# all_seed_kronecker_3_se: 0.019
#
# all_seed_kronecker_5_MSE: 0.592
# all_seed_kronecker_5_se: 0.024
#
# all_seed_kronecker_7_MSE: 0.492
# all_seed_kronecker_7_se: 0.015
#
# all_seed_kronecker_10_MSE: 0.460
# all_seed_kronecker_10_se: 0.011
#
# all_seed_kronecker_20_MSE: 0.453
# all_seed_kronecker_20_se: 0.023
#
# all_seed_kronecker_all_MSE: 0.423
# all_seed_kronecker_all_se: 0.022

# %%
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [1.4793324648009407, 1.5019039793809255, 1.5302829159630669, 1.3897288947635227, 1.4487813842454145]
seed100_egcn_r = [1.041749185985989, 1.1468471680084864, 1.1540858141581218, 1.0817898480097452, 1.0632362722825375]
seed100_egcn_s = [0.6868392615848118, 0.8788606923156315, 0.8907642237345378, 0.8240677592489455, 0.6794887408285939]
seed100_egcn = [0.6714685344696045, 0.7809648831685384, 0.8401347001393636, 0.8392288072903951, 0.7087082138145547]
seed200_kronecker_10 = [0.48569675339592827, 0.4622279919518365, 0.5051700199974908, 0.5238857539494832, 0.4746371486638611]
seed200_kronecker_20 = [0.500923555692037, 0.47701854758792456, 0.51962843047248, 0.5280956501430936, 0.4439079351887304]
seed200_kronecker_all =[0.5672599008348254, 0.4447291766272651, 0.5033756701151529, 0.5629100534651015, 0.41866397752635803]

seed300_gcn = [1.504715421464708, 1.4375490220387777, 1.4675836743248833, 1.3478274652693008, 1.50102448988591]
seed300_egcn_r = [0.9938005383809407, 1.0797421349419487, 1.1310827922821045, 1.0897201357947455, 1.1643583543500187]
seed300_egcn_s = [0.7597723854912652, 0.6670139275656806, 0.7249862405988905, 0.9345753606160482, 0.7218532809076855]
seed300_egcn = [0.7903556352191501, 0.7045256503423055, 0.7235430728064643, 0.7639179399278428, 0.7301549958762619]
seed300_concat_3 = [0.6455453088548448, 0.5661674118041993, 0.5798472001817492, 0.5992778375413683, 0.6058641656379867]
seed300_concat_5 = [0.5852178467644585, 0.5426748773786757, 0.5784795644548204, 0.5783079147338868, 0.5888637404084731]
seed300_concat_7 = [0.6004664463467068, 0.5509341801537407, 0.5349695470598009, 0.5222540283203125, 0.5231366157531738]
seed300_concat_10 = [0.5644569953282674, 0.5226889620886909, 0.5418283091651068, 0.5498961660597059, 0.5097932489958104]
seed300_concat_20 = [0.5183701446321276, 0.4820728047688802, 0.4654064602322049, 0.47242496066623263, 0.5158491974885243]
seed300_concat_ds = [0.4656838884618547, 0.44719852553473577, 0.47259060435824923, 0.5053803422715929, 0.5050951657316233]
seed300_kronecker_3 = [0.6140640232298109, 0.5544357861412896, 0.5911090882619222, 0.560316530863444, 0.563089962835354]
seed300_kronecker_5 = [0.5746601994832357, 0.5474401262071398, 0.6297175428602431, 0.5006203333536784, 0.5777460683284877]
seed300_kronecker_7 = [0.5547286902533637, 0.5464709054099189, 0.5674339167277018, 0.4775736554463704, 0.49726727617994804]
seed300_kronecker_10 = [0.5109755041864184, 0.5306760025024414, 0.4959910477532281, 0.47931188583374024, 0.47591891477811704]
seed300_kronecker_20 = [0.4745637051264445, 0.4742780791388618, 0.4798502604166667, 0.45870814429389106, 0.4964186010906875]
seed300_kronecker_all = [0.4821628483798769, 0.4223105896843804, 0.4223769913779365, 0.45277721616956923, 0.44470688635032085]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# all_seed_GCN_MAE: 1.475
# all_seed_GCN_se: 0.015
#
# all_seed_EGCN_R_MAE: 1.092
# all_seed_EGCN_R_se: 0.013
#
# all_seed_EGCN_S_MAE: 0.774
# all_seed_EGCN_S_se: 0.021
#
# all_seed_EGCN_S_MAE: 0.761
# all_seed_EGCN_S_se: 0.013
#
# all_seed_Concat_3_MAE: 0.607
# all_seed_Concat_3_se: 0.009
#
# all_seed_Concat_5_MAE: 0.580
# all_seed_Concat_5_se: 0.008
#
# all_seed_Concat_7_MAE: 0.536
# all_seed_Concat_7_se: 0.008
#
# all_seed_Concat_10_MAE: 0.538
# all_seed_Concat_10_se: 0.007
#
# all_seed_Concat_20_MAE: 0.508
# all_seed_Concat_20_se: 0.007
#
# all_seed_Concat_ds_MAE: 0.479
# all_seed_Concat_ds_se: 0.008
#
# all_seed_kronecker_3_MAE: 0.590
# all_seed_kronecker_3_se: 0.012
#
# all_seed_kronecker_5_MAE: 0.567
# all_seed_kronecker_5_se: 0.012
#
# all_seed_kronecker_7_MAE: 0.520
# all_seed_kronecker_7_se: 0.010
#
# all_seed_kronecker_10_MAE: 0.498
# all_seed_kronecker_10_se: 0.006
#
# all_seed_kronecker_20_MAE: 0.484
# all_seed_kronecker_20_se: 0.007
#
# all_seed_kronecker_all_MAE: 0.469
# all_seed_kronecker_all_se: 0.013

# %%
backbone = 'GCN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [7.113293085342798, 6.4974015064728565, 6.7766602345002, 6.619444235777244, 6.926248958697334]
seed100_egcn_r = [3.646434490497296, 3.833992151113657, 3.766239215166141, 4.004765779544146, 3.9471413121817593]
seed100_egcn_s = [1.5343679525913336, 1.5385114963238056, 1.8661100436479618, 1.751120347243089, 1.353779192549733]
seed100_egcn = [1.44205598342113, 1.4550001926911182, 1.6544577036148462, 1.6113232588156676, 1.4225346379386732]
seed100_concat_3 = [1.1458980242411296, 1.0425851039397411, 1.2982255740043445, 1.2375633044120593, 1.162977078471321]
seed100_concat_5 = [0.8177178089435284, 0.8999978823539538, 0.9930159739958935, 1.0407931498992138, 0.8287058577369958]
seed100_concat_7 = [0.8594932922950158, 0.8566331741137382, 0.9781463207342685, 0.8654074302086463, 0.7449596270966453]
seed100_concat_10 = [0.7341935573480068, 0.7021677066118289, 0.7952278210566595, 0.7454769305693798, 0.6787417780477017]
seed100_concat_20 = [0.593915248528505, 0.5882255603105594, 0.7093292627579126, 0.6788059870402018, 0.599785564044794]
seed100_concat_ds = [0.5904776560954559, 0.5211395911681347, 0.816370413853572, 0.6320788921454014, 0.5479536208862694]
seed100_kronecker_3 = [1.0576184223859737, 0.9138269302172538, 1.30865417382656, 1.1084877527677095, 0.9586849517334765]
seed100_kronecker_5 = [0.8409953239636544, 0.784165504651192, 0.8886842727661133, 0.7767120385781313, 0.8052690524262742]
seed100_kronecker_7 = [0.6678431339752979, 0.6414054112556653, 0.7413792365636581, 0.704776922861735, 0.6762713471921488]
seed100_kronecker_10 = [0.5367394594045786, 0.48476589643038237, 0.5533173328790909, 0.5197395177987906, 0.49202679521359577]
seed100_kronecker_20 = [0.4318881707313733, 0.4018468367747771, 0.5173151370806571, 0.44214927233182466, 0.4281249914687282]
seed100_kronecker_all = [0.47401920954386395, 0.37680623470208585, 0.5035894161615616, 0.4560409386952718, 0.44261951873096794]

seed200_gcn = [6.3448531321990185, 7.379406464405549, 8.120496211907803, 6.470394721397986, 6.237859463920228]
seed200_egcn_r = [4.3965140122633715, 4.927061129838992, 4.99788587521284, 4.333594004313151, 4.510283887576752]
seed200_egcn_s = [1.6603208688589244, 1.343772448026217, 1.773184360601963, 1.8439829410650792, 1.848502527791471]
seed200_egcn = [1.4248144932282276, 1.2573925409561548, 1.5457418392866085, 1.614598396496895, 1.499978744945587]
seed200_concat_3 = [1.1542697075085762, 1.0902521182329228, 1.3012883968842335, 1.2105011573204627, 1.1172338857437476]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: scgas
# all_seed_GCN_MSE: 6.668
# all_seed_GCN_se: 0.142
#
# all_seed_EGCN_R_MSE: 4.378
# all_seed_EGCN_R_se: 0.116
#
# all_seed_EGCN_S_MSE: 1.653
# all_seed_EGCN_S_se: 0.047
#
# all_seed_EGCN_S_MSE: 1.464
# all_seed_EGCN_S_se: 0.034
#
# all_seed_Concat_3_MSE: 1.192
# all_seed_Concat_3_se: 0.026
#
# all_seed_Concat_5_MSE: 0.946
# all_seed_Concat_5_se: 0.027
#
# all_seed_Concat_7_MSE: 0.858
# all_seed_Concat_7_se: 0.017
#
# all_seed_Concat_10_MSE: 0.700
# all_seed_Concat_10_se: 0.014
#
# all_seed_Concat_20_MSE: 0.598
# all_seed_Concat_20_se: 0.015
#
# all_seed_Concat_ds_MSE: 0.592
# all_seed_Concat_ds_se: 0.019
#
# all_seed_kronecker_3_MSE: 1.076
# all_seed_kronecker_3_se: 0.032
#
# all_seed_kronecker_5_MSE: 0.818
# all_seed_kronecker_5_se: 0.017
#
# all_seed_kronecker_7_MSE: 0.657
# all_seed_kronecker_7_se: 0.016
#
# all_seed_kronecker_10_MSE: 0.528
# all_seed_kronecker_10_se: 0.011
#
# all_seed_kronecker_20_MSE: 0.444
# all_seed_kronecker_20_se: 0.009
#
# all_seed_kronecker_all_MSE: 0.447
# all_seed_kronecker_all_se: 0.009

# %%
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [2.013793651874249, 1.8971146803635817, 2.0012607329931016, 1.9914472041985927, 2.1050051119380866]
seed100_egcn_r = [1.47375671680157, 1.4463257178282127, 1.4322566741552107, 1.4186043127989159, 1.525183510094786]
seed100_egcn_s = [0.9130859497265938, 0.9208053686679938, 0.9730379031254694, 0.955296455285488, 0.8853058129453811]
seed100_egcn = [0.8504461508530837, 0.866515563084529, 0.9084751422588642, 0.8798815531608386, 0.8808126967555037]
seed100_concat_3 = [0.7782029249729254, 0.7892678578694662, 0.8386293313442132, 0.8138753573099772, 0.8200580852861983]
seed100_concat_5 = [0.670781196692051, 0.7118328656905737, 0.7429421987289038, 0.7096104866419083, 0.6857696874453999]
seed100_concat_7 = [0.6730293004940717, 0.693090218764085, 0.6984866093366574, 0.6988887542333359, 0.6671039471611048]
seed100_concat_10 = [0.6193975179623334, 0.6164588194627029, 0.6572092007368039, 0.6164394892179049, 0.5960143214216629]
seed100_concat_20 = [0.5578674169687124, 0.5416751886025454, 0.6075888413649339, 0.5831084618201623, 0.5836442210042058]
seed100_concat_ds = [0.551056702931722, 0.5105337607554901, 0.6140029858320187, 0.5832260449727377, 0.568997989447353]
seed100_kronecker_3 = [0.7407758786128118, 0.7660930951436361, 0.8212410486661471, 0.7720841261056753, 0.802250542198888]
seed100_kronecker_5 = [0.6731671553391677, 0.70941528907189, 0.7097418369391025, 0.7222997469779773, 0.6602978569250137]
seed100_kronecker_7 = [0.5915003434205667, 0.6298933518238556, 0.5999321570763221, 0.577945195711576, 0.5738010223681173]
seed300_concat_7 = [0.7230075933994391, 0.6908563100374662, 0.7097671459882687, 0.6465871762006711, 0.6409511139598517]
seed300_concat_10 = [0.6514821419349084, 0.6193715364505084, 0.6408223861303085, 0.5751597942450107, 0.5969167593569039]
seed300_concat_20 = [0.5778695253225473, 0.5818282763163248, 0.5687119655120068, 0.5347198278476031, 0.544523897262427]
seed300_concat_ds = [0.5811175810985076, 0.5608155727386475, 0.5785031012999706, 0.5371405894939716, 0.5227534077799739]
seed300_kronecker_3 = [0.8599370076106145, 0.8048110864101312, 0.7793512833424103, 0.7338459797394581, 0.7423330434975913]
seed300_kronecker_5 = [0.6906522970933181, 0.6897216332264435, 0.7133264419360038, 0.6241393700624124, 0.6290929386029228]
seed300_kronecker_7 = [0.6724205139355782, 0.5877877137599847, 0.5868284029838367, 0.5480517668601794, 0.5417385527881952]
seed300_kronecker_10 = [0.550119705689259, 0.5420713485815586, 0.5443275280487843, 0.5157567660013834, 0.4912403703878482]
seed300_kronecker_20 = [0.5027665908520038, 0.49098420754457134, 0.5042952085152651, 0.4708615021827893, 0.4684738975744278]
seed300_kronecker_all = [0.487381134277735, 0.4825874353066469, 0.5117534123934232, 0.47000807982224685, 0.46591959822292145]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: scgas
# all_seed_GCN_MAE: 1.966
# all_seed_GCN_se: 0.022
#
# all_seed_EGCN_R_MAE: 1.541
# all_seed_EGCN_R_se: 0.021
#
# all_seed_EGCN_S_MAE: 0.955
# all_seed_EGCN_S_se: 0.012
#
# all_seed_EGCN_S_MAE: 0.879
# all_seed_EGCN_S_se: 0.008
#
# all_seed_Concat_3_MAE: 0.814
# all_seed_Concat_3_se: 0.008
#
# all_seed_Concat_5_MAE: 0.710
# all_seed_Concat_5_se: 0.007
#
# all_seed_Concat_7_MAE: 0.687
# all_seed_Concat_7_se: 0.007
#
# all_seed_Concat_10_MAE: 0.613
# all_seed_Concat_10_se: 0.007
#
# all_seed_Concat_20_MAE: 0.563
# all_seed_Concat_20_se: 0.006
#
# all_seed_Concat_ds_MAE: 0.560
# all_seed_Concat_ds_se: 0.008
#
# all_seed_kronecker_3_MAE: 0.782
# all_seed_kronecker_3_se: 0.010
#
# all_seed_kronecker_5_MAE: 0.678
# all_seed_kronecker_5_se: 0.008
#
# all_seed_kronecker_7_MAE: 0.593
# all_seed_kronecker_7_se: 0.009
#
# all_seed_kronecker_10_MAE: 0.540
# all_seed_kronecker_10_se: 0.006
#
# all_seed_kronecker_20_MAE: 0.491
# all_seed_kronecker_20_se: 0.006
#
# all_seed_kronecker_all_MAE: 0.497
# all_seed_kronecker_all_se: 0.006

# %% [markdown]
# # GAT

# %%
backbone = 'GAT'
dataset = 'freesolv'
metric = 'MSE'

seed100_gcn = [6.962656696950357, 7.425777164969857, 4.871581250288355, 6.658351327490619, 4.60243169769986]
seed100_egcn_r = [6.191213772991511, 4.7889779158464565, 3.919316749873124, 6.319493091012549, 3.482653596019017]
seed100_egcn_s = [5.2431913360835996, 5.260970829040047, 4.217202734759473, 5.362135158749077, 3.45912181694089]
seed100_egcn = [6.292416429895115, 4.346340629998155, 3.679638359490342, 5.251160809374231, 2.8653227063535733]
seed100_concat_3 = [2.7491550896111434, 3.9185079739788384, 3.78483341247078, 3.61019104484498, 3.4919006687994223]
seed100_concat_5 = [1.2153164270355945, 2.045844040517732, 1.8088318832277313, 2.5925599346010704, 1.5006552154326256]
seed100_concat_7 = [1.2383425554891272, 1.7492449602742834, 1.9514069444551243, 1.3126190365768793, 1.6115914014459567]
seed100_concat_10 = [1.0181234840332993, 1.6850220988115927, 1.6936731713963307, 1.2718754265252061, 1.546651171363947]
seed100_concat_20 = [0.841383138040858, 1.2563854127418337, 1.82161190002922, 1.008746905589667, 1.5479319941906529]
seed100_concat_ds = [0.994454503998043, 1.1450903284268117, 1.2412830412857176, 0.9268847488042876, 1.2073240134552234]
seed100_kronecker_3 = [3.1429005119744247, 2.9159968518835355, 3.4405495951494833, 2.9529183455339565, 3.1502332414379555]
seed100_kronecker_5 = [0.9289923915712852, 2.047512204628291, 1.48559816615788, 1.3368246724286417, 1.7975780332588966]
seed100_kronecker_7 = [0.8801806667658287, 1.4930743119848056, 1.421265789842981, 1.1395920730951263, 1.3051095071838785]
seed100_kronecker_10 = [0.854796875180222, 1.2632760250662256, 1.1423220897284079, 0.9522529211569959, 1.4103060095137312]
seed100_kronecker_20 = [1.147511602386715, 1.0993064069372462, 1.8550794706569882, 1.0688119197454977, 0.8506086656169696]
seed100_kronecker_all = [1.108848496684878, 1.2478561251182256, 1.1177537122110681, 0.9249781210591473, 1.6635486775909671]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")a
# Out:
# backbone: GAT
# metric: MSE
# dataset: freesolv
# all_seed_GCN_MSE: 6.104
# all_seed_GCN_se: 0.573
#
# all_seed_EGCN_R_MSE: 4.940
# all_seed_EGCN_R_se: 0.577
#
# all_seed_EGCN_S_MSE: 4.709
# all_seed_EGCN_S_se: 0.376
#
# all_seed_EGCN_S_MSE: 4.487
# all_seed_EGCN_S_se: 0.598
#
# all_seed_Concat_3_MSE: 3.511
# all_seed_Concat_3_se: 0.204
#
# all_seed_Concat_5_MSE: 1.833
# all_seed_Concat_5_se: 0.236
#
# all_seed_Concat_7_MSE: 1.573
# all_seed_Concat_7_se: 0.133
#
# all_seed_Concat_10_MSE: 1.443
# all_seed_Concat_10_se: 0.131
#
# all_seed_Concat_20_MSE: 1.295
# all_seed_Concat_20_se: 0.178
#
# all_seed_Concat_ds_MSE: 1.103
# all_seed_Concat_ds_se: 0.061
#
# all_seed_kronecker_3_MSE: 3.121
# all_seed_kronecker_3_se: 0.093
#
# all_seed_kronecker_5_MSE: 1.519
# all_seed_kronecker_5_se: 0.192
#
# all_seed_kronecker_7_MSE: 1.248
# all_seed_kronecker_7_se: 0.110
#
# all_seed_kronecker_10_MSE: 1.125
# all_seed_kronecker_10_se: 0.101
#
# all_seed_kronecker_20_MSE: 1.204
# all_seed_kronecker_20_se: 0.170
#
# all_seed_kronecker_all_MSE: 1.213
# all_seed_kronecker_all_se: 0.124

# %%
backbone = 'GAT'
dataset = 'freesolv'
metric = 'MAE'

seed100_gcn = [1.7611141955758642, 1.8987676965908742, 1.8782244704839752, 1.874737506776344, 1.8231979981633544]
seed100_egcn_r = [1.760584883802519, 1.5952616413747231, 1.7008963757612574, 1.6742006437046322, 1.4295701907791254]
seed100_egcn_s = [1.6415167680875522, 1.6404059102216104, 1.704530280406081, 1.7280380969911109, 1.4417249810604649]
seed100_egcn = [1.5815259978527159, 1.5251863134188914, 1.5661791103092704, 1.8573789221095287, 1.4974737968153626]
seed100_concat_3 = [1.5032671230045829, 1.78291281752699, 1.7908142870805395, 1.594051331046998, 1.5418061682286153]
seed100_concat_5 = [0.8122942166065606, 0.9187666975607084, 1.0872191932257704, 0.9218920159527636, 0.9463703213757231]
seed100_concat_7 = [0.9238422423835815, 0.9045378317044476, 1.045367834136242, 0.8300119385005921, 0.9641135494217618]
seed100_concat_10 = [0.7055095837810846, 0.8175698227769747, 1.0100417399969626, 0.8355783177173044, 0.8655516018394296]
seed100_concat_20 = [0.5560023991141733, 0.7237650803693636, 0.9389674419493187, 0.6802813912939838, 0.7205524089682194]
seed100_concat_ds = [0.5428615555049866, 0.7361175507072388, 0.7805361259640671, 0.5788663203322043, 0.5784342866817503]
seed100_kronecker_3 = [1.1506984590545415, 1.4558817946066067, 1.4195384528693251, 1.2764289735809087, 1.4501852925497156]
seed100_kronecker_5 = [0.6925212229330708, 0.9435519421194482, 0.9164422853725163, 0.8567146091010627, 0.8905161009490035]
seed100_kronecker_7 = [0.7618917029673659, 0.8264204610989788, 0.9028688716137503, 0.7838772901399867, 0.867206207213511]
seed100_kronecker_10 = [0.5980644526444082, 0.7327158469853439, 0.7566788440614235, 0.7014215874859667, 0.8115542644762811]
seed100_kronecker_20 = [0.5176634976244349, 0.6471199576310286, 0.7894471085916354, 0.610389078695943, 0.5854370462075444]
seed100_kronecker_all = [0.5619139633779451, 0.6745381092462014, 0.6518700817438561, 0.6008739321250615, 0.600898711508467]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MAE
# dataset: freesolv
# 5
# all_seed_GCN_MAE: 1.847
# all_seed_GCN_se: 0.025
#
# all_seed_EGCN_R_MAE: 1.632
# all_seed_EGCN_R_se: 0.057
#
# all_seed_EGCN_S_MAE: 1.631
# all_seed_EGCN_S_se: 0.050
#
# all_seed_EGCN_S_MAE: 1.606
# all_seed_EGCN_S_se: 0.065
#
# all_seed_Concat_3_MAE: 1.643
# all_seed_Concat_3_se: 0.061
#
# all_seed_Concat_5_MAE: 0.937
# all_seed_Concat_5_se: 0.044
#
# all_seed_Concat_7_MAE: 0.934
# all_seed_Concat_7_se: 0.035
#
# all_seed_Concat_10_MAE: 0.847
# all_seed_Concat_10_se: 0.049
#
# all_seed_Concat_20_MAE: 0.724
# all_seed_Concat_20_se: 0.062
#
# all_seed_Concat_ds_MAE: 0.643
# all_seed_Concat_ds_se: 0.048
#
# all_seed_kronecker_3_MAE: 1.351
# all_seed_kronecker_3_se: 0.060
#
# all_seed_kronecker_5_MAE: 0.860
# all_seed_kronecker_5_se: 0.044
#
# all_seed_kronecker_7_MAE: 0.828
# all_seed_kronecker_7_se: 0.026
#
# all_seed_kronecker_10_MAE: 0.720
# all_seed_kronecker_10_se: 0.035
#
# all_seed_kronecker_20_MAE: 0.630
# all_seed_kronecker_20_se: 0.045
#
# all_seed_kronecker_all_MAE: 0.618
# all_seed_kronecker_all_se: 0.020

# %%
backbone = 'GAT'
dataset = 'esol'
metric = 'MSE'

seed100_gcn = [4.010509200096131, 3.1166435156928167, 2.3051705339219835, 3.6552788786093395, 2.8766478231824966]
seed100_egcn_r = [2.375552126897706, 1.8134336725042925, 1.65563544538286, 2.082961741086393, 2.2506748590175274]
seed100_egcn_s = [0.7350514374838935, 0.6170273979070285, 0.8186795311012409, 1.0385424628853799, 0.9526494042988916]
seed100_egcn = [0.6608601482046975, 0.5871767711639404, 0.8656879926079677, 0.9285280593236287, 0.7256085484038366]
seed100_concat_3 = [0.6111174547672271, 0.6584147935443454, 0.5378213431686163, 0.6346083910597695, 0.6007345443517627]
seed100_concat_5 = [0.5722917913066017, 0.6429524580223693, 0.5045322547687424, 0.4980184586180581, 0.5004283712298859]
seed100_concat_7 = [0.5190422031614516, 0.5777627440624767, 0.46543749446670213, 0.5531274522675408, 0.5116954264661814]
seed100_concat_10 = [0.49482392801178826, 0.5645865268177457, 0.4989674042330848, 0.4390978198581272, 0.5172867234057792]
seed100_concat_20 = [0.4237149945894877, 0.4540887608130773, 0.46861748918890955, 0.45972182247373794, 0.42910377779721165]
seed100_concat_ds = [0.4131363430288103, 0.44288990122576555, 0.45569895492659673, 0.3919668153921763, 0.4660667821699302]
seed100_kronecker_3 = [0.6569375777244568, 0.6836616198221842, 0.5785520333382819, 0.8125097551279598, 0.5841422028478547]
seed100_kronecker_5 = [0.5861042703522577, 0.6072757932874892, 0.5957692316312913, 0.5950489148073312, 0.5202290158439838]
seed100_kronecker_7 = [0.5408414933416579, 0.4989821608033445, 0.5588534494034119, 0.38072283135520085, 0.4926104519335709]
seed100_kronecker_10 = [0.5015489901436699, 0.5557684464587106, 0.49502172166274655, 0.441266610622406, 0.4940897158063981]
seed100_kronecker_20 = [0.5264847199784385, 0.444345659216245, 0.5092624149719874, 0.4818279483583238, 0.37630512247001546]
seed100_kronecker_all = [0.40887721406088934, 0.3443146611998479, 0.44309450406167245, 0.5216966071393755, 0.3549018200273556]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MSE
# dataset: esol
# 5
# all_seed_GCN_MSE: 3.193
# all_seed_GCN_se: 0.298
#
# all_seed_EGCN_R_MSE: 2.036
# all_seed_EGCN_R_se: 0.134
#
# all_seed_EGCN_S_MSE: 0.832
# all_seed_EGCN_S_se: 0.075
#
# all_seed_EGCN_S_MSE: 0.754
# all_seed_EGCN_S_se: 0.063
#
# all_seed_Concat_3_MSE: 0.609
# all_seed_Concat_3_se: 0.020
#
# all_seed_Concat_5_MSE: 0.544
# all_seed_Concat_5_se: 0.028
#
# all_seed_Concat_7_MSE: 0.525
# all_seed_Concat_7_se: 0.019
#
# all_seed_Concat_10_MSE: 0.503
# all_seed_Concat_10_se: 0.020
#
# all_seed_Concat_20_MSE: 0.447
# all_seed_Concat_20_se: 0.009
#
# all_seed_Concat_ds_MSE: 0.434
# all_seed_Concat_ds_se: 0.014
#
# all_seed_kronecker_3_MSE: 0.663
# all_seed_kronecker_3_se: 0.043
#
# all_seed_kronecker_5_MSE: 0.581
# all_seed_kronecker_5_se: 0.016
#
# all_seed_kronecker_7_MSE: 0.494
# all_seed_kronecker_7_se: 0.031
#
# all_seed_kronecker_10_MSE: 0.498
# all_seed_kronecker_10_se: 0.018
#
# all_seed_kronecker_20_MSE: 0.468
# all_seed_kronecker_20_se: 0.027
#
# all_seed_kronecker_all_MSE: 0.415
# all_seed_kronecker_all_se: 0.032

# %%
backbone = 'GAT'
dataset = 'esol'
metric = 'MAE'

seed100_gcn = [1.4881497266557482, 1.3671615939670139, 1.2672440497080486, 1.4355417887369792, 1.4568929126084114]
seed100_egcn_r = [1.1409479882982043, 0.9913625081380208, 0.9145362981160482, 1.1641382371054756, 1.1264819237629222]
seed100_egcn_s = [0.654888096915351, 0.6292525842454698, 0.6847648090786405, 0.7458215173085531, 0.6396236220120334]
seed100_egcn = [0.652837036980523, 0.5888636059231228, 0.6805456882052952, 0.7481356604894003, 0.6656305191275307]
seed100_concat_3 = [0.5809993216726514, 0.5863585657543606, 0.5419943523406983, 0.5972449064254761, 0.5759828447770442]
seed100_concat_5 = [0.5980978253152636, 0.5862002660168542, 0.48465779463450115, 0.5396157422330644, 0.5443828057350041]
seed100_concat_7 = [0.5603776706589593, 0.5382424465815226, 0.4885909080505371, 0.5428450028101603, 0.5206918747939727]
seed100_concat_10 = [0.5344316832224528, 0.5253570144706302, 0.517148093647427, 0.48690072298049925, 0.5171655889124597]
seed100_concat_20 = [0.48179148117701215, 0.5047896820969052, 0.4747576438056098, 0.5107172478569878, 0.5060990056277371]
seed100_concat_ds = [0.4766967549588945, 0.49180890685982176, 0.4575082439846463, 0.4697527241706848, 0.5008822978855755]
seed100_kronecker_3 = [0.6513181145985921, 0.6614085960388184, 0.5773886320326064, 0.6170279166433547, 0.5939529929392138]
seed100_kronecker_5 = [0.5855811757511563, 0.6348625527487861, 0.5422360208299425, 0.5725456648402744, 0.5613989157823739]
seed100_kronecker_7 = [0.5513462858729893, 0.511882996029324, 0.4733144855499268, 0.47950473335054183, 0.5158467090602489]
seed100_kronecker_10 = [0.5315425279405382, 0.5129687407281663, 0.5047894827524821, 0.4835549134678311, 0.529433012533818]
seed100_kronecker_20 = [0.5612509102291531, 0.47723094125588733, 0.4757902299033271, 0.5112944465213352, 0.48404972301180665]
seed100_kronecker_all = [0.4650336315896776, 0.4330293791823917, 0.46750406689114044, 0.4619723497496711, 0.4395814745436681]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MAE
# dataset: esol
# 5
# all_seed_GCN_MAE: 1.403
# all_seed_GCN_se: 0.039
#
# all_seed_EGCN_R_MAE: 1.067
# all_seed_EGCN_R_se: 0.049
#
# all_seed_EGCN_S_MAE: 0.671
# all_seed_EGCN_S_se: 0.021
#
# all_seed_EGCN_S_MAE: 0.667
# all_seed_EGCN_S_se: 0.026
#
# all_seed_Concat_3_MAE: 0.577
# all_seed_Concat_3_se: 0.009
#
# all_seed_Concat_5_MAE: 0.551
# all_seed_Concat_5_se: 0.020
#
# all_seed_Concat_7_MAE: 0.530
# all_seed_Concat_7_se: 0.012
#
# all_seed_Concat_10_MAE: 0.516
# all_seed_Concat_10_se: 0.008
#
# all_seed_Concat_20_MAE: 0.496
# all_seed_Concat_20_se: 0.007
#
# all_seed_Concat_ds_MAE: 0.479
# all_seed_Concat_ds_se: 0.008
#
# all_seed_kronecker_3_MAE: 0.620
# all_seed_kronecker_3_se: 0.016
#
# all_seed_kronecker_5_MAE: 0.579
# all_seed_kronecker_5_se: 0.016
#
# all_seed_kronecker_7_MAE: 0.506
# all_seed_kronecker_7_se: 0.014
#
# all_seed_kronecker_10_MAE: 0.512
# all_seed_kronecker_10_se: 0.009
#
# all_seed_kronecker_20_MAE: 0.502
# all_seed_kronecker_20_se: 0.016
#
# all_seed_kronecker_all_MAE: 0.453
# all_seed_kronecker_all_se: 0.007

# %%
backbone = 'GAT'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [6.150399525960286, 5.242617876101763, 5.400340447059045, 5.433693421192658, 5.508022710538139]
seed100_egcn_r = [4.615162482628455, 4.094345630743565, 4.049773436326247, 4.3207702147655, 4.478840739582293]
seed100_egcn_s = [1.5318184387989533, 1.3927880311623597, 1.3483553910866761, 1.4474147405379858, 1.3616760302656374]
seed100_egcn = [1.4700837257580879, 1.3075845669477413, 1.1215431262285283, 1.290159286596836, 1.3107098222921452]
seed100_concat_3 = [1.0643840936514049, 0.9756178733630058, 1.2436137199401855, 1.1537723418993828, 1.0131802543664512]
seed100_concat_5 = [0.8260191770700308, 0.7697109197958921, 0.9128370651831994, 0.9161865894611065, 0.8238964507374139]
seed100_concat_7 = [0.7705699113699106, 0.7818471468411959, 0.9158124190110427, 0.8167628263815855, 0.7372816286909695]
seed100_concat_10 = [0.6571551102858323, 0.5966492799612192, 0.8596205833630685, 0.6981388972355769, 0.5866569055916783]
seed100_concat_20 = [0.6094788588010348, 0.5302269886701535, 0.6829146483005621, 0.7580066705361391, 0.5575052572134584]
seed100_concat_ds = [0.5833599750812237, 0.5027688099787786, 0.7091014446356357, 0.6540579306773651, 0.5468462008637742]
seed100_kronecker_3 = [1.064779831812932, 0.9012842056078788, 1.1959038147559533, 1.0770180775569036, 1.1065651646818215]
seed100_kronecker_5 = [0.7348553706438113, 0.6838257496173565, 0.9163453517816006, 0.8458937131441556, 0.7826113959851737]
seed100_kronecker_7 = [0.6062124753609682, 0.5760169212634747, 0.7004667795621432, 0.6306055753658979, 0.6061082419495993]
seed100_kronecker_10 = [0.5856831379425831, 0.4954653886648325, 0.5587532092363406, 0.5370629322834504, 0.5127114426975433]
seed100_kronecker_20 = [0.43477270542046964, 0.3765183534377661, 0.49262071878482133, 0.47080494195987016, 0.4437973583087373]
seed100_kronecker_all = [0.4329248330531976, 0.38788574169843626, 0.502244967680711, 0.46567520117148375, 0.4290636446529303]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MSE
# dataset: scgas
# 5
# all_seed_GCN_MSE: 5.547
# all_seed_GCN_se: 0.157
#
# all_seed_EGCN_R_MSE: 4.312
# all_seed_EGCN_R_se: 0.109
#
# all_seed_EGCN_S_MSE: 1.416
# all_seed_EGCN_S_se: 0.034
#
# all_seed_EGCN_S_MSE: 1.300
# all_seed_EGCN_S_se: 0.055
#
# all_seed_Concat_3_MSE: 1.090
# all_seed_Concat_3_se: 0.049
#
# all_seed_Concat_5_MSE: 0.850
# all_seed_Concat_5_se: 0.028
#
# all_seed_Concat_7_MSE: 0.804
# all_seed_Concat_7_se: 0.031
#
# all_seed_Concat_10_MSE: 0.680
# all_seed_Concat_10_se: 0.049
#
# all_seed_Concat_20_MSE: 0.628
# all_seed_Concat_20_se: 0.042
#
# all_seed_Concat_ds_MSE: 0.599
# all_seed_Concat_ds_se: 0.037
#
# all_seed_kronecker_3_MSE: 1.069
# all_seed_kronecker_3_se: 0.048
#
# all_seed_kronecker_5_MSE: 0.793
# all_seed_kronecker_5_se: 0.041
#
# all_seed_kronecker_7_MSE: 0.624
# all_seed_kronecker_7_se: 0.021
#
# all_seed_kronecker_10_MSE: 0.538
# all_seed_kronecker_10_se: 0.016
#
# all_seed_kronecker_20_MSE: 0.444
# all_seed_kronecker_20_se: 0.020
#
# all_seed_kronecker_all_MSE: 0.444
# all_seed_kronecker_all_se: 0.019

# %%
backbone = 'GAT'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [1.7759796533829126, 1.6928284962972004, 1.7371569657937074, 1.7932014220800154, 1.8774465737632289]
seed100_egcn_r = [1.531086041377141, 1.4904960241073217, 1.4882689744998248, 1.5028700461754432, 1.5530376251513205]
seed100_egcn_s = [0.8998960592807868, 0.8967393239339193, 0.8771013479966384, 0.8710552484561236, 0.8923897667053028]
seed100_egcn = [0.870899518330892, 0.8761477714929825, 0.8299021476354355, 0.8698098965180225, 0.8582093845160244]
seed100_concat_3 = [0.7628070024343637, 0.7611641639318222, 0.8259176596617087, 0.8093127837547889, 0.7933094524346982]
seed100_concat_5 = [0.6907981970371344, 0.6857528319725623, 0.7015850116045047, 0.6750703102503067, 0.6657628556029104]
seed100_concat_7 = [0.6539978981018066, 0.656011667007055, 0.6600471398769281, 0.6432370528196677, 0.6257618669503794]
seed100_concat_10 = [0.6243070088900052, 0.6210964643038236, 0.6459859212239584, 0.6000160070566031, 0.6096001951077494]
seed100_concat_20 = [0.5532618302565354, 0.5393230059208014, 0.580170655861879, 0.5753270051418207, 0.5467046548764165]
seed100_concat_ds = [0.5425897439320883, 0.5237057331280831, 0.5785609269753481, 0.5672134436093844, 0.5333232331199768]
seed100_kronecker_3 = [0.7381322200481708, 0.7468429712148813, 0.8427563569484613, 0.8059253325829139, 0.78015197656406]
seed100_kronecker_5 = [0.6536092513646835, 0.6625114709903033, 0.6778999475332407, 0.6993502592429136, 0.662447810553895]
seed100_kronecker_7 = [0.601842476771428, 0.6013628030434633, 0.6183124811221392, 0.5944678233220027, 0.560081798809405]
seed100_kronecker_10 = [0.5590696946168557, 0.5149611570896246, 0.558666278154422, 0.5511644436762884, 0.5281840193385895]
seed100_kronecker_20 = [0.4895542034736046, 0.4574260956201798, 0.5056679432208722, 0.5190366781674899, 0.45844365689701166]
seed100_kronecker_all = [0.5015688370435666, 0.47375062795785755, 0.5056094634227264, 0.5061975259047288, 0.48834810470239803]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MAE
# dataset: scgas
# 5
# all_seed_GCN_MAE: 1.775
# all_seed_GCN_se: 0.031
#
# all_seed_EGCN_R_MAE: 1.513
# all_seed_EGCN_R_se: 0.013
#
# all_seed_EGCN_S_MAE: 0.887
# all_seed_EGCN_S_se: 0.006
#
# all_seed_EGCN_S_MAE: 0.861
# all_seed_EGCN_S_se: 0.008
#
# all_seed_Concat_3_MAE: 0.791
# all_seed_Concat_3_se: 0.013
#
# all_seed_Concat_5_MAE: 0.684
# all_seed_Concat_5_se: 0.006
#
# all_seed_Concat_7_MAE: 0.648
# all_seed_Concat_7_se: 0.006
#
# all_seed_Concat_10_MAE: 0.620
# all_seed_Concat_10_se: 0.008
#
# all_seed_Concat_20_MAE: 0.559
# all_seed_Concat_20_se: 0.008
#
# all_seed_Concat_ds_MAE: 0.549
# all_seed_Concat_ds_se: 0.010
#
# all_seed_kronecker_3_MAE: 0.783
# all_seed_kronecker_3_se: 0.019
#
# all_seed_kronecker_5_MAE: 0.671
# all_seed_kronecker_5_se: 0.008
#
# all_seed_kronecker_7_MAE: 0.595
# all_seed_kronecker_7_se: 0.010
#
# all_seed_kronecker_10_MAE: 0.542
# all_seed_kronecker_10_se: 0.009
#
# all_seed_kronecker_20_MAE: 0.486
# all_seed_kronecker_20_se: 0.012
#
# all_seed_kronecker_all_MAE: 0.495
# all_seed_kronecker_all_se: 0.006

# %% [markdown]
# # GIN

# %%
backbone = 'GIN'
dataset = 'freesolv'
metric = 'MSE'

seed100_gcn = [1.9439121756966657, 1.8848692526028852, 2.1678376986285834, 4.042791712002491, 2.4141968515993075]
seed100_egcn_r = [2.178820212056318, 2.218178816667692, 2.3509913467046784, 2.450548937940222, 2.505072191471362]
seed100_egcn_s = [1.8732530789112483, 2.0602212740680366, 3.348465506486067, 2.7595076072873095, 2.0153212347103437]
seed100_egcn = [1.8942077516570806, 2.644617816594642, 3.3040970329224595, 2.071504607914001, 2.2527949391430573]
seed100_concat_3 = [1.4154634100245678, 1.3535968750480591, 1.7553334273691252, 1.272189418161948, 1.2404308071118275]
seed100_concat_5 = [1.113214808186208, 1.7226717791219397, 1.609959910235067, 1.287910866925097, 1.3785057845916457]
seed100_concat_7 = [1.0353986484797921, 1.3169951251172645, 1.5103612584391917, 0.9005364996241773, 1.0891451700270631]
seed100_concat_10 = [1.2322367119976854, 1.613931986290639, 1.6667785344161385, 0.6346161909929411, 1.1102018574721941]
seed100_concat_20 = [1.0504522398700864, 1.3251352986012856, 1.6617519348625123, 0.7465174667478547, 0.8469276061949839]
seed100_concat_ds = [0.9787872194305179, 1.0685662922896737, 1.6161341329259196, 0.6220734738928126, 0.8989702890847475]
seed100_kronecker_3 = [1.8720739169383611, 1.999571957926112, 2.7372018708957464, 2.2375976081908218, 2.421704336318351]
seed100_kronecker_5 = [0.7230461751382182, 1.4492018391766885, 1.5669913704939715, 1.5425763317919152, 1.4938024327955173]
seed100_kronecker_7 = [0.9197233455387626, 1.4179378719780389, 1.8355178532637948, 0.8567821622833492, 1.145350740326725]
seed100_kronecker_10 = [1.7005941736416554, 3.658819784329632, 2.5583963168887642, 2.0097760177972748, 3.8257189088195336]
seed100_kronecker_20 = [1.2526593020581824, 1.9488874420406312, 2.1420168839101716, 1.2637036391130583, 1.236506428882366]
seed100_kronecker_all = [1.3041636099026899, 1.159816764471099, 1.0761966855507197, 0.7184569141057533, 0.7675113980551712]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GIN
# metric: MSE
# dataset: freesolv
# 5
# all_seed_GCN_MSE: 2.491
# all_seed_GCN_se: 0.399
#
# all_seed_EGCN_R_MSE: 2.341
# all_seed_EGCN_R_se: 0.063
#
# all_seed_EGCN_S_MSE: 2.411
# all_seed_EGCN_S_se: 0.280
#
# all_seed_EGCN_S_MSE: 2.433
# all_seed_EGCN_S_se: 0.251
#
# all_seed_Concat_3_MSE: 1.407
# all_seed_Concat_3_se: 0.092
#
# all_seed_Concat_5_MSE: 1.422
# all_seed_Concat_5_se: 0.110
#
# all_seed_Concat_7_MSE: 1.170
# all_seed_Concat_7_se: 0.108
#
# all_seed_Concat_10_MSE: 1.252
# all_seed_Concat_10_se: 0.188
#
# all_seed_Concat_20_MSE: 1.126
# all_seed_Concat_20_se: 0.166
#
# all_seed_Concat_ds_MSE: 1.037
# all_seed_Concat_ds_se: 0.163
#
# all_seed_kronecker_3_MSE: 2.254
# all_seed_kronecker_3_se: 0.154
#
# all_seed_kronecker_5_MSE: 1.355
# all_seed_kronecker_5_se: 0.159
#
# all_seed_kronecker_7_MSE: 1.235
# all_seed_kronecker_7_se: 0.180
#
# all_seed_kronecker_10_MSE: 2.751
# all_seed_kronecker_10_se: 0.428
#
# all_seed_kronecker_20_MSE: 1.569
# all_seed_kronecker_20_se: 0.197
#
# all_seed_kronecker_all_MSE: 1.005
# all_seed_kronecker_all_se: 0.113

# %%
backbone = 'GIN'
dataset = 'freesolv'
metric = 'MAE'

seed100_gcn = [1.1431443672480546, 1.0023387698676642, 0.9941964487391194, 1.1295008922186422, 1.0588927851378462]
seed100_egcn_r = [1.0651621330441452, 0.9492744385726809, 1.0783186484509566, 1.0893110740841843, 0.9614898721680386]
seed100_egcn_s = [1.014391516137311, 0.9304830145648145, 0.9796952525461753, 0.960646847101647, 1.1673562472103207]
seed100_egcn = [1.0653031416765348, 0.942130546870194, 0.9712132731760581, 1.0015163271445928, 0.9288118176787864]
seed100_concat_3 = [0.7681391408124308, 0.9748942157414955, 0.8698033009927104, 0.7756924366387795, 0.9283325167102668]
seed100_concat_5 = [0.7696966336468073, 0.7975652349276805, 0.7917673606572189, 0.677753178153451, 0.7754628667394623]
seed100_concat_7 = [0.6970823918740581, 0.8024220203790139, 0.8188965865007536, 0.6852095220971295, 0.7714759120504364]
seed100_concat_10 = [0.6849505131638894, 0.7731814046544353, 0.7812673613781066, 0.5804648737269124, 0.6791320438603409]
seed100_concat_20 = [0.5576565209336168, 0.7422247759000523, 0.7410851426011934, 0.6317798284095103, 0.5891530136115678]
seed100_concat_ds = [0.5320162285031296, 0.6046791452122485, 0.7195424207552211, 0.5038139313224732, 0.5743389798484686]
seed100_kronecker_3 = [0.8413140604815145, 1.051567963727816, 1.2222091794952632, 0.9879067037987896, 0.8574139453072585]
seed100_kronecker_5 = [0.7216169552540216, 0.7542537929504876, 0.8230948110265056, 0.6665744180754414, 0.8393860873375231]
seed100_kronecker_7 = [0.6517545820221188, 0.8144309276670921, 0.8132285020482821, 0.6311059035654143, 0.8358708997719161]
seed100_kronecker_10 = [1.0964447081558348, 1.2460923382616418, 1.503037159837137, 1.2622783090185932, 1.5265590270966973]
seed100_kronecker_20 = [0.9969679764875277, 1.045324716042346, 0.929429016714021, 0.8743277121716597, 0.9663958221901464]
seed100_kronecker_all = [0.6150240710401159, 0.6001960348895216, 0.7382888793945312, 0.5809910991999108, 0.5600050414791544]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GIN
# metric: MAE
# dataset: freesolv
# 5
# all_seed_GCN_MAE: 1.066
# all_seed_GCN_se: 0.031
#
# all_seed_EGCN_R_MAE: 1.029
# all_seed_EGCN_R_se: 0.030
#
# all_seed_EGCN_S_MAE: 1.011
# all_seed_EGCN_S_se: 0.042
#
# all_seed_EGCN_S_MAE: 0.982
# all_seed_EGCN_S_se: 0.024
#
# all_seed_Concat_3_MAE: 0.863
# all_seed_Concat_3_se: 0.041
#
# all_seed_Concat_5_MAE: 0.762
# all_seed_Concat_5_se: 0.022
#
# all_seed_Concat_7_MAE: 0.755
# all_seed_Concat_7_se: 0.027
#
# all_seed_Concat_10_MAE: 0.700
# all_seed_Concat_10_se: 0.037
#
# all_seed_Concat_20_MAE: 0.652
# all_seed_Concat_20_se: 0.038
#
# all_seed_Concat_ds_MAE: 0.587
# all_seed_Concat_ds_se: 0.037
#
# all_seed_kronecker_3_MAE: 0.992
# all_seed_kronecker_3_se: 0.070
#
# all_seed_kronecker_5_MAE: 0.761
# all_seed_kronecker_5_se: 0.032
#
# all_seed_kronecker_7_MAE: 0.749
# all_seed_kronecker_7_se: 0.044
#
# all_seed_kronecker_10_MAE: 1.327
# all_seed_kronecker_10_se: 0.082
#
# all_seed_kronecker_20_MAE: 0.962
# all_seed_kronecker_20_se: 0.029
#
# all_seed_kronecker_all_MAE: 0.619
# all_seed_kronecker_all_se: 0.031

# %%
backbone = 'GIN'
dataset = 'esol'
metric = 'MSE'

seed100_gcn = [1.3116167318826126, 1.0360816552241643, 0.7457661166456011, 1.1278039190504285, 1.0847734396678235]
seed100_egcn_r = [0.938070896466573, 0.8489291209206405, 0.5984255995534316, 0.9270943456225925, 1.006782470820759]
seed100_egcn_s = [0.4184670167499118, 0.6297769627306197, 0.513394431538052, 0.602693497604794, 0.6528580965974783]
seed100_egcn = [0.4152838240729438, 0.5585965789233645, 0.4509519892268711, 0.593345164987776, 0.5691670772787758]
seed100_concat_3 = [0.39383024401134914, 0.46886814289622836, 0.4649543415175544, 0.3989628365325431, 0.45689166274889975]
seed100_concat_5 = [0.35713077578279706, 0.41359127667215134, 0.4475406909858187, 0.4570678901486099, 0.3904744334157868]
seed100_concat_7 = [0.40555875725216334, 0.44152401142650183, 0.40218922342691155, 0.4668318910068936, 0.48376910276875096]
seed100_concat_10 = [0.3602170530954997, 0.46365290323893227, 0.3585383838415146, 0.4580548654951983, 0.3958034368338564]
seed100_concat_20 = [0.3966849198606279, 0.41396777669588725, 0.50495503036505, 0.4583323295911153, 0.4235036289114259]
seed100_concat_ds = [0.522553816901313, 0.4327136217456104, 0.5239322751098209, 0.4791298054324256, 0.37280655327347406]
seed100_kronecker_3 = [0.44416574835777284, 0.46597277177704705, 0.4251978691087829, 0.49269949964351123, 0.4180495308359289]
seed100_kronecker_5 = [0.683133483197954, 0.45867762155003017, 0.5802625652599251, 0.46051678988668654, 0.41734485991200687]
seed100_kronecker_7 = [0.4453340588675605, 0.470142212178972, 0.4578478816399972, 0.39634612368212807, 0.3825493079450162]
seed100_kronecker_10 = [0.4549446050326029, 0.4176501846892966, 0.43732339514626395, 0.3963324390848478, 0.36422896437707974]
seed100_kronecker_20 = [0.44072553111447227, 0.3874649206088442, 0.49719772376947935, 0.48826682590362097, 0.31535125389235663]
seed100_kronecker_all = [0.427221040725708, 0.3268698253979286, 0.4845699010127121, 0.49982860526044126, 0.3377781449960717]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GIN
# metric: MSE
# dataset: esol
# 5
# all_seed_GCN_MSE: 1.061
# all_seed_GCN_se: 0.092
#
# all_seed_EGCN_R_MSE: 0.864
# all_seed_EGCN_R_se: 0.071
#
# all_seed_EGCN_S_MSE: 0.563
# all_seed_EGCN_S_se: 0.043
#
# all_seed_EGCN_S_MSE: 0.517
# all_seed_EGCN_S_se: 0.035
#
# all_seed_Concat_3_MSE: 0.437
# all_seed_Concat_3_se: 0.017
#
# all_seed_Concat_5_MSE: 0.413
# all_seed_Concat_5_se: 0.018
#
# all_seed_Concat_7_MSE: 0.440
# all_seed_Concat_7_se: 0.016
#
# all_seed_Concat_10_MSE: 0.407
# all_seed_Concat_10_se: 0.023
#
# all_seed_Concat_20_MSE: 0.439
# all_seed_Concat_20_se: 0.019
#
# all_seed_Concat_ds_MSE: 0.466
# all_seed_Concat_ds_se: 0.029
#
# all_seed_kronecker_3_MSE: 0.449
# all_seed_kronecker_3_se: 0.014
#
# all_seed_kronecker_5_MSE: 0.520
# all_seed_kronecker_5_se: 0.049
#
# all_seed_kronecker_7_MSE: 0.430
# all_seed_kronecker_7_se: 0.017
#
# all_seed_kronecker_10_MSE: 0.414
# all_seed_kronecker_10_se: 0.016
#
# all_seed_kronecker_20_MSE: 0.426
# all_seed_kronecker_20_se: 0.034
#
# all_seed_kronecker_all_MSE: 0.415
# all_seed_kronecker_all_se: 0.036

# %%
backbone = 'GIN'
dataset = 'esol'
metric = 'MAE'

seed100_gcn = [0.7533590454525417, 0.8487564044528537, 0.7209368620978461, 0.8839770115746393, 0.7615656642661746]
seed100_egcn_r = [0.7599289883507623, 0.7267674785190158, 0.6898248714870877, 0.7234816869099935, 0.7408975924689339]
seed100_egcn_s = [0.5477960968017578, 0.606607174343533, 0.5575404442681207, 0.5835724745856391, 0.6731038387651486]
seed100_egcn = [0.5638994026184082, 0.5139468945397271, 0.5467997868855794, 0.5424372302161322, 0.5941267769767324]
seed100_concat_3 = [0.5555247969097561, 0.49624362627665203, 0.4836563014984131, 0.4967384758260515, 0.4804923072260382]
seed100_concat_5 = [0.4299747594197591, 0.4590386454264323, 0.4680681027306451, 0.43184311111768087, 0.4682144173441479]
seed100_concat_7 = [0.47524698045518665, 0.5340747239192327, 0.46034312460157606, 0.47308058460553487, 0.45226139749199284]
seed100_concat_10 = [0.46566334909862944, 0.4906360277864668, 0.4771326594882541, 0.44738698535495336, 0.4727540698870688]
seed100_concat_20 = [0.4778089065021939, 0.4390099562538995, 0.46428157912360296, 0.5021451454692417, 0.4874287854207245]
seed100_concat_ds = [0.4816585658656226, 0.4745160228676266, 0.45851988474527994, 0.47272888898849486, 0.5001426562338673]
seed100_kronecker_3 = [0.500572705798679, 0.5407717928621504, 0.5062903594970704, 0.5585592345396677, 0.4604592165757906]
seed100_kronecker_5 = [0.6836595955159929, 0.5351115916834938, 0.5974612220128377, 0.529025386704339, 0.4967353971519134]
seed100_kronecker_7 = [0.5016313513782289, 0.45813688344425624, 0.48170191711849636, 0.480339093208313, 0.45209622015511935]
seed100_kronecker_10 = [0.48592900044388243, 0.4724364287323422, 0.45547598732842337, 0.47168446289168464, 0.4988511315001265]
seed100_kronecker_20 = [0.4895635529359182, 0.4627513388792674, 0.484378686481052, 0.4669980786906348, 0.4211932003235502]
seed100_kronecker_all = [0.47012994501325817, 0.47614528470569184, 0.4886804495917426, 0.46209616985585955, 0.4219907719133184]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GIN
# metric: MAE
# dataset: esol
# 5
# all_seed_GCN_MAE: 0.794
# all_seed_GCN_se: 0.031
#
# all_seed_EGCN_R_MAE: 0.728
# all_seed_EGCN_R_se: 0.012
#
# all_seed_EGCN_S_MAE: 0.594
# all_seed_EGCN_S_se: 0.022
#
# all_seed_EGCN_S_MAE: 0.552
# all_seed_EGCN_S_se: 0.013
#
# all_seed_Concat_3_MAE: 0.503
# all_seed_Concat_3_se: 0.014
#
# all_seed_Concat_5_MAE: 0.451
# all_seed_Concat_5_se: 0.009
#
# all_seed_Concat_7_MAE: 0.479
# all_seed_Concat_7_se: 0.014
#
# all_seed_Concat_10_MAE: 0.471
# all_seed_Concat_10_se: 0.007
#
# all_seed_Concat_20_MAE: 0.474
# all_seed_Concat_20_se: 0.011
#
# all_seed_Concat_ds_MAE: 0.478
# all_seed_Concat_ds_se: 0.007
#
# all_seed_kronecker_3_MAE: 0.513
# all_seed_kronecker_3_se: 0.017
#
# all_seed_kronecker_5_MAE: 0.568
# all_seed_kronecker_5_se: 0.033
#
# all_seed_kronecker_7_MAE: 0.475
# all_seed_kronecker_7_se: 0.009
#
# all_seed_kronecker_10_MAE: 0.477
# all_seed_kronecker_10_se: 0.007
#
# all_seed_kronecker_20_MAE: 0.465
# all_seed_kronecker_20_se: 0.012
#
# all_seed_kronecker_all_MAE: 0.464
# all_seed_kronecker_all_se: 0.011

# %%
backbone = 'GIN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [2.5998888260278945, 1.6953403521806767, 1.865917743780674, 2.1547110141851964, 2.151322654260995]
seed100_egcn_r = [2.068743265592135, 1.79881345308744, 1.634693708175268, 1.795589716006548, 1.6602684971623527]
seed100_egcn_s = [0.8520114972041204, 0.7134426557100736, 0.7432702015607785, 0.8432832131019006, 0.8874968019918131]
seed100_egcn = [0.9176816084446051, 0.8008690369434845, 0.6892404678540353, 0.8793815099276029, 0.8476110220717165]
seed100_concat_3 = [0.8098645332532052, 0.5740909820947891, 0.6943879861098069, 0.7634299840682592, 0.6297787797336761]
seed100_concat_5 = [0.6847058809720553, 0.5375844331888052, 0.693980241433168, 0.8266684336540027, 0.6779350305136781]
seed100_concat_7 = [0.702921042075524, 0.5711735884348551, 0.766912790445181, 0.8238570873553936, 0.6092531490630616]
seed100_concat_10 = [0.7153351857112005, 0.5262255546374198, 0.6255468405210055, 0.5377695499322354, 0.5237338337273644]
seed100_concat_20 = [0.5502120837187155, 0.4552741111853184, 0.6968454336508726, 0.6110867231320112, 0.5080322594688342]
seed100_concat_ds = [0.6005384738628681, 0.4735625584920247, 0.6343933374453814, 0.6172318030626346, 0.5703569235512242]
seed100_kronecker_3 = [0.8315790494283041, 0.6853939447647486, 0.7100150034977839, 0.763946655469063, 0.5817040147872778]
seed100_kronecker_5 = [0.604303946861854, 0.5502155316181672, 0.6493692031273475, 0.8011695788456843, 0.5926977163686539]
seed100_kronecker_7 = [0.5718059967725705, 0.499461082311777, 0.6625203230442145, 0.5719529604300474, 0.5195208296608239]
seed100_kronecker_10 = [0.4996466820056622, 0.4387165521964049, 0.5486531563294239, 0.518353168780987, 0.48761306250819003]
seed100_kronecker_20 = [0.48544665483328014, 0.41742043617444163, 0.5258184946500338, 0.5835518164512439, 0.4034893291826827]
seed100_kronecker_all = [0.5009201612228003, 0.3957383877191788, 0.6353013270940536, 0.5270266838562794, 0.47596047252130963]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GIN
# metric: MSE
# dataset: scgas
# 5
# all_seed_GCN_MSE: 2.093
# all_seed_GCN_se: 0.154
#
# all_seed_EGCN_R_MSE: 1.792
# all_seed_EGCN_R_se: 0.077
#
# all_seed_EGCN_S_MSE: 0.808
# all_seed_EGCN_S_se: 0.034
#
# all_seed_EGCN_S_MSE: 0.827
# all_seed_EGCN_S_se: 0.039
#
# all_seed_Concat_3_MSE: 0.694
# all_seed_Concat_3_se: 0.043
#
# all_seed_Concat_5_MSE: 0.684
# all_seed_Concat_5_se: 0.046
#
# all_seed_Concat_7_MSE: 0.695
# all_seed_Concat_7_se: 0.047
#
# all_seed_Concat_10_MSE: 0.586
# all_seed_Concat_10_se: 0.037
#
# all_seed_Concat_20_MSE: 0.564
# all_seed_Concat_20_se: 0.042
#
# all_seed_Concat_ds_MSE: 0.579
# all_seed_Concat_ds_se: 0.028
#
# all_seed_kronecker_3_MSE: 0.715
# all_seed_kronecker_3_se: 0.042
#
# all_seed_kronecker_5_MSE: 0.640
# all_seed_kronecker_5_se: 0.043
#
# all_seed_kronecker_7_MSE: 0.565
# all_seed_kronecker_7_se: 0.028
#
# all_seed_kronecker_10_MSE: 0.499
# all_seed_kronecker_10_se: 0.018
#
# all_seed_kronecker_20_MSE: 0.483
# all_seed_kronecker_20_se: 0.034
#
# all_seed_kronecker_all_MSE: 0.507
# all_seed_kronecker_all_se: 0.039

# %%
backbone = 'GIN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [1.0464373735281138, 1.0414784749348958, 1.1758840756538587, 1.2496171853481195, 1.1532988136949631]
seed100_egcn_r = [0.9248431768172827, 0.9474874643179086, 0.8903911052606045, 1.0687111218770344, 0.934557454654584]
seed100_egcn_s = [0.6344207005623059, 0.6540161279531626, 0.5980863937964807, 0.660645815042349, 0.6640463149585663]
seed100_egcn = [0.6634186108907064, 0.6652385516044421, 0.6038536658653846, 0.6755542143797263, 0.6303468040003183]
seed100_concat_3 = [0.6207014597379245, 0.5525379914503831, 0.5838277156536396, 0.5752748098128881, 0.5442043767569545]
seed100_concat_5 = [0.5738028990916717, 0.5564011182540503, 0.5737869556133564, 0.573372388497377, 0.5512739431362944]
seed100_concat_7 = [0.599098584590814, 0.5531071149385892, 0.6036694110968174, 0.5672312149634728, 0.5290098830153005]
seed100_concat_10 = [0.5480382442474365, 0.5470246412815192, 0.5487574308346479, 0.5182369488936204, 0.5657787749561639]
seed100_concat_20 = [0.5744463969499637, 0.5238007215353159, 0.5405857135088016, 0.5396317579807379, 0.5280233206459508]
seed100_concat_ds = [0.5220845173566769, 0.5124594737321903, 0.5991308627984463, 0.5198520391415327, 0.48856015555774823]
seed100_kronecker_3 = [0.633822025396885, 0.6094299340859438, 0.6084292485163763, 0.6170773750696427, 0.6403874162667856]
seed100_kronecker_5 = [0.5843646587469639, 0.5591725691770896, 0.6029873811281644, 0.5482033093770345, 0.5671055583527294]
seed100_kronecker_7 = [0.5461422480069674, 0.5315715960967236, 0.5672583396618183, 0.5522684561900604, 0.5721083997537534]
seed100_kronecker_10 = [0.523185405975733, 0.5173962849837083, 0.535943716000288, 0.5331853719858023, 0.496497120720129]
seed100_kronecker_20 = [0.4794211081969432, 0.5016559943174704, 0.5166442333123623, 0.5067539398486798, 0.4776801880175313]
seed100_kronecker_all = [0.4878077262487167, 0.4718089592762483, 0.5417589407700759, 0.5336809647388947, 0.4930481042343968]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GIN
# metric: MAE
# dataset: scgas
# 5
# all_seed_GCN_MAE: 1.133
# all_seed_GCN_se: 0.040
#
# all_seed_EGCN_R_MAE: 0.953
# all_seed_EGCN_R_se: 0.030
#
# all_seed_EGCN_S_MAE: 0.642
# all_seed_EGCN_S_se: 0.012
#
# all_seed_EGCN_S_MAE: 0.648
# all_seed_EGCN_S_se: 0.013
#
# all_seed_Concat_3_MAE: 0.575
# all_seed_Concat_3_se: 0.013
#
# all_seed_Concat_5_MAE: 0.566
# all_seed_Concat_5_se: 0.005
#
# all_seed_Concat_7_MAE: 0.570
# all_seed_Concat_7_se: 0.014
#
# all_seed_Concat_10_MAE: 0.546
# all_seed_Concat_10_se: 0.008
#
# all_seed_Concat_20_MAE: 0.541
# all_seed_Concat_20_se: 0.009
#
# all_seed_Concat_ds_MAE: 0.528
# all_seed_Concat_ds_se: 0.019
#
# all_seed_kronecker_3_MAE: 0.622
# all_seed_kronecker_3_se: 0.006
#
# all_seed_kronecker_5_MAE: 0.572
# all_seed_kronecker_5_se: 0.010
#
# all_seed_kronecker_7_MAE: 0.554
# all_seed_kronecker_7_se: 0.007
#
# all_seed_kronecker_10_MAE: 0.521
# all_seed_kronecker_10_se: 0.007
#
# all_seed_kronecker_20_MAE: 0.496
# all_seed_kronecker_20_se: 0.008
#
# all_seed_kronecker_all_MAE: 0.506
# all_seed_kronecker_all_se: 0.014

# %% [markdown]
# # Scaffold - GCN

# %%
backbone = 'GCN'
dataset = 'freesolv'
metric = 'MAE'

seed100_gcn = [2.473729559715758, 1.8177448908487956, 3.7315375145445477, 2.778600769042969, 3.6848171873588784]
seed100_egcn_r = [1.7956208019721798, 1.8968299865722655, 1.7592690574879548, 3.6451516544117646, 3.011066436767578]
seed100_egcn_s = [1.2005144444907583, 2.067464065551758, 2.119019411048111, 2.611208870831658, 1.7558208193097795]
seed100_egcn = [1.1245412012425864, 1.9918418884277345, 1.8335067593321508, 2.68779338387882, 2.7887689499627974]
seed100_concat_3 = [2.36442531027445, 2.637998580932617, 2.4713995991920936, 3.48467440885656, 1.694814954485212]
seed100_concat_5 = [1.5003268544266863, 1.6989521026611327, 1.4497502786772591, 1.757942928987391, 1.1162850289117723]
seed100_concat_7 = [1.6707127733928402, 1.930531883239746, 0.9802208275211101, 1.8117132635677562, 1.1857221921284993]
seed100_concat_10 = [1.4412054899262219, 1.3486546516418456, 1.212009174483163, 1.3050823716556326, 1.0983949729374476]
seed100_concat_20 = [1.16842239659007, 1.896733856201172, 0.99251909401952, 1.10644474029541, 0.9713881129310244]
seed100_concat_ds = [1.0879636624964273, 1.8610591888427734, 1.0753411358716536, 0.9919566995957319, 0.884070600782122]
seed100_kronecker_3 = [1.8310581532920278, 3.043252944946289, 2.2764422650239906, 2.6507988873650046, 1.3957235245477586]
seed100_kronecker_5 = [1.6814730109238043, 1.8798721313476563, 1.4000102841124242, 1.3665133420158835, 1.2462627774193173]
seed100_kronecker_7 = [1.3710292025310238, 1.9589054107666015, 1.3374344280787878, 1.6429774452658261, 1.3117119017101468]
seed100_kronecker_10 = [0.8611000340159346, 1.9463964462280274, 1.4584848929424674, 1.517223694745232, 1.1427392051333474]
seed100_kronecker_20 = [0.8540213282515363, 1.6072460174560548, 1.1661716675271794, 1.2515834583955652, 0.8765241077968052]
seed100_kronecker_all = [0.9824251314488853, 1.4546483993530273, 1.1119635980956408, 0.9754616793464211, 0.7783576647440592]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: freesolv
# 5
# all_seed_GCN_MAE: 2.897
# all_seed_GCN_se: 0.366
#
# all_seed_EGCN_R_MAE: 2.422
# all_seed_EGCN_R_se: 0.384
#
# all_seed_EGCN_S_MAE: 1.951
# all_seed_EGCN_S_se: 0.232
#
# all_seed_EGCN_S_MAE: 2.085
# all_seed_EGCN_S_se: 0.304
#
# all_seed_Concat_3_MAE: 2.531
# all_seed_Concat_3_se: 0.287
#
# all_seed_Concat_5_MAE: 1.505
# all_seed_Concat_5_se: 0.113
#
# all_seed_Concat_7_MAE: 1.516
# all_seed_Concat_7_se: 0.184
#
# all_seed_Concat_10_MAE: 1.281
# all_seed_Concat_10_se: 0.059
#
# all_seed_Concat_20_MAE: 1.227
# all_seed_Concat_20_se: 0.171
#
# all_seed_Concat_ds_MAE: 1.180
# all_seed_Concat_ds_se: 0.174
#
# all_seed_kronecker_3_MAE: 2.239
# all_seed_kronecker_3_se: 0.291
#
# all_seed_kronecker_5_MAE: 1.515
# all_seed_kronecker_5_se: 0.116
#
# all_seed_kronecker_7_MAE: 1.524
# all_seed_kronecker_7_se: 0.124
#
# all_seed_kronecker_10_MAE: 1.385
# all_seed_kronecker_10_se: 0.183
#
# all_seed_kronecker_20_MAE: 1.151
# all_seed_kronecker_20_se: 0.138
#
# all_seed_kronecker_all_MAE: 1.061
# all_seed_kronecker_all_se: 0.112

# %%
backbone = 'GCN'
dataset = 'esol'
metric = 'MAE'

seed100_gcn = [2.4483474782995276, 1.7659159721212183, 1.6554409946714128, 2.5811709025020684, 1.417592625285304]
seed100_egcn_r = [1.924398176492046, 1.3437043072884542, 0.9206629753112793, 1.3494128857628773, 0.8496920781977036]
seed100_egcn_s = [0.9233894292292448, 1.1206768688402677, 0.8880204634232954, 1.0646781274827861, 0.9279500362919826]
seed100_egcn = [1.0816743412269156, 0.9479512750056752, 0.9044321406971324, 1.009449425390211, 0.7621407088111428]
seed100_concat_3 = [0.811761808604831, 0.7309235522621557, 0.6171794457869096, 0.8962314573384947, 0.6089514704311595]
seed100_concat_5 = [0.7593692315968728, 0.6503099558646219, 0.6619759299538353, 0.8366001905021021, 0.6199007782281614]
seed100_concat_7 = [0.8081241708199765, 0.6369322642945406, 0.620450327613137, 0.8241348428241277, 0.6731525215448118]
seed100_concat_10 = [0.6546475981548974, 0.7441526546812894, 0.6425218755548651, 0.7790940979779777, 0.5915772353901583]
seed100_concat_20 = [0.6450537636897924, 0.6671543790583025, 0.6393306211991744, 0.6821675704697431, 0.5850117790932748]
seed100_concat_ds = [0.7190024053369748, 0.6374656275699013, 0.6302330233834007, 0.8349683244349593, 0.6554589037801705]
seed100_kronecker_3 = [0.8754490172356847, 0.8920337777388724, 0.7071684750643643, 0.9838960453615351, 0.672365244697122]
seed100_kronecker_5 = [0.7115246366442209, 0.8624519883540639, 0.679294204711914, 0.8920508562508276, 0.6125711272744572]
seed100_kronecker_7 = [0.7820058183125486, 0.6873863789073208, 0.6411621353842996, 0.8592811519816771, 0.5730292423098695]
seed100_kronecker_10 = [0.8093368745303957, 0.7745412525377775, 0.7345768495039506, 0.7745543496083405, 0.6156870220221725]
seed100_kronecker_20 = [0.8403390574420354, 0.681385082111024, 0.6269069888375022, 0.8192600638179456, 0.651623852112714]
seed100_kronecker_all = [0.6370782698579623, 0.803651257565147, 0.6135565757751464, 0.7675857705585027, 0.5642643886453965]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: esol
# 5
# all_seed_GCN_MAE: 1.974
# all_seed_GCN_se: 0.229
#
# all_seed_EGCN_R_MAE: 1.278
# all_seed_EGCN_R_se: 0.192
#
# all_seed_EGCN_S_MAE: 0.985
# all_seed_EGCN_S_se: 0.045
#
# all_seed_EGCN_S_MAE: 0.941
# all_seed_EGCN_S_se: 0.054
#
# all_seed_Concat_3_MAE: 0.733
# all_seed_Concat_3_se: 0.056
#
# all_seed_Concat_5_MAE: 0.706
# all_seed_Concat_5_se: 0.040
#
# all_seed_Concat_7_MAE: 0.713
# all_seed_Concat_7_se: 0.043
#
# all_seed_Concat_10_MAE: 0.682
# all_seed_Concat_10_se: 0.034
#
# all_seed_Concat_20_MAE: 0.644
# all_seed_Concat_20_se: 0.017
#
# all_seed_Concat_ds_MAE: 0.695
# all_seed_Concat_ds_se: 0.038
#
# all_seed_kronecker_3_MAE: 0.826
# all_seed_kronecker_3_se: 0.059
#
# all_seed_kronecker_5_MAE: 0.752
# all_seed_kronecker_5_se: 0.054
#
# all_seed_kronecker_7_MAE: 0.709
# all_seed_kronecker_7_se: 0.051
#
# all_seed_kronecker_10_MAE: 0.742
# all_seed_kronecker_10_se: 0.034
#
# all_seed_kronecker_20_MAE: 0.724
# all_seed_kronecker_20_se: 0.044
#
# all_seed_kronecker_all_MAE: 0.677
# all_seed_kronecker_all_se: 0.046

# %%
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [2.404448089108973, 2.6085352404364226, 3.2478602660026437, 1.8257483982504439, 2.309625820850763]
seed100_egcn_r = [1.511118267654279, 1.5311298368813155, 1.8541786098371729, 1.75551761810436, 1.4660174051920574]
seed100_egcn_s = [1.113782445225147, 0.8862975266846743, 1.0472523599218861, 1.1968086609153248, 1.1631696532372715]
seed100_egcn = [0.9070655752759461, 0.8661656990066752, 1.0212661040114055, 1.0946544997036196, 1.0449680016965281]
seed100_concat_3 = [1.0730502627311496, 0.8597438183697788, 1.0186698965651997, 1.2131035150919418, 1.0065450343955942]
seed100_concat_5 = [0.7801115753453806, 0.7076145551421426, 0.9166753788450065, 0.909965548452852, 0.7936487068124369]
seed100_concat_7 = [0.697890080443216, 0.7294703516093167, 0.8647777418498971, 0.9066578561041553, 0.7608648092568326]
seed100_concat_10 = [0.7111598373553075, 0.6582520708248213, 0.7310733513078049, 0.9045893906505867, 0.717907308721218]
seed100_concat_20 = [0.6269782180086189, 0.5786194297013345, 0.6557627906842715, 0.6756633108880322, 0.6093945860051785]
seed100_concat_ds = [0.6139096951265948, 0.580228981840146, 0.6481529274898178, 0.7084319935094842, 0.6045069921584356]
seed100_kronecker_3 = [1.0180166401994337, 0.8531954025486848, 1.0721620509784513, 1.2043571305587302, 1.0482180718661978]
seed100_kronecker_5 = [0.8861766430216098, 0.7492524617678159, 1.1318014923894228, 0.9511076414949509, 0.7868127109242135]
seed100_kronecker_7 = [0.7187936415366076, 0.7339882307238393, 1.0663271134759515, 0.8181679738140523, 0.6266295569283622]
seed100_kronecker_10 = [0.6306746246617868, 0.64184421022217, 1.1865533778827482, 0.7045478654220114, 0.5677912900236999]
seed100_kronecker_20 = [0.7324975914911392, 0.8235512070841603, 0.8324182898789407, 0.6561106052981714, 0.5189854368871573]
seed100_kronecker_all = [0.6276898515333823, 0.8057564819013917, 0.7796027646807951, 0.6595323387712371, 0.48530947756605086]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: scgas
# 5
# all_seed_GCN_MAE: 2.479
# all_seed_GCN_se: 0.231
#
# all_seed_EGCN_R_MAE: 1.624
# all_seed_EGCN_R_se: 0.076
#
# all_seed_EGCN_S_MAE: 1.081
# all_seed_EGCN_S_se: 0.055
#
# all_seed_EGCN_S_MAE: 0.987
# all_seed_EGCN_S_se: 0.043
#
# all_seed_Concat_3_MAE: 1.034
# all_seed_Concat_3_se: 0.057
#
# all_seed_Concat_5_MAE: 0.822
# all_seed_Concat_5_se: 0.040
#
# all_seed_Concat_7_MAE: 0.792
# all_seed_Concat_7_se: 0.040
#
# all_seed_Concat_10_MAE: 0.745
# all_seed_Concat_10_se: 0.042
#
# all_seed_Concat_20_MAE: 0.629
# all_seed_Concat_20_se: 0.017
#
# all_seed_Concat_ds_MAE: 0.631
# all_seed_Concat_ds_se: 0.022
#
# all_seed_kronecker_3_MAE: 1.039
# all_seed_kronecker_3_se: 0.056
#
# all_seed_kronecker_5_MAE: 0.901
# all_seed_kronecker_5_se: 0.068
#
# all_seed_kronecker_7_MAE: 0.793
# all_seed_kronecker_7_se: 0.075
#
# all_seed_kronecker_10_MAE: 0.746
# all_seed_kronecker_10_se: 0.112
#
# all_seed_kronecker_20_MAE: 0.713
# all_seed_kronecker_20_se: 0.058
#
# all_seed_kronecker_all_MAE: 0.672
# all_seed_kronecker_all_se: 0.058

# %% [markdown]
# # Scaffold - GAT

# %%
split = 'scaffold'
backbone = 'GAT'
dataset = 'freesolv'
metric = 'MAE'

seed100_gcn = [2.5893692665911736, 1.8096771240234375, 3.482319770975316, 2.7673958042689732, 3.04174327299085]
seed100_egcn_r = [1.4708304288910656, 2.0713436126708986, 1.6485941166780433, 2.5619223089779126, 3.2694579987298873]
seed100_egcn_s = [1.1862137724713582, 2.0085559844970704, 1.991056996948865, 2.2460685842177446, 2.485956532614572]
seed100_egcn = [1.1303129428770484, 2.0981956481933595, 1.8711252115210708, 2.076124247382669, 3.578905468895322]
seed100_concat_3 = [2.163492319060535, 2.5875139236450195, 2.1130445879332873, 2.7397595125086167, 1.4858287175496419]
seed100_concat_5 = [1.1361715735458746, 1.6497295379638672, 1.1613472237878917, 1.3557687535005458, 1.1644085021246047]
seed100_concat_7 = [1.1602186342565024, 1.642947006225586, 0.9136715385378623, 1.4105140125050264, 0.9280863716488793]
seed100_concat_10 = [1.1207986459499453, 1.3061378479003907, 1.212293270899325, 1.457425880432129, 1.219476132165818]
seed100_concat_20 = [1.1071294342599265, 1.795231246948242, 0.9557681205321331, 1.2791139378267176, 0.9343162491208031]
seed100_concat_ds = [0.9250961629355826, 2.0689342498779295, 0.9485015942125904, 0.8117958854226505, 0.8411007381620861]
seed100_kronecker_3 = [1.645847506639434, 2.9371143341064454, 2.408071702840377, 2.5570352890912225, 1.340240092504592]
seed100_kronecker_5 = [1.2537859474740378, 1.8335346221923827, 1.3687921543510593, 1.702811544081744, 0.8138692038399833]
seed100_kronecker_7 = [1.426284743518364, 1.7863826751708984, 1.4516578937063411, 1.5421602361342486, 1.0310550190153576]
seed100_kronecker_10 = [1.015233295719798, 2.0929492950439452, 1.3650796121480513, 1.3925028183880974, 1.1719628969828289]
seed100_kronecker_20 = [0.8732890501254942, 1.5787038803100586, 1.1075192033028116, 1.1385368739857393, 0.9115313802446637]
seed100_kronecker_all = [0.7340900839828863, 1.489883804321289, 1.1394562757745081, 1.0156956336077523, 0.7666836352575392]

seed200_gcn = [2.366598967182843, 2.899653196334839, 2.736114978790283, 3.2139960635792124, 3.1915566628439382]
seed200_egcn_r = [2.8039446744051846, 1.6553185919056768, 3.5510813070803273, 4.496196878367457, 1.891962954872533]
seed200_egcn_s = [2.0936209938742896, 1.6698700448741084, 3.6234352929251537, 4.51336617305361, 1.714872259842722]
seed200_egcn = [2.7013086492365055, 1.486557276352592, 2.7746872726751834, 4.3707256974845095, 1.9523564388877468]
seed200_concat_3 = [2.0203820662064986, 2.5050700643788213, 3.4385612760271345, 3.8009135805327317, 2.0250744066740336]
seed200_concat_5 = [0.9239801233465021, 1.0220838422360627, 1.8107464050760074, 2.9297509028993804, 1.4877621500115645]
seed200_concat_7 = [1.2347781788219105, 0.9871807098388672, 1.4357029233660017, 2.345477663237473, 1.6099044398257607]
seed200_concat_10 = [0.9915369553999467, 0.9561588453209918, 1.3839837794401209, 2.30865531132139, 1.4912908453690379]
seed200_concat_20 = [0.9485958792946555, 1.1185070535411006, 1.502791823173056, 2.153796491951778, 1.127072484869706]
seed200_concat_ds = [0.745363339510831, 0.8525927274123483, 1.0649009860291774, 2.499341241244612, 1.3730840181049548]
seed200_kronecker_3 = [1.4477812680331144, 2.4735600015391475, 2.3355773847930283, 4.015765749174973, 2.3066851967259456]
seed200_kronecker_5 = [0.9647408572110263, 1.0300211699112602, 1.6674862452915737, 2.6122428630960397, 1.854736930445621]
seed200_kronecker_7 = [1.4692164334383877, 0.9994283759075663, 1.4868708162891622, 1.8713970842032597, 1.7922335172954358]
seed200_kronecker_10 = [1.0651456312699752, 0.9275100956792417, 1.2475193743803064, 1.7798543469659214, 1.4258756135639392]
seed200_kronecker_20 = [0.7531382127241655, 1.0377347365669582, 1.1023142853561714, 1.543183162294585, 0.9074548420153166]
seed200_kronecker_all =[1.0420418826016513, 1.0053292150082795, 1.0900209290640694, 1.5810700778303475, 1.4822556345086348]

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn # + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r # + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s # + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn # + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 # + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 # + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 # + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 # + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 # + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds # + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 #  + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 # + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 # + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 # + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 # + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all # + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MAE
# dataset: freesolv
# 5
# all_seed_GCN_MAE: 2.810
# all_seed_GCN_se: 0.152
#
# all_seed_EGCN_R_MAE: 2.542
# all_seed_EGCN_R_se: 0.313
#
# all_seed_EGCN_S_MAE: 2.353
# all_seed_EGCN_S_se: 0.314
#
# all_seed_EGCN_S_MAE: 2.404
# all_seed_EGCN_S_se: 0.310
#
# all_seed_Concat_3_MAE: 2.488
# all_seed_Concat_3_se: 0.221
#
# all_seed_Concat_5_MAE: 1.464
# all_seed_Concat_5_se: 0.185
#
# all_seed_Concat_7_MAE: 1.367
# all_seed_Concat_7_se: 0.138
#
# all_seed_Concat_10_MAE: 1.345
# all_seed_Concat_10_se: 0.121
#
# all_seed_Concat_20_MAE: 1.292
# all_seed_Concat_20_se: 0.129
#
# all_seed_Concat_ds_MAE: 1.213
# all_seed_Concat_ds_se: 0.190
#
# all_seed_kronecker_3_MAE: 2.347
# all_seed_kronecker_3_se: 0.247
#
# all_seed_kronecker_5_MAE: 1.510
# all_seed_kronecker_5_se: 0.170
#
# all_seed_kronecker_7_MAE: 1.486
# all_seed_kronecker_7_se: 0.093
#
# all_seed_kronecker_10_MAE: 1.348
# all_seed_kronecker_10_se: 0.113
#
# all_seed_kronecker_20_MAE: 1.095
# all_seed_kronecker_20_se: 0.087
#
# all_seed_kronecker_all_MAE: 1.135
# all_seed_kronecker_all_se: 0.093

# %%
split = 'scaffold'
backbone = 'GAT'
dataset = 'esol'
metric = 'MAE'

seed100_gcn = [2.168103063428724, 1.635488307222407, 1.5819417578833443, 2.0053035786058184, 1.3732088665629543]
seed100_egcn_r = [1.2203855723971677, 1.50399887352659, 0.9830672177401456, 1.3687953302415752, 0.9269516912161135]
seed100_egcn_s = [0.802770832447147, 0.7585934254161099, 0.7674712441184304, 0.9725537865848864, 0.7634107528948316]
seed100_egcn = [1.0605602850851168, 0.8221190770467123, 0.7979433059692382, 0.9988514205156747, 0.7029501269845402]
seed100_concat_3 = [0.8538951776038152, 0.6801746518988359, 0.6098382516340776, 0.9184729527618926, 0.6788740251578537]
seed100_concat_5 = [0.788174803749185, 0.6311457198962831, 0.6813506126403809, 0.7826160333924375, 0.577968957377415]
seed100_concat_7 = [0.7185914205771763, 0.6420913160892955, 0.6463923020796343, 0.7727106223672123, 0.6057317350424972]
seed100_concat_10 = [0.6284223335902827, 0.63066383830288, 0.6544326262040572, 0.7526599916361146, 0.6128573885150984]
seed100_concat_20 = [0.6674744255546246, 0.708740652653209, 0.6191917159340599, 0.7153925976510775, 0.5757197585760379]
seed100_concat_ds = [0.7314413791170581, 0.7101933747007135, 0.6061800913377242, 0.7993610834671279, 0.6985784114575854]
seed100_kronecker_3 = [0.8528537903837369, 0.8098497558058354, 0.6915370767766779, 0.988694126323118, 0.7236544197680903]
seed100_kronecker_5 = [0.6967378828570923, 0.6948091941967345, 0.7034504196860574, 0.8748732098078323, 0.6300848839329738]
seed100_kronecker_7 = [0.7738594918090463, 0.8128582301892733, 0.6765521569685502, 0.8312712362257101, 0.5681533439486635]
seed100_kronecker_10 = [1.0161473230945592, 0.7828212704574853, 0.5991619977084073, 0.7721574104438393, 0.6501503738702512]
seed100_kronecker_20 = [0.8331728526125192, 0.7733143588952851, 0.6779492638327859, 0.8461419444973186, 0.6326827792560353]
seed100_kronecker_all = [0.6851915021591969, 0.7219096735904091, 0.5748662385073575, 0.8111162508948374, 0.6312769347546148]

seed200_gcn = [1.4459869509837666, 1.9146227468191657, 1.4538289181472082, 1.9688035288164694, 1.5508788029352825]
seed200_egcn_r = [1.0498285059835397, 1.440850952215362, 1.1811948988172742, 1.0535447722987126, 1.3748063234458292]
seed200_egcn_s = [0.7937492412679336, 0.8395800883309883, 0.6965717898474799, 0.8148111167706942, 0.7289250255527353]
seed200_egcn = [0.8176664090624043, 0.8377394592552855, 0.6941449377271864, 0.8183537658892179, 0.744490967657333]
seed200_concat_3 = [0.7245049757115981, 0.8754423563940483, 0.6797932889726427, 0.6595920387067293, 0.5653142731888849]
seed200_concat_5 = [0.5655633070889641, 0.8869808724052027, 0.6565065224965413, 0.5404312610626221, 0.5214086600712368]
seed200_concat_7 = [0.6119701967519873, 0.7075836846702978, 0.6143608993954128, 0.5465595471231561, 0.586022020282602]
seed200_concat_10 = [0.651447569622713, 0.7079650100908781, 0.700036162800259, 0.6149529155931974, 0.5923611795095572]
seed200_concat_20 = [0.6000126062654981, 0.5969617638671607, 0.5731062703662448, 0.661005183270103, 0.5773381559472335]
seed200_concat_ds = [0.5503878418137046, 0.6136024542022169, 0.5739176538255479, 0.6554651574084633, 0.6319618045835567]
seed200_kronecker_3 = [0.7817735765494552, 0.7172229938339769, 0.7277865754233466, 0.6889577915793971, 0.7743053615541386]
seed200_kronecker_5 = [0.7147502712174958, 0.7332671316046464, 0.6835382567511664, 0.6754176365701776, 0.8696808922559696]
seed200_kronecker_7 = [0.6747935729868272, 0.729127660132291, 0.6773074467976888, 0.6493768001857557, 0.6589314202616986]
seed200_kronecker_10 = [0.6253534672307033, 0.7398819295983565, 0.6656049516465928, 0.6158339349847091, 0.6020300442114809]
seed200_kronecker_20 = [0.6275367690067665, 0.7118780822084662, 0.6733617464701335, 0.6801865602794447, 0.6415300763639292]
seed200_kronecker_all = [0.5326861259984035, 0.6442090210161711, 0.5959946261511908, 0.6489478224202206, 0.6372410067938324]

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn # + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r # + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s # + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn # + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 # + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 # + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 # + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 # + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 # + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds # + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 #  + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 # + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 # + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 # + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 # + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all # + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MAE
# dataset: esol
# 5
# all_seed_GCN_MAE: 1.710
# all_seed_GCN_se: 0.088
#
# all_seed_EGCN_R_MAE: 1.210
# all_seed_EGCN_R_se: 0.065
#
# all_seed_EGCN_S_MAE: 0.794
# all_seed_EGCN_S_se: 0.024
#
# all_seed_EGCN_S_MAE: 0.829
# all_seed_EGCN_S_se: 0.037
#
# all_seed_Concat_3_MAE: 0.725
# all_seed_Concat_3_se: 0.037
#
# all_seed_Concat_5_MAE: 0.663
# all_seed_Concat_5_se: 0.038
#
# all_seed_Concat_7_MAE: 0.645
# all_seed_Concat_7_se: 0.022
#
# all_seed_Concat_10_MAE: 0.655
# all_seed_Concat_10_se: 0.016
#
# all_seed_Concat_20_MAE: 0.629
# all_seed_Concat_20_se: 0.017
#
# all_seed_Concat_ds_MAE: 0.657
# all_seed_Concat_ds_se: 0.024
#
# all_seed_kronecker_3_MAE: 0.776
# all_seed_kronecker_3_se: 0.029
#
# all_seed_kronecker_5_MAE: 0.728
# all_seed_kronecker_5_se: 0.026
#
# all_seed_kronecker_7_MAE: 0.705
# all_seed_kronecker_7_se: 0.026
#
# all_seed_kronecker_10_MAE: 0.707
# all_seed_kronecker_10_se: 0.041
#
# all_seed_kronecker_20_MAE: 0.710
# all_seed_kronecker_20_se: 0.025
#
# all_seed_kronecker_all_MAE: 0.648
# all_seed_kronecker_all_se: 0.025

# %%
split = 'scaffold'
backbone = 'GAT'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn =
seed200_kronecker_7 = [0.8071300279471304, 0.7643257487903942, 0.6260599091995595, 1.0300303416367367, 0.8262286896401263]
seed200_kronecker_10 = [0.6521055840345084, 0.8071430627401773, 0.586497706036235, 1.0233021682370518, 0.6641280153964428]
seed200_kronecker_20 = [0.7748543796098971, 0.7083763271183162, 0.6284596864567247, 0.8026828963408125, 0.6199417925895528]
seed200_kronecker_all =[0.6771386240406431, 0.7498864632148248, 0.5749373768651208, 0.8109481183788444, 0.6458433110663231]

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn # + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r # + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s # + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn # + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 # + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 # + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 # + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 # + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 # + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds # + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 #  + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 # + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 # + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 # + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 # + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all # + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MAE
# dataset: scgas
# 5
# all_seed_GCN_MAE: 2.243
# all_seed_GCN_se: 0.142
#
# all_seed_EGCN_R_MAE: 1.817
# all_seed_EGCN_R_se: 0.104
#
# all_seed_EGCN_S_MAE: 1.058
# all_seed_EGCN_S_se: 0.037
#
# all_seed_EGCN_S_MAE: 1.040
# all_seed_EGCN_S_se: 0.038
#
# all_seed_Concat_3_MAE: 0.996
# all_seed_Concat_3_se: 0.042
#
# all_seed_Concat_5_MAE: 0.829
# all_seed_Concat_5_se: 0.025
#
# all_seed_Concat_7_MAE: 0.771
# all_seed_Concat_7_se: 0.030
#
# all_seed_Concat_10_MAE: 0.737
# all_seed_Concat_10_se: 0.030
#
# all_seed_Concat_20_MAE: 0.653
# all_seed_Concat_20_se: 0.020
#
# all_seed_Concat_ds_MAE: 0.649
# all_seed_Concat_ds_se: 0.020
#
# all_seed_kronecker_3_MAE: 1.046
# all_seed_kronecker_3_se: 0.039
#
# all_seed_kronecker_5_MAE: 0.880
# all_seed_kronecker_5_se: 0.047
#
# all_seed_kronecker_7_MAE: 0.801
# all_seed_kronecker_7_se: 0.043
#
# all_seed_kronecker_10_MAE: 0.746
# all_seed_kronecker_10_se: 0.063
#
# all_seed_kronecker_20_MAE: 0.695
# all_seed_kronecker_20_se: 0.026
#
# all_seed_kronecker_all_MAE: 0.697
# all_seed_kronecker_all_se: 0.031

# %% [markdown]
# # Scaffold - GIN

# %%
split = 'scaffold'
backbone = 'GIN'
dataset = 'freesolv'
metric = 'MAE'

seed100_gcn = [2.0078852227393615, 1.4398406346638997, 1.542142299895591, 1.6610958644321987, 2.029793612529777]
seed100_egcn_r = [1.2351462666581317, 1.7424654006958007, 1.3482348189062001, 1.9107569750617532, 1.4823473067510695]
seed100_egcn_s = [1.1674059425912253, 1.7847137451171875, 1.809037364259058, 1.9330591426176182, 1.0175847326006209]
seed100_egcn = [1.3524301808054855, 1.9665351867675782, 1.433836688800734, 1.6341220631318933, 1.417400564466204]
seed100_concat_3 = [1.0742005604069407, 2.2199113845825194, 1.513395221865907, 2.1140512242036706, 0.9228655043102446]
seed100_concat_5 = [1.0247404982404011, 1.604738998413086, 1.0368964112534815, 1.7892420376048368, 1.054545902070545]
seed100_concat_7 = [0.9062519073486328, 1.7159137725830078, 0.9553341610091073, 1.3472194896024816, 0.9628644216628301]
seed100_concat_10 = [0.6164733723896306, 1.8846189498901367, 1.0251003528127864, 1.7468426311717313, 1.1122309593927293]
seed100_concat_20 = [0.9513956977099907, 1.811161994934082, 1.1151841672099367, 1.1049679475672105, 1.0835741417748588]
seed100_concat_ds = [0.8006088442918731, 1.9276088714599608, 1.123421458565459, 1.4490060581880457, 0.7889803420929682]


# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn # + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r # + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s # + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn # + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 # + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 # + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 # + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 # + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 # + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds # + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 #  + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 # + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 # + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 # + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 # + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all # + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GIN
# metric: MAE
# dataset: freesolv
# 5
# all_seed_GCN_MAE: 1.653
# all_seed_GCN_se: 0.140
#
# all_seed_EGCN_R_MAE: 1.691
# all_seed_EGCN_R_se: 0.133
#
# all_seed_EGCN_S_MAE: 1.669
# all_seed_EGCN_S_se: 0.139
#
# all_seed_EGCN_S_MAE: 1.714
# all_seed_EGCN_S_se: 0.105
#
# all_seed_Concat_3_MAE: 1.545
# all_seed_Concat_3_se: 0.155
#
# all_seed_Concat_5_MAE: 1.352
# all_seed_Concat_5_se: 0.146
#
# all_seed_Concat_7_MAE: 1.250
# all_seed_Concat_7_se: 0.127
#
# all_seed_Concat_10_MAE: 1.338
# all_seed_Concat_10_se: 0.155
#
# all_seed_Concat_20_MAE: 1.267
# all_seed_Concat_20_se: 0.154
#
# all_seed_Concat_ds_MAE: 1.249
# all_seed_Concat_ds_se: 0.136
#
# all_seed_kronecker_3_MAE: 1.884
# all_seed_kronecker_3_se: 0.189
#
# all_seed_kronecker_5_MAE: 1.411
# all_seed_kronecker_5_se: 0.133
#
# all_seed_kronecker_7_MAE: 1.398
# all_seed_kronecker_7_se: 0.164
#
# all_seed_kronecker_10_MAE: 1.332
# all_seed_kronecker_10_se: 0.112
#
# all_seed_kronecker_20_MAE: 1.217
# all_seed_kronecker_20_se: 0.085
#
# all_seed_kronecker_all_MAE: 1.157
# all_seed_kronecker_all_se: 0.124

# %%
split = 'scaffold'
backbone = 'GIN'
dataset = 'esol'
metric = 'MAE'

seed100_gcn = [1.2571273236661344, 0.9742458221760202, 1.0547868694577898, 1.9428074099611508, 1.0300393880799759]
seed100_egcn_r = [1.7074567479235536, 0.9941700550547817, 0.8604130918329412, 1.0582616612062616, 0.7958427994858985]
seed100_egcn_s = [1.0712112130741773, 0.7276957327859443, 0.9322759454900568, 0.8621571750964149, 0.593009256849102]
seed100_egcn = [0.9247307533051923, 1.433633938170316, 0.78169415213845, 0.8124130378335209, 0.546106782614016]
seed100_concat_3 = [0.8897249269276029, 0.6222119331359863, 0.6864817142486572, 0.7178833040140443, 0.5634710344613767]
seed100_concat_5 = [0.6996540723049449, 0.5983934067843253, 0.628862901167436, 0.6390153917215639, 0.5819305532118854]
seed100_concat_7 = [0.6519804936376882, 0.7008681882891739, 0.735483420978893, 0.650006633693889, 0.497500877754361]
seed100_concat_10 = [0.869961022283462, 0.600538362536514, 0.6269191655245694, 0.601098731412726, 0.49701181580038634]
seed100_concat_20 = [0.8292707580074908, 0.6628909529301158, 0.6496122273531827, 0.7012618113372285, 0.5612903482773725]
seed100_concat_ds = [1.045282657115037, 0.6773651691905239, 0.5694499145854603, 0.9125290563551046, 0.8044405030269249]
seed100_kronecker_3 = [0.7724721121054966, 0.6438872688695004, 0.6027538993141868, 1.0617063813290353, 0.5858606450697955]
seed100_kronecker_5 = [0.7787501599045135, 0.727602389820835, 0.6685976375233044, 0.8604120319172487, 0.6256613824881759]
seed100_kronecker_7 = [0.8784608659423113, 0.6165752996478164, 0.5818193739110773, 0.7150553040585276, 0.6067716187121821]
seed100_kronecker_10 = [1.0177188806268516, 0.6732729443332606, 0.5953719485889781, 0.7739202208438162, 0.6540701272440892]
seed100_kronecker_20 = [0.9390982590168496, 0.6709170257836058, 0.6650110721588135, 0.6926637908159676, 0.656410387918061]
seed100_kronecker_all = [0.8267864545651795, 0.8023995014659145, 0.5712922529740767, 0.7346812426033666, 0.6106292874205346]

seed200_gcn = [0.808755030397509, 1.5603325235396295, 1.2259841473574566, 1.448436798587922, 0.8789038260777792]
seed200_egcn_r = [0.9282967717039818, 1.4625066497869659, 0.9743328041500515, 0.8255058213284141, 1.2918278920023065]
seed200_egcn_s = [0.6808474806009555, 0.7913291349745634, 0.6489055474599202, 0.717943693462171, 0.6875559082604888]
seed200_egcn = [0.7254787321184196, 0.8849876094282719, 0.5785012669033475, 0.6584212278064928, 0.6411179402717074]
seed200_concat_3 = [0.6567779335321164, 0.7891059883853846, 0.6259685304429796, 0.5721491826208014, 0.5762498002303275]
seed200_concat_5 = [0.6034258124875087, 0.7048682476344862, 0.582727313041687, 0.6270860245353297, 0.5498746714197603]
seed200_concat_7 = [0.8900531378446841, 0.712053192289252, 0.5736606942282783, 0.6142086606276663, 0.6289735091359991]
seed200_concat_10 = [0.6199198119780597, 0.7481116662945664, 0.5788548098670112, 0.6409556301016557, 0.5494067507578915]
seed200_concat_20 = [0.5461615008466384, 0.698736167790597, 0.6702490541670058, 0.5952486866398862, 0.5755009400217157]
seed200_concat_ds = [0.5896422851319406, 0.9445919865056088, 0.5847670820024279, 0.6372770133771395, 0.6000726222991943]
seed200_kronecker_3 = [0.7576305562374639, 0.6910422580283985, 0.6429557535383437, 0.6487703009655601, 0.8605470836610722]
seed200_kronecker_5 = [0.6638835785435695, 0.7497697252976266, 0.5878922250535753, 0.6289938123602616, 0.6933598285330865]
seed200_kronecker_7 = [0.6249828175002453, 0.7900391001450388, 0.7255062103271485, 0.5758933895512631, 0.6453512037607064]
seed200_kronecker_10 = [0.6171689734739416, 0.8191600682442648, 0.6430188761817084, 0.6884772275623522, 0.6335613243561938]
seed200_kronecker_20 = [0.6005613733740414, 0.7289489863211649, 0.6478760057025486, 0.7644761738024259, 0.7316024823296339]
seed200_kronecker_all = [0.5754669554093305, 0.7266487155044288, 0.5734646452797784, 0.6706853038386295, 0.6380510867986464]

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn # + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r # + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s # + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn # + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 # + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 # + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 # + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 # + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 # + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds # + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 #  + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 # + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 # + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 # + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 # + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all # + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GIN
# metric: MAE
# dataset: esol
# 5
# all_seed_GCN_MAE: 1.218
# all_seed_GCN_se: 0.111
#
# all_seed_EGCN_R_MAE: 1.090
# all_seed_EGCN_R_se: 0.095
#
# all_seed_EGCN_S_MAE: 0.771
# all_seed_EGCN_S_se: 0.046
#
# all_seed_EGCN_S_MAE: 0.799
# all_seed_EGCN_S_se: 0.081
#
# all_seed_Concat_3_MAE: 0.670
# all_seed_Concat_3_se: 0.033
#
# all_seed_Concat_5_MAE: 0.622
# all_seed_Concat_5_se: 0.016
#
# all_seed_Concat_7_MAE: 0.665
# all_seed_Concat_7_se: 0.033
#
# all_seed_Concat_10_MAE: 0.633
# all_seed_Concat_10_se: 0.033
#
# all_seed_Concat_20_MAE: 0.649
# all_seed_Concat_20_se: 0.027
#
# all_seed_Concat_ds_MAE: 0.737
# all_seed_Concat_ds_se: 0.056
#
# all_seed_kronecker_3_MAE: 0.727
# all_seed_kronecker_3_se: 0.046
#
# all_seed_kronecker_5_MAE: 0.698
# all_seed_kronecker_5_se: 0.026
#
# all_seed_kronecker_7_MAE: 0.676
# all_seed_kronecker_7_se: 0.031
#
# all_seed_kronecker_10_MAE: 0.712
# all_seed_kronecker_10_se: 0.041
#
# all_seed_kronecker_20_MAE: 0.710
# all_seed_kronecker_20_se: 0.030
#
# all_seed_kronecker_all_MAE: 0.673
# all_seed_kronecker_all_se: 0.030

# %%
split = 'scaffold'
backbone = 'GIN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn =
seed200_concat_20 = [0.6469565121545247, 0.7417059440117377, 0.5135092846182889, 0.9014503404378068, 0.633772667418135]
seed200_concat_ds = [0.619588687382231, 0.7568889469295353, 0.5386700519295626, 0.8325583542449565, 0.682591409886137]
seed200_kronecker_3 = [0.7413214802886852, 0.8337684235015472, 0.7087248203366302, 1.0210105119009425, 0.7826181939307679]
seed200_kronecker_5 = [0.6784023502762379, 0.8151766046301111, 0.7502355575561523, 1.1198533193151476, 0.7430558874251995]
seed200_kronecker_7 = [0.6808344723966837, 0.7860280074082412, 0.6110271631285201, 1.0202222172218034, 0.7233485120408079]
seed200_kronecker_10 = [0.6600251782997845, 0.7748266195322012, 0.6101237895876862, 1.2037100797418345, 0.7522434315782912]
seed200_kronecker_20 = [0.6984825922246403, 0.7158191978157341, 0.6037104628806891, 0.9741619470067348, 0.7109681474401596]
seed200_kronecker_all =[0.6837039173446043, 0.7422759440038111, 0.6503594642461732, 1.0440958174517843, 0.7529574779753989]

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn # + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r # + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s # + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn # + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 # + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 # + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 # + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 # + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 # + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds # + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 #  + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 # + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 # + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 # + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 # + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all # + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GIN
# metric: MAE
# dataset: scgas
# 5
# all_seed_GCN_MAE: 1.706
# all_seed_GCN_se: 0.067
#
# all_seed_EGCN_R_MAE: 1.563
# all_seed_EGCN_R_se: 0.139
#
# all_seed_EGCN_S_MAE: 0.871
# all_seed_EGCN_S_se: 0.034
#
# all_seed_EGCN_S_MAE: 0.860
# all_seed_EGCN_S_se: 0.040
#
# all_seed_Concat_3_MAE: 0.863
# all_seed_Concat_3_se: 0.082
#
# all_seed_Concat_5_MAE: 0.772
# all_seed_Concat_5_se: 0.030
#
# all_seed_Concat_7_MAE: 0.749
# all_seed_Concat_7_se: 0.029
#
# all_seed_Concat_10_MAE: 0.722
# all_seed_Concat_10_se: 0.035
#
# all_seed_Concat_20_MAE: 0.677
# all_seed_Concat_20_se: 0.039
#
# all_seed_Concat_ds_MAE: 0.677
# all_seed_Concat_ds_se: 0.032
#
# all_seed_kronecker_3_MAE: 0.830
# all_seed_kronecker_3_se: 0.037
#
# all_seed_kronecker_5_MAE: 0.857
# all_seed_kronecker_5_se: 0.071
#
# all_seed_kronecker_7_MAE: 0.774
# all_seed_kronecker_7_se: 0.054
#
# all_seed_kronecker_10_MAE: 0.774
# all_seed_kronecker_10_se: 0.063
#
# all_seed_kronecker_20_MAE: 0.726
# all_seed_kronecker_20_se: 0.040
#
# all_seed_kronecker_all_MAE: 0.732
# all_seed_kronecker_all_se: 0.051
