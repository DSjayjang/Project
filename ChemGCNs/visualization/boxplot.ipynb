# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Box plot

# %%
dataset_vp = 'logvp_cp'
dataset_vp = pd.read_csv(f'..\datasets\{dataset_vp}.csv')

dataset_solubility = 'solubility'
dataset_solubility = pd.read_csv(f'..\datasets\{dataset_solubility}.csv')

save_dir = r'..\results_figure\boxplot'

# %%
# y1 = 'logvp'
# y2 = 'solubility'

# fig = plt.figure(figsize=(6.69, 2.0))
# ax1 = fig.add_subplot(111)

# sns.boxplot(x=dataset_vp[y], color='darkgray')

# ax1.set_xlabel('')
# ax1.set_ylabel('')
# ax1.set_xticks(range(dataset_vp[y].min().astype(int), dataset_vp[y].max().astype(int)+5, 5))
# ax1.set_yticks(np.arange(0, 0.22, 0.04))
# ax1.tick_params(axis='both', labelsize=8)

# # # 저장
# # file_name = '30.pdf'
# # file_path = os.path.join(save_dir, file_name)
# # print(file_path)
# # plt.savefig(file_path, dpi=300, bbox_inches = "tight")

# plt.show()
# Out:
# ..\results_figure\boxplot\30.pdf

# %% [markdown]
# # 합치기

# %%
y1 = 'logvp'
y2 = 'solubility'

fig = plt.figure(figsize=(6.69, 5.0))

ax1 = fig.add_subplot(211)
sns.boxplot(x=dataset_vp[y1], color='darkgray')

ax1.set_xlabel('')
ax1.set_ylabel('')
ax1.set_xticks(range(dataset_vp[y1].min().astype(int), dataset_vp[y1].max().astype(int)+5, 5))
ax1.set_yticks(np.arange(0, 0.22, 0.04))
ax1.tick_params(axis='both', labelsize=8)
ax1.text(0.5, -0.35, "(a) Vapor Pressure", ha="center", va="center", transform=ax1.transAxes, fontsize=11)


ax2 = fig.add_subplot(212)
sns.boxplot(x=dataset_solubility[y2], color='darkgray')

ax2.set_xlabel('')
ax2.set_ylabel('')
ax2.set_xticks(range(dataset_solubility[y2].min().astype(int), dataset_solubility[y2].max().astype(int)+5, 5))
ax2.set_yticks(np.arange(0, 0.22, 0.05))
ax2.tick_params(axis='both', labelsize=8)
ax2.text(0.5, -0.35, "(b) Solubility", ha="center", va="center", transform=ax2.transAxes, fontsize=11)

plt.tight_layout()
plt.subplots_adjust(hspace=0.7)  # subplot 사이 간격

# # 저장
# file_name = '8.pdf'
# file_path = os.path.join(save_dir, file_name)
# print(file_path)
# plt.savefig(file_path, dpi=300, bbox_inches = "tight")

plt.show()
