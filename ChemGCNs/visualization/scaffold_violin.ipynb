# %%
from rdkit.Chem.rdFingerprintGenerator import GetMorganGenerator
from rdkit.Chem import MolFromSmiles
 
mol = 'CCCOC(=O)C'
fpg = GetMorganGenerator(radius=2, fpSize=2048)
fp_mol = fpg.GetFingerprint(MolFromSmiles(mol))

# %%
from rdkit.DataStructs import TanimotoSimilarity
 
mol_db = [
    'OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)C(O)C3O',
    'Cc1occc1C(=O)Nc2ccccc2',
    'c2ccc1scnc1c2',
    'CCC1(C(=O)NCNC1=O)c2ccccc2',
    'CC(C)CCOC(=O)C',
    'CCOc1ccc(NC(=O)C)cc1'
]
fp_db = [fpg.GetFingerprint(MolFromSmiles(m)) for m in mol_db]
 
for i in range(0, len(mol_db)):
    print(mol_db[i], TanimotoSimilarity(fp_mol, fp_db[i]))
# Out:
# OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)C(O)C3O 0.05263157894736842
# Cc1occc1C(=O)Nc2ccccc2 0.0975609756097561
# c2ccc1scnc1c2 0.0
# CCC1(C(=O)NCNC1=O)c2ccccc2 0.10256410256410256
# CC(C)CCOC(=O)C 0.5217391304347826
# CCOc1ccc(NC(=O)C)cc1 0.23529411764705882
