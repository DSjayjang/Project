# %%
import math
import numpy as np
import pandas as pd

# %%
"""
seed100_gcn = 
seed100_egcn_r = 
seed100_egcn_s = 
seed100_egcn = 
seed100_concat_3 = 
seed100_concat_5 = 
seed100_concat_7 = 
seed100_concat_10 = 
seed100_concat_20 = 
seed100_concat_ds = 
seed100_kronecker_3 = 
seed100_kronecker_5 = 
seed100_kronecker_7 = 
seed100_kronecker_10 = 
seed100_kronecker_20 = 
seed100_kronecker_all = 

seed200_gcn = 
seed200_egcn_r = 
seed200_egcn_s = 
seed200_egcn = 
seed200_concat_3 = 
seed200_concat_5 = 
seed200_concat_7 = 
seed200_concat_10 = 
seed200_concat_20 = 
seed200_concat_ds = 
seed200_kronecker_3 = 
seed200_kronecker_5 = 
seed200_kronecker_7 = 
seed200_kronecker_10 = 
seed200_kronecker_20 = 
seed200_kronecker_all =

seed300_gcn = 
seed300_egcn_r = 
seed300_egcn_s = 
seed300_egcn = 
seed300_concat_3 = 
seed300_concat_5 = 
seed300_concat_7 = 
seed300_concat_10 = 
seed300_concat_20 = 
seed300_concat_ds = 
seed300_kronecker_3 = 
seed300_kronecker_5 = 
seed300_kronecker_7 = 
seed300_kronecker_10 = 
seed300_kronecker_20 = 
seed300_kronecker_all = 
"""

# %%
backbone = 'GCN'
dataset = 'freesolv'
metric = 'MSE'

seed100_gcn = 
seed100_egcn_r = 
seed100_egcn_s = 
seed100_egcn = 
seed100_concat_3 = 
seed100_concat_5 = 
seed100_concat_7 = 
seed100_concat_10 = 
seed100_concat_20 = 
seed100_concat_ds = 
seed100_kronecker_3 = 
seed100_kronecker_5 = 
seed100_kronecker_7 = 
seed100_kronecker_10 = 
seed100_kronecker_20 = 
seed100_kronecker_all = 

seed200_gcn = 
seed200_egcn_r = 
seed200_egcn_s = 
seed200_egcn = 
seed200_concat_3 = 
seed200_concat_5 = 
seed200_concat_7 = 
seed200_concat_10 = 
seed200_concat_20 = 
seed200_concat_ds = 
seed200_kronecker_3 = 
seed200_kronecker_5 = 
seed200_kronecker_7 = 
seed200_kronecker_10 = 
seed200_kronecker_20 = 
seed200_kronecker_all =

seed300_gcn = 
seed300_egcn_r = 
seed300_egcn_s = 
seed300_egcn = 
seed300_concat_3 = 
seed300_concat_5 = 
seed300_concat_7 = 
seed300_concat_10 = 
seed300_concat_20 = 
seed300_concat_ds = 
seed300_kronecker_3 = 
seed300_kronecker_5 = 
seed300_kronecker_7 = 
seed300_kronecker_10 = 
seed300_kronecker_20 = 
seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")

# %%
backbone = 'GCN'
dataset = 'freesolv'
metric = 'MAE'

seed100_gcn = [2.473729559715758, 1.8177448908487956, 3.7315375145445477, 2.778600769042969, 3.6848171873588784]
seed100_egcn_r = [1.7956208019721798, 1.8968299865722655, 1.7592690574879548, 3.6451516544117646, 3.011066436767578]
seed100_egcn_s = [1.2005144444907583, 2.067464065551758, 2.119019411048111, 2.611208870831658, 1.7558208193097795]
seed100_egcn = [1.1245412012425864, 1.9918418884277345, 1.8335067593321508, 2.68779338387882, 2.7887689499627974]
seed100_concat_3 = [2.36442531027445, 2.637998580932617, 2.4713995991920936, 3.48467440885656, 1.694814954485212]
seed100_concat_5 = [1.5003268544266863, 1.6989521026611327, 1.4497502786772591, 1.757942928987391, 1.1162850289117723]
seed100_concat_7 = [1.6707127733928402, 1.930531883239746, 0.9802208275211101, 1.8117132635677562, 1.1857221921284993]
seed100_concat_10 = [1.4412054899262219, 1.3486546516418456, 1.212009174483163, 1.3050823716556326, 1.0983949729374476]
seed100_concat_20 = [1.16842239659007, 1.896733856201172, 0.99251909401952, 1.10644474029541, 0.9713881129310244]
seed100_concat_ds = [1.0879636624964273, 1.8610591888427734, 1.0753411358716536, 0.9919566995957319, 0.884070600782122]
seed100_kronecker_3 = [1.8310581532920278, 3.043252944946289, 2.2764422650239906, 2.6507988873650046, 1.3957235245477586]
seed100_kronecker_5 = [1.6814730109238043, 1.8798721313476563, 1.4000102841124242, 1.3665133420158835, 1.2462627774193173]
seed100_kronecker_7 = [1.3710292025310238, 1.9589054107666015, 1.3374344280787878, 1.6429774452658261, 1.3117119017101468]
seed100_kronecker_10 = [0.8611000340159346, 1.9463964462280274, 1.4584848929424674, 1.517223694745232, 1.1427392051333474]
seed100_kronecker_20 = [0.8540213282515363, 1.6072460174560548, 1.1661716675271794, 1.2515834583955652, 0.8765241077968052]
seed100_kronecker_all = [0.9824251314488853, 1.4546483993530273, 1.1119635980956408, 0.9754616793464211, 0.7783576647440592]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")

# %%
backbone = 'GCN'
dataset = 'esol'
metric = 'MSE'

seed100_gcn = 
seed100_egcn_r = 
seed100_egcn_s = 
seed100_egcn = 
seed100_concat_3 = 
seed100_concat_5 = 
seed100_concat_7 = 
seed100_concat_10 = 
seed100_concat_20 = 
seed100_concat_ds = 
seed100_kronecker_3 = 
seed100_kronecker_5 = 
seed100_kronecker_7 = 
seed100_kronecker_10 = 
seed100_kronecker_20 = 
seed100_kronecker_all = 

seed200_gcn = 
seed200_egcn_r = 
seed200_egcn_s = 
seed200_egcn = 
seed200_concat_3 = 
seed200_concat_5 = 
seed200_concat_7 = 
seed200_concat_10 = 
seed200_concat_20 = 
seed200_concat_ds = 
seed200_kronecker_3 = 
seed200_kronecker_5 = 
seed200_kronecker_7 = 
seed200_kronecker_10 = 
seed200_kronecker_20 = 
seed200_kronecker_all =

seed300_gcn = 
seed300_egcn_r = 
seed300_egcn_s = 
seed300_egcn = 
seed300_concat_3 = 
seed300_concat_5 = 
seed300_concat_7 = 
seed300_concat_10 = 
seed300_concat_20 = 
seed300_concat_ds = 
seed300_kronecker_3 = 
seed300_kronecker_5 = 
seed300_kronecker_7 = 
seed300_kronecker_10 = 
seed300_kronecker_20 = 
seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")

# %%
backbone = 'GCN'
dataset = 'esol'
metric = 'MAE'

seed100_gcn = [2.4483474782995276, 1.7659159721212183, 1.6554409946714128, 2.5811709025020684, 1.417592625285304]
seed100_egcn_r = [1.924398176492046, 1.3437043072884542, 0.9206629753112793, 1.3494128857628773, 0.8496920781977036]
seed100_egcn_s = [0.9233894292292448, 1.1206768688402677, 0.8880204634232954, 1.0646781274827861, 0.9279500362919826]
seed100_egcn = [1.0816743412269156, 0.9479512750056752, 0.9044321406971324, 1.009449425390211, 0.7621407088111428]
seed100_concat_3 = [0.811761808604831, 0.7309235522621557, 0.6171794457869096, 0.8962314573384947, 0.6089514704311595]
seed100_concat_5 = [0.7593692315968728, 0.6503099558646219, 0.6619759299538353, 0.8366001905021021, 0.6199007782281614]
seed100_concat_7 = [0.8081241708199765, 0.6369322642945406, 0.620450327613137, 0.8241348428241277, 0.6731525215448118]
seed100_concat_10 = [0.6546475981548974, 0.7441526546812894, 0.6425218755548651, 0.7790940979779777, 0.5915772353901583]
seed100_concat_20 = [0.6450537636897924, 0.6671543790583025, 0.6393306211991744, 0.6821675704697431, 0.5850117790932748]
seed100_concat_ds = [0.7190024053369748, 0.6374656275699013, 0.6302330233834007, 0.8349683244349593, 0.6554589037801705]
seed100_kronecker_3 = [0.8754490172356847, 0.8920337777388724, 0.7071684750643643, 0.9838960453615351, 0.672365244697122]
seed100_kronecker_5 = [0.7115246366442209, 0.8624519883540639, 0.679294204711914, 0.8920508562508276, 0.6125711272744572]
seed100_kronecker_7 = [0.7820058183125486, 0.6873863789073208, 0.6411621353842996, 0.8592811519816771, 0.5730292423098695]
seed100_kronecker_10 = [0.8093368745303957, 0.7745412525377775, 0.7345768495039506, 0.7745543496083405, 0.6156870220221725]
seed100_kronecker_20 = [0.8403390574420354, 0.681385082111024, 0.6269069888375022, 0.8192600638179456, 0.651623852112714]
seed100_kronecker_all = [0.6370782698579623, 0.803651257565147, 0.6135565757751464, 0.7675857705585027, 0.5642643886453965]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")

# %%
backbone = 'GCN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = 
seed100_egcn_r = 
seed100_egcn_s = 
seed100_egcn = 
seed100_concat_3 = 
seed100_concat_5 = 
seed100_concat_7 = 
seed100_concat_10 = 
seed100_concat_20 = 
seed100_concat_ds = 
seed100_kronecker_3 = 
seed100_kronecker_5 = 
seed100_kronecker_7 = 
seed100_kronecker_10 = 
seed100_kronecker_20 = 
seed100_kronecker_all = 

seed200_gcn = 
seed200_egcn_r = 
seed200_egcn_s = 
seed200_egcn = 
seed200_concat_3 = 
seed200_concat_5 = 
seed200_concat_7 = 
seed200_concat_10 = 
seed200_concat_20 = 
seed200_concat_ds = 
seed200_kronecker_3 = 
seed200_kronecker_5 = 
seed200_kronecker_7 = 
seed200_kronecker_10 = 
seed200_kronecker_20 = 
seed200_kronecker_all =

seed300_gcn = 
seed300_egcn_r = 
seed300_egcn_s = 
seed300_egcn = 
seed300_concat_3 = 
seed300_concat_5 = 
seed300_concat_7 = 
seed300_concat_10 = 
seed300_concat_20 = 
seed300_concat_ds = 
seed300_kronecker_3 = 
seed300_kronecker_5 = 
seed300_kronecker_7 = 
seed300_kronecker_10 = 
seed300_kronecker_20 = 
seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")

# %%
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [2.404448089108973, 2.6085352404364226, 3.2478602660026437, 1.8257483982504439, 2.309625820850763]
seed100_egcn_r = [1.511118267654279, 1.5311298368813155, 1.8541786098371729, 1.75551761810436, 1.4660174051920574]
seed100_egcn_s = [1.113782445225147, 0.8862975266846743, 1.0472523599218861, 1.1968086609153248, 1.1631696532372715]
seed100_egcn = [0.9070655752759461, 0.8661656990066752, 1.0212661040114055, 1.0946544997036196, 1.0449680016965281]
seed100_concat_3 = [1.0730502627311496, 0.8597438183697788, 1.0186698965651997, 1.2131035150919418, 1.0065450343955942]
seed100_concat_5 = [0.7801115753453806, 0.7076145551421426, 0.9166753788450065, 0.909965548452852, 0.7936487068124369]
seed100_concat_7 = [0.697890080443216, 0.7294703516093167, 0.8647777418498971, 0.9066578561041553, 0.7608648092568326]
seed100_concat_10 = [0.7111598373553075, 0.6582520708248213, 0.7310733513078049, 0.9045893906505867, 0.717907308721218]
seed100_concat_20 = [0.6269782180086189, 0.5786194297013345, 0.6557627906842715, 0.6756633108880322, 0.6093945860051785]
seed100_concat_ds = [0.6139096951265948, 0.580228981840146, 0.6481529274898178, 0.7084319935094842, 0.6045069921584356]
seed100_kronecker_3 = [1.0180166401994337, 0.8531954025486848, 1.0721620509784513, 1.2043571305587302, 1.0482180718661978]
seed100_kronecker_5 = [0.8861766430216098, 0.7492524617678159, 1.1318014923894228, 0.9511076414949509, 0.7868127109242135]
seed100_kronecker_7 = [0.7187936415366076, 0.7339882307238393, 1.0663271134759515, 0.8181679738140523, 0.6266295569283622]
seed100_kronecker_10 = [0.6306746246617868, 0.64184421022217, 1.1865533778827482, 0.7045478654220114, 0.5677912900236999]
seed100_kronecker_20 = [0.7324975914911392, 0.8235512070841603, 0.8324182898789407, 0.6561106052981714, 0.5189854368871573]
seed100_kronecker_all = [0.6276898515333823, 0.8057564819013917, 0.7796027646807951, 0.6595323387712371, 0.48530947756605086]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")

# %%
backbone = 'GCN'
dataset = 'solubility'
metric = 'MSE'
seed100_gcn = [3.133037467680627, 2.7311925849945045, 3.4149538915167668, 3.435189835568692, 4.280830691213565]
seed100_egcn_r = [1.9439729763545133, 2.6455501920342868, 2.280433776530814, 2.554078759926774, 2.1400592879743767]
seed100_egcn_s = [1.390228499985376, 1.4518227420751042, 1.3089858115987574, 1.6530893995161235, 1.3108332551867756]
seed100_egcn = [1.2866824335742513, 1.480086174954795, 1.334633340226843, 1.5435597972639061, 1.2501399690741735]
seed100_concat_3 = [1.1746821982689983, 1.1929049754251078, 1.1589798420033557, 1.224807890334932, 1.1208623924002743]
seed100_concat_5 = [1.2305075190031587, 1.6171490776605042, 1.1475409649788064, 1.2319954010781937, 1.218322400225709]
seed100_concat_7 = [1.168719693150576, 1.1413304455529434, 1.1933588880173704, 1.1762509319779635, 1.1176173481720173]
seed100_concat_10 = [1.0991278345295277, 1.2774573224533212, 0.9834677817973685, 1.0637202666799883, 0.9874889929563004]
seed100_concat_20 = [0.8684271433190776, 1.080396587712665, 0.7800728919658255, 0.8443972647386809, 0.8141544417829703]
seed100_concat_ds = [0.8455307971617941, 1.2933360855125646, 0.7460324713524352, 0.8084254668753008, 0.8964875328619748]
seed100_kronecker_3 = [1.163490460438657, 1.5347494580780598, 1.0290175295890647, 1.1961882437023, 1.2496936242311996]
seed100_kronecker_5 = [1.1867940207686083, 1.6647459990084021, 0.9907719226593666, 1.105385070062182, 1.2290090851436388]
seed100_kronecker_7 = [0.9527713820065515, 1.9621792985356739, 0.9849370591183926, 0.9696482038340553, 1.0184059395695364]
seed100_kronecker_10 = [0.9549034867627847, 1.2630658869428024, 0.889504168895965, 0.8745042488257615, 0.8356449051408579]
seed100_kronecker_20 = [0.7090306845361897, 0.892894787237176, 0.596793032707052, 0.5830647685740253, 0.6139364747811626]
seed100_kronecker_all = [0.6654979178988795, 0.8117195968974545, 0.5575207345029141, 0.5455797319233876, 0.6227397918701172]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")

# %%
backbone = 'GCN'
dataset = 'solubility'
metric = 'MAE'

seed100_gcn = [1.4692445310652005, 1.334299650123651, 1.4443420156211135, 1.4504349891175614, 1.6503383917950436]
seed100_egcn_r = [1.099642114115634, 1.2486843473077243, 1.1709914917641497, 1.2194423696520043, 1.1236052228914981]
seed100_egcn_s = [0.8847216385573198, 0.9407214145958875, 0.8869134923245044, 0.9413271947006713, 0.8767290557457121]
seed100_egcn = [0.8456227942036709, 0.9332812779603252, 0.9466400653757947, 0.9681742618841962, 0.9043204073874366]
seed100_concat_3 = [0.8294439839444026, 0.8586276813566776, 0.8461575203753532, 0.8391084324802109, 0.8227525546850748]
seed100_concat_5 = [0.7908789814014403, 0.8474362203414124, 0.7925456128221877, 0.8494394887792002, 0.7857151663066536]
seed100_concat_7 = [0.7808706756439463, 0.799328888262961, 0.7795918241460272, 0.7966021043632684, 0.7981057703889758]
seed100_concat_10 = [0.7809076039445976, 0.7767612817370488, 0.7468652015036725, 0.7747909663402863, 0.7592309737047612]
seed100_concat_20 = [0.6431739286654404, 0.7139318852277792, 0.6271954090037244, 0.6644396892081786, 0.6659614234570636]
seed100_concat_ds = [0.6563148435062656, 0.6828545903028231, 0.6178879534944575, 0.642009084636491, 0.6503532169670458]
seed100_kronecker_3 = [0.8385989400194013, 0.8310889658574081, 0.7524174426464324, 0.8057139179494122, 0.7855311640051027]
seed100_kronecker_5 = [0.8391986028128575, 0.8185948136477444, 0.7580652744212049, 0.816961491986601, 0.7981969441799138]
seed100_kronecker_7 = [0.7238184441742603, 0.7474569910888056, 0.6898850177196746, 0.7629695762239799, 0.7717779045862867]
seed100_kronecker_10 = [0.7173358199997075, 0.7488603201976393, 0.683881292951868, 0.720639697789359, 0.6998361878047715]
seed100_kronecker_20 = [0.5606579074447048, 0.6176933142225409, 0.5410550401565877, 0.5390521008582791, 0.566802732202391]
seed100_kronecker_all = [0.5609354282575915, 0.6393800010469332, 0.5558273944448917, 0.5419487276486438, 0.5533122637413985]

# seed200_gcn = 
# seed200_egcn_r = 
# seed200_egcn_s = 
# seed200_egcn = 
# seed200_concat_3 = 
# seed200_concat_5 = 
# seed200_concat_7 = 
# seed200_concat_10 = 
# seed200_concat_20 = 
# seed200_concat_ds = 
# seed200_kronecker_3 = 
# seed200_kronecker_5 = 
# seed200_kronecker_7 = 
# seed200_kronecker_10 = 
# seed200_kronecker_20 = 
# seed200_kronecker_all =

# seed300_gcn = 
# seed300_egcn_r = 
# seed300_egcn_s = 
# seed300_egcn = 
# seed300_concat_3 = 
# seed300_concat_5 = 
# seed300_concat_7 = 
# seed300_concat_10 = 
# seed300_concat_20 = 
# seed300_concat_ds = 
# seed300_kronecker_3 = 
# seed300_kronecker_5 = 
# seed300_kronecker_7 = 
# seed300_kronecker_10 = 
# seed300_kronecker_20 = 
# seed300_kronecker_all = 

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn # + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r # + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s # + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn # + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 # + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 # + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 # + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 # + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 # + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds # + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 # + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 # + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 # + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 # + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 # + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all # + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
