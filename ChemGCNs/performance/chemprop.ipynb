# %%
import math
import numpy as np
import pandas as pd

# %% [markdown]
# # Freesolv

# %%
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [0.5598945021629333, 0.8200034499168396, 0.6253548860549927, 1.6444346904754639, 2.5263595581054688]
seed200_gcn = [0.8748635649681091, 1.1275814771652222, 0.37481340765953064, 1.2503942251205444, 1.0977809429168701]
seed300_gcn = [0.6492854952812195, 0.8863603472709656, 0.688782274723053, 1.6205192804336548, 2.366543769836426] # 시드 바꾸기


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# 15
# all_seed_GCN_MSE: 1.273
# all_seed_GCN_se: 0.198

# %%
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# Freesolv / MSE / Scaffold / 완료
split = 'scaffold'
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [6.7037434577941895, 6.203883171081543, 5.4084014892578125, 4.351751327514648, 1.6265019178390503]
seed200_gcn = [4.618043422698975, 5.554508686065674, 3.6096227169036865, 4.194719314575195, 1.4570976495742798]
seed300_gcn = [5.918437957763672, 5.895181655883789, 4.015366554260254, 4.849441051483154, 2.288961172103882]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# 15
# all_seed_GCN_MSE: 4.446
# all_seed_GCN_se: 0.421

# %%
split = 'scaffold'
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

seed100_gcn = [1.5800844430923462, 1.917816400527954, 1.4440287351608276, 1.3957020044326782, 1.1284780502319336]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %% [markdown]
# # ESOL

# %%
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %% [markdown]
# # Vapor pressure

# %%
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %% [markdown]
# # Solubility
