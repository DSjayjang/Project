# %%
import math
import numpy as np
import pandas as pd

# %%
seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]

# %% [markdown]
# # Freesolv + feature

# %%
# 배치 32 / 에포크 10
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [ 2.665814161300659, 1.0355058908462524,  0.6608843803405762, 0.887265682220459, 1.2716933488845825]
seed200_gcn = [1.3762626647949219, 0.9718579053878784 ,  0.7457371354103088, 1.1786725521087646, 0.9257450103759766]
seed300_gcn = [1.6738982200622559, 0.8470167517662048, 0.8371084928512573, 2.0518622398376465, 0.8290976285934448]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# 15
# all_seed_GCN_MSE: 1.197
# all_seed_GCN_se: 0.143

# %%
# 배치 32 / 에포크 10
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

seed100_gcn = [0.7319229245185852,  0.7324025630950928, 0.56587815284729,  0.578476071357727, 0.5658595561981201]
seed200_gcn = [0.7370102405548096, 0.6432194113731384,  0.6423344612121582,  0.7613146901130676,  0.6049311757087708]
seed300_gcn = [0.7129506468772888, 0.5760411024093628, 0.6566039323806763,0.7056811451911926 , 0.6511023044586182]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Freesolv
# 15
# all_seed_GCN_MAE: 0.658
# all_seed_GCN_se: 0.018

# %%
# 배치 32 / 에포크 10 / scaffold
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [8.619138717651367,1.7311633825302124 ,  10.861214637756348,3.7631404399871826 ,  2.625936508178711]
seed200_gcn = [4.2132039070129395, 2.9308578968048096, 9.425050735473633, 5.2362775802612305,20.14018440246582 ]
seed300_gcn = [2.446544647216797,  4.218554496765137, 9.522444725036621,10.238044738769531 ,  3.7171521186828613]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# 15
# all_seed_GCN_MSE: 6.646
# all_seed_GCN_se: 1.263

# %%
# 배치 32 / 에포크 10 / scaffold
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

seed100_gcn = [ 1.8742611408233643, 1.0898566246032715, 2.2274725437164307 ,1.4050979614257812 ,1.206919550895691]
seed200_gcn = [ 1.655133605003357,  1.2854936122894287, 2.2764623165130615,  1.5077935457229614,  2.7441561222076416]
seed300_gcn = [ 1.1510149240493774,  1.193792462348938,  1.8217869997024536, 2.1043102741241455 ,1.244478702545166 ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Freesolv
# 15
# all_seed_GCN_MAE: 1.653
# all_seed_GCN_se: 0.130

# %% [markdown]
# # ESOL + feature

# %%
# 배치 32 / 에포크 10
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [ 0.38724157214164734, 0.39555075764656067, 0.37075671553611755, 0.2640792727470398 ,  0.32089462876319885]
seed200_gcn = [0.446478933095932, 0.49903181195259094, 0.3976195156574249,0.49684658646583557 ,0.35359054803848267 ]
seed300_gcn = [ 0.2840166985988617, 0.438874214887619 ,0.4103371202945709 ,0.3776029646396637 ,  0.3008648455142975]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# 15
# all_seed_GCN_MSE: 0.383
# all_seed_GCN_se: 0.018

# %%
# 배치 32 / 에포크 10
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [ 0.45272544026374817, 0.4590052664279938 ,0.41302433609962463 ,0.41601017117500305, 0.41161707043647766]
seed200_gcn = [0.48752760887145996, 0.5119737386703491 ,0.43627458810806274 ,0.4828718304634094 , 0.46165502071380615]
seed300_gcn = [ 0.4128566086292267, 0.5051513910293579,0.431089848279953 , 0.4432660937309265, 0.42141175270080566]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# 15
# all_seed_GCN_MAE: 0.450
# all_seed_GCN_se: 0.009

# %%
# 배치 32 / 에포크 10 / scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [ 0.583345890045166,  0.5459058880805969, 0.5958658456802368 , 0.8047780990600586 ,0.8872588872909546 ]
seed200_gcn = [ 0.8224260210990906,0.39138367772102356 ,0.6788696646690369 , 0.7572758793830872 , 0.732202410697937]
seed300_gcn = [ 0.531870424747467, 0.6187289357185364,0.5304476022720337 , 0.8350419998168945, 0.7293240427970886]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# 15
# all_seed_GCN_MSE: 0.670
# all_seed_GCN_se: 0.036

# %%
# 배치 32 / 에포크 10 / scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [ 0.6017979979515076, 0.6165086030960083, 0.6161749958992004, 0.7151690721511841 , 0.7255964875221252]
seed200_gcn = [0.6937114596366882,  0.47867003083229065,0.6371175646781921 , 0.6956833600997925 ,0.6449399590492249 ]
seed300_gcn = [0.5608095526695251, 0.6022523641586304 ,0.5755134224891663 ,0.7163538932800293 , 0.713986873626709]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# 15
# all_seed_GCN_MAE: 0.640
# all_seed_GCN_se: 0.018

# %% [markdown]
# # scgas + feature

# %%
# 배치 128 / 에포크 10
backbone = 'GCN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [0.6840794086456299, 0.5540899038314819 ,0.7980154156684875 ,0.5316919684410095, 0.553542971611023]
seed200_gcn = [ 0.6232443451881409,  0.6615094542503357, 0.6703511476516724, 0.6413643956184387 , 0.613757848739624]
seed300_gcn = [0.5973086953163147, 0.5343279242515564 ,0.5596538186073303 , 0.6205703020095825,0.6761600375175476 ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: scgas
# 15
# all_seed_GCN_MSE: 0.621
# all_seed_GCN_se: 0.018

# %%
# 배치 128 / 에포크 10
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# 배치 128 / 에포크 10 / scaffold
backbone = 'GCN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# 배치 128 / 에포크 10 / scaffold
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %% [markdown]
# # solubility + feature

# %%
# 배치 256 / 에포크 10
backbone = 'GCN'
dataset = 'solubility'
metric = 'MSE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# 배치 256 / 에포크 10
backbone = 'GCN'
dataset = 'solubility'
metric = 'MAE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# 배치 256 / 에포크 10 / scaffold
backbone = 'GCN'
dataset = 'solubility'
metric = 'MSE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# 배치 256 / 에포크 10 / scaffold
backbone = 'GCN'
dataset = 'solubility'
metric = 'MAE'

seed100_gcn = [, , , , ]
seed200_gcn = [, , , , ]
seed300_gcn = [, , , , ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %% [markdown]
# # Freesolv

# %%
# 확인 완료
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [0.5598945021629333, 0.8200034499168396, 0.6253548860549927, 1.6444346904754639, 2.5263595581054688]
seed200_gcn = [0.8748635649681091, 1.1275814771652222, 1.1258677244186401, 1.2503942251205444, 1.0977809429168701]
seed300_gcn = [0.7454223036766052, 0.6878228187561035, 0.688782274723053, 0.5315753221511841, 1.1988627910614014]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# 15
# all_seed_GCN_MSE: 1.034
# all_seed_GCN_se: 0.133

# %%
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

seed100_gcn = [0.668056309223175, 0.508363664150238, 0.4948192238807678, 0.4534640610218048, 0.611436128616333]
seed200_gcn = [0.6915085315704346, 0.6353315711021423, 0.4763774871826172, 0.7177680134773254, 0.4772416353225708]
seed300_gcn = [0.5467171669006348, 0.5190694332122803, 0.5221070051193237, 0.7124722599983215, 0.6255051493644714]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GCN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Freesolv
# 15
# all_seed_GCN_MAE: 0.577
# all_seed_GCN_se: 0.024

# %%
# Freesolv / MSE / Scaffold / 완료
split = 'scaffold'
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [6.7037434577941895, 6.203883171081543, 5.4084014892578125, 4.351751327514648, 1.6265019178390503]
seed200_gcn = [4.618043422698975, 5.554508686065674, 3.6096227169036865, 4.194719314575195, 1.4570976495742798]
seed300_gcn = [5.918437957763672, 5.895181655883789, 4.015366554260254, 4.849441051483154, 2.288961172103882]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# 15
# all_seed_GCN_MSE: 4.446
# all_seed_GCN_se: 0.421

# %%
# Freesolv / MAE / Scaffold / 완료
# split = 'scaffold'
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

# 배치가 64임 MSE랑 다름
seed100_gcn = [1.3893883228302002, 0.8937247395515442, 1.6176677942276, 1.602807164192199, 1.2282835245132446]
seed200_gcn = [1.2319602966308594, 1.526350975036621, 1.9659168720245361, 1.3012639284133911, 2.4484426975250244]
seed300_gcn = [1.136134147644043, 1.3085631132125854, 2.248101234436035, 1.0343201160430908, 1.2814899682998657]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Freesolv
# 15
# all_seed_GCN_MAE: 1.481
# all_seed_GCN_se: 0.113

# %% [markdown]
# # ESOL

# %%
# ESOL / MSE 완료 / 에포크 300 성능너무좋음 버리기
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [0.30911821126937866, 0.3147337734699249, 0.3792197108268738, 0.2487310916185379, 0.2779322564601898]
seed200_gcn = [0.3721828758716583, 0.4205831289291382, 0.3618179261684418, 0.38511088490486145, 0.40307343006134033]
seed300_gcn = [0.22386670112609863, 0.445015549659729, 0.3080071210861206, 0.4034487307071686, 0.4310876131057739]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# 15
# all_seed_GCN_MSE: 0.352
# all_seed_GCN_se: 0.018

# %%
# (재)ESOL / MSE / 에포크 50
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [0.3140261769294739, 0.24142329394817352 , 0.41878366470336914, 0.30907198786735535,0.3737832307815552]
seed200_gcn = [0.36497071385383606,0.42142733931541443 , 0.36130353808403015,0.3851487338542938 ,0.4181424081325531]
seed300_gcn = [0.2201230674982071, 0.47315534949302673, 0.2937159538269043,0.3888118863105774 ,0.3359736204147339]
		

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# 15
# all_seed_GCN_MSE: 0.355
# all_seed_GCN_se: 0.018

# %%
# ESOL / MAE 완료 / 에포크 300 성능너무좋음
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [0.3845527172088623, 0.43211719393730164, 0.4292299747467041, 0.3616536259651184, 0.3823174834251404]
seed200_gcn = [0.46651387214660645, 0.4863157570362091, 0.43750616908073425, 0.453986793756485, 0.4868374764919281]
seed300_gcn = [0.38506561517715454, 0.4673052728176117, 0.41620418429374695, 0.4271065294742584, 0.47412073612213135]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# 15
# all_seed_GCN_MAE: 0.433
# all_seed_GCN_se: 0.010

# %%
# (재)ESOL / MSE / 에포크 50
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [0.43176931142807007,0.4275954067707062 ,0.4697200059890747 , 0.36924195289611816 ,0.4374442994594574]
seed200_gcn = [0.4908858835697174,0.4761166572570801 , 0.4243316352367401,0.48883873224258423 , 0.45870593190193176]
seed300_gcn = [0.4193253517150879, 0.4265853464603424 ,0.4300234019756317 , 0.4962332248687744 ,0.3638879656791687]
		

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# 15
# all_seed_GCN_MAE: 0.441
# all_seed_GCN_se: 0.010

# %%
# 에포크 200
# scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [0.5025439858436584, 0.6202679872512817, 0.5908075571060181, 0.68485027551651, 0.6536353826522827]
seed200_gcn = [0.6513792276382446, 0.3261599540710449, 0.606860339641571, 0.8463383913040161, 0.6032155752182007]
seed300_gcn = [0.4192807674407959, 0.5509483218193054, 0.4594114422798157, 0.6392632722854614, 0.6442832946777344]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# 15
# all_seed_GCN_MSE: 0.587
# all_seed_GCN_se: 0.032

# %%
# (재)ESOL / MSE / scaffold / 에포크 100 / 확완
# scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [0.5676416754722595 ,0.6497116088867188 ,0.4737992584705353 , 0.5666655898094177 , 0.5442035794258118]
seed200_gcn = [ 0.6005363464355469 ,0.8685426712036133 , 0.5729278326034546,   0.33135026693344116,  0.6763997673988342]
seed300_gcn = [0.4660598933696747 , 0.6179285645484924,0.6928604245185852 ,  0.5578593015670776 , 0.6760516166687012 ]
		

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# 15
# all_seed_GCN_MSE: 0.591
# all_seed_GCN_se: 0.031

# %%
# 에포크 200
# scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [0.5861546397209167, 0.5767920613288879, 0.5810844302177429, 0.6622164845466614, 0.6007498502731323]
seed200_gcn = [0.6114513278007507, 0.4300832152366638, 0.6085847616195679, 0.6953691244125366, 0.5990987420082092]
seed300_gcn = [0.5167617201805115, 0.566627740859985, 0.5312094688415527, 0.7136334776878357, 0.6247853636741638]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# 15
# all_seed_GCN_MAE: 0.594
# all_seed_GCN_se: 0.018

# %%
# (재)ESOL / MSE / scaffold / 에포크 100 / 확완
# scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [ 0.5980666875839233, 0.5647973418235779 ,0.5853005647659302 , 0.6038931608200073 , 0.6752581596374512]
seed200_gcn = [ 0.5879608392715454,0.4210982024669647 ,0.6016559600830078 , 0.6974817514419556 ,0.5955716967582703 ]
seed300_gcn = [ 0.5072430372238159, 0.6204820275306702 , 0.5708974003791809 , 0.6535350680351257 , 0.619615912437439]
		

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# 15
# all_seed_GCN_MAE: 0.594
# all_seed_GCN_se: 0.017

# %% [markdown]
# # Vapor pressure

# %%
# scgas / MSE / 에포크 300 확인 완료
backbone = 'GCN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [0.47026100754737854, 0.5814273357391357, 0.7360825538635254, 0.5100933313369751, 0.5091162323951721]
seed200_gcn = [0.5480701327323914, 0.5910966992378235, 0.6766953468322754, 0.5246216654777527, 0.45329347252845764]
seed300_gcn = [0.5210620760917664, 0.40555763244628906, 0.546679675579071, 0.4324108064174652, 0.5571358799934387]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: scgas
# 15
# all_seed_GCN_MSE: 0.538
# all_seed_GCN_se: 0.022

# %%
# scgas / MAE / 에포크 300확인 완료
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [0.5031841993331909, 0.4978157579898834, 0.5059525966644287, 0.49346864223480225, 0.5255056619644165]
seed200_gcn = [0.5234864354133606, 0.488984614610672, 0.5580824017524719, 0.49086907505989075, 0.47998565435409546]
seed300_gcn = [0.4947992265224457, 0.46054747700691223, 0.5555339455604553, 0.4865967035293579, 0.48171788454055786]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: scgas
# 15
# all_seed_GCN_MAE: 0.503
# all_seed_GCN_se: 0.007

# %%
# scgas / MSE / 에포크 300 / scaffold 확인 완료
split = 'scaffold'
backbone = 'GCN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [0.9914301037788391, 0.9346104860305786, 0.902410626411438, 0.7105428576469421, 1.0706740617752075]
seed200_gcn = [0.8858079314231873, 1.1451653242111206, 1.213592290878296, 1.060626745223999, 1.0528665781021118]
seed300_gcn = [0.8951245546340942, 0.8745774626731873, 0.8524655699729919, 0.8666290044784546, 0.9876482486724854]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: scgas
# 15
# all_seed_GCN_MSE: 0.963
# all_seed_GCN_se: 0.033

# %%
# scgas / MAE / 에포크 100 / scaffold 확인완료
split = 'scaffold'
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [0.7298633456230164, 0.7208033800125122, 0.6699187755584717, 0.5867136716842651, 0.7577037811279297]
seed200_gcn = [0.7325884699821472, 0.8191017508506775, 0.7758557796478271, 0.7733885645866394, 0.7828481793403625]
seed300_gcn = [0.7332015633583069, 0.7848671674728394, 0.7242656350135803, 0.7402769923210144, 0.7275309562683105]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: scgas
# 15
# all_seed_GCN_MAE: 0.737
# all_seed_GCN_se: 0.014

# %% [markdown]
# # Solubility

# %%
# backbone = 'GCN'
# dataset = 'Solubility'
# metric = 'MSE'

# seed100_gcn = [0.4521327913, 0.51051718, 0.3670786321, 0.3992614746, 0.5548509359] # ok
# seed200_gcn = [, , , , ]
# seed300_gcn = [, , , , ]


# print(f'backbone: {backbone}')
# print(f'metric: {metric}')
# print(f'dataset: {dataset}')

# # D-MPNN
# all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
# n = len(all_seed_gcn)
# print(n)

# all_seed_gcn_avg = np.mean(all_seed_gcn)
# std_dev = np.std(all_seed_gcn, ddof = 1)
# standard_error = std_dev / math.sqrt(n)
# print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
# print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# backbone = 'GCN'
# dataset = 'Solubility'
# metric = 'MAE'

# seed100_gcn = [, , , , ]
# seed200_gcn = [, , , , ]
# seed300_gcn = [, , , , ]


# print(f'backbone: {backbone}')
# print(f'metric: {metric}')
# print(f'dataset: {dataset}')

# # D-MPNN
# all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
# n = len(all_seed_gcn)
# print(n)

# all_seed_gcn_avg = np.mean(all_seed_gcn)
# std_dev = np.std(all_seed_gcn, ddof = 1)
# standard_error = std_dev / math.sqrt(n)
# print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
# print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# %%
# solubility / MSE / scaffold 확인 완료
# epoch 100
split = 'scaffold'
backbone = 'GCN'
dataset = 'Solubility'
metric = 'MSE'

seed100_gcn = [0.477268666, 0.5455856919, 0.5522141457, 0.531443119, 0.5359806418]
seed200_gcn = [0.5555725694, 0.5852497816, 0.5258767009, 0.6449117661, 0.6507828832]
seed300_gcn = [0.5266108513, 0.6517349482, 0.5531741977, 0.6237578988, 0.5757411718]
				
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# D-MPNN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Solubility
# 15
# all_seed_GCN_MSE: 0.569
# all_seed_GCN_se: 0.014

# %%
# 확완
split = 'scaffold'
backbone = 'GCN'
dataset = 'Solubility'
metric = 'MAE'

seed100_gcn = [0.5142720342, 0.5189602375, 0.5294950604, 0.5137935281, 0.5122079849]
seed200_gcn = [0.541435957, 0.5948351026, 0.532745719, 0.5241897106, 0.5554314852]
seed300_gcn = [0.5022509098, 0.56808424, 0.5496813059, 0.5827792287, 0.5624732971]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# D-MPNN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Solubility
# 15
# all_seed_GCN_MAE: 0.540
# all_seed_GCN_se: 0.007

# %%
# (재) MSE 확인완료
backbone = 'GCN'
dataset = 'Solubility'
metric = 'MSE'

seed100_gcn = [0.5357615947723389, 0.5787810683250427,0.4237916171550751 ,0.49514979124069214 , 0.6680429577827454 ]
seed200_gcn = [0.7122572064399719, 0.52464759349823 , 0.5727351903915405, 0.5420407652854919,  0.5409132242202759]
seed300_gcn = [0.537493884563446, 0.6978483200073242 , 0.5337699055671692 ,0.8088594675064087 , 0.618057131767273 ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# D-MPNN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Solubility
# 15
# all_seed_GCN_MSE: 0.586
# all_seed_GCN_se: 0.025

# %%
# (재)
backbone = 'GCN'
dataset = 'Solubility'
metric = 'MAE'

seed100_gcn = [ 0.5315847396850586, 0.5355077981948853, 0.4736756980419159,0.5296262502670288 ,0.5634639859199524 ]
seed200_gcn = [0.54078608751297,0.5151848793029785 ,  0.5210251212120056, 0.5232585072517395 ,0.5296072363853455 ]
seed300_gcn = [ 0.5394251346588135,  0.5283176302909851, 0.5342308878898621 , 0.5474718809127808 , 0.5145962834358215]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# D-MPNN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Solubility
# 15
# all_seed_GCN_MAE: 0.529
# all_seed_GCN_se: 0.005

# %%
# (재) scaffold
backbone = 'GCN'
dataset = 'Solubility'
metric = 'MSE'

seed100_gcn = [ 0.574664831161499, 0.6502418518066406,0.6969701051712036 ,  0.6676963567733765, 0.6692602634429932]
seed200_gcn = [ 0.6669996380805969,  0.6365035176277161,0.7312427163124084 , 0.7351406216621399,0.7502323985099792 ]
seed300_gcn = [ 0.6251100897789001, 0.722477912902832 , 0.6199119091033936 ,0.7555424571037292 , 0.693212628364563 ]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# D-MPNN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Solubility
# 15
# all_seed_GCN_MSE: 0.680
# all_seed_GCN_se: 0.014

# %%
# (재) scaffold
backbone = 'GCN'
dataset = 'Solubility'
metric = 'MAE'

seed100_gcn = [ 0.5631100535392761, 0.5727800726890564,  0.5990650057792664,  0.568601429462432, 0.5718581676483154]
seed200_gcn = [0.6022798418998718,0.5677592754364014,  0.6069715619087219,0.6447541117668152 ,  0.5877099633216858]
seed300_gcn = [ 0.5478169918060303, 0.6257693767547607, 0.6044606566429138 , 0.6422341465950012 , 0.5947726964950562]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# D-MPNN
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Solubility
# 15
# all_seed_GCN_MAE: 0.593
# all_seed_GCN_se: 0.007
