# %%
import math
import numpy as np
import pandas as pd

# %%
"""
seed100_gcn = 
seed100_egcn_r = 
seed100_egcn_s = 
seed100_egcn = 
seed100_concat_3 = 
seed100_concat_5 = 
seed100_concat_7 = 
seed100_concat_10 = 
seed100_concat_20 = 
seed100_concat_ds = 
seed100_kronecker_3 = 
seed100_kronecker_5 = 
seed100_kronecker_7 = 
seed100_kronecker_10 = 
seed100_kronecker_20 = 
seed100_kronecker_all = 

seed200_gcn = 
seed200_egcn_r = 
seed200_egcn_s = 
seed200_egcn = 
seed200_concat_3 = 
seed200_concat_5 = 
seed200_concat_7 = 
seed200_concat_10 = 
seed200_concat_20 = 
seed200_concat_ds = 
seed200_kronecker_3 = 
seed200_kronecker_5 = 
seed200_kronecker_7 = 
seed200_kronecker_10 = 
seed200_kronecker_20 = 
seed200_kronecker_all = 

seed300_gcn = 
seed300_egcn_r = 
seed300_egcn_s = 
seed300_egcn = 
seed300_concat_3 = 
seed300_concat_5 = 
seed300_concat_7 = 
seed300_concat_10 = 
seed300_concat_20 = 
seed300_concat_ds = 
seed300_kronecker_3 = 
seed300_kronecker_5 = 
seed300_kronecker_7 = 
seed300_kronecker_10 = 
seed300_kronecker_20 = 
seed300_kronecker_all = 
"""
# Out:
# '\nseed100_gcn = \nseed100_egcn_r = \nseed100_egcn_s = \nseed100_egcn = \nseed100_concat_3 = \nseed100_concat_5 = \nseed100_concat_7 = \nseed100_concat_10 = \nseed100_concat_20 = \nseed100_concat_ds = \nseed100_kronecker_3 = \nseed100_kronecker_5 = \nseed100_kronecker_7 = \nseed100_kronecker_10 = \nseed100_kronecker_20 = \nseed100_kronecker_all = \n\nseed200_gcn = \nseed200_egcn_r = \nseed200_egcn_s = \nseed200_egcn = \nseed200_concat_3 = \nseed200_concat_5 = \nseed200_concat_7 = \nseed200_concat_10 = \nseed200_concat_20 = \nseed200_concat_ds = \nseed200_kronecker_3 = \nseed200_kronecker_5 = \nseed200_kronecker_7 = \nseed200_kronecker_10 = \nseed200_kronecker_20 = \nseed200_kronecker_all =\n\nseed300_gcn = \nseed300_egcn_r = \nseed300_egcn_s = \nseed300_egcn = \nseed300_concat_3 = \nseed300_concat_5 = \nseed300_concat_7 = \nseed300_concat_10 = \nseed300_concat_20 = \nseed300_concat_ds = \nseed300_kronecker_3 = \nseed300_kronecker_5 = \nseed300_kronecker_7 = \nseed300_kronecker_10 = \nseed300_kronecker_20 = \nseed300_kronecker_all = \n'

# %%
# GAT / Freesolv / MSE / 확인 완료
split = 'scaffold'
backbone = 'GAT'
dataset = 'freesolv'
metric = 'MSE'

seed100_gcn = [15.686704595038231, 5.593400319417317, 13.549517043093418, 6.103908865792411, 17.58629890397794]
seed100_egcn_r = [2.509745248934118, 7.666775512695312, 4.482172518360372, 15.621065521240235, 21.193325950985862]
seed100_egcn_s = [2.021746286531774, 7.877122497558593, 5.346980815031091, 10.164955296235926, 15.024329094659715]
seed100_egcn = [2.4025031066522367, 8.032011413574219, 5.711581736194844, 11.20898473403033, 20.23233341035389]
seed100_concat_3 = [5.44247450479647, 8.774311828613282, 6.054833626260563, 8.48932575899012, 2.778745969136556]
# 배치 64
seed300_gcn = [4.524250666300456, 26.19507344563802, 4.551684424990699, 16.126856948390152, 15.979109965891078]
seed300_egcn_r = [9.553326022240423, 11.753897666931152, 3.7574262947871766, 32.02742826021635, 27.49236286685998]
seed300_egcn_s = [9.11162345640121, 8.542583465576172, 4.64251656367861, 33.26560621995192, 35.80279516052371]
seed300_egcn = [9.268963229271673, 15.643022537231445, 4.722581534550108, 39.84711162860577, 25.600749758854967]
seed300_concat_3 = [9.964531683152721, 3.682393789291382, 5.21081858667834, 21.36535409780649, 20.543212453768053]
seed300_concat_5 = [2.4793533817414315, 1.7379963397979736, 1.8347683610587284, 13.992267315204327, 10.574671427408854]
seed300_concat_7 = [3.4311946745841735, 1.5990989208221436, 2.5173139900996766, 8.94368685208834, 6.854759731175709]
seed300_concat_10 = [3.3087310791015625, 1.3769201040267944, 2.6191811397157867, 5.316852276141827, 2.49166831112103]
seed300_concat_20 = [5.7534056632749495, 1.111339807510376, 2.3076821688948006, 3.816211407001202, 2.348351882279285]
seed300_concat_ds = [4.417560208228327, 0.785782516002655, 3.287117530559671, 16.744010338416466, 3.1356894058196336]
seed300_kronecker_3 = [10.929386261970766, 4.527909278869629, 10.452739847117456, 16.362037071814903, 8.442078385616373]
seed300_kronecker_5 = [3.489110146799395, 1.9069644212722778, 4.435341670595366, 5.5932793250450725, 3.616347611316143]
seed300_kronecker_7 = [3.114167736422631, 1.9698888063430786, 3.6960349247373383, 3.734258798452524, 4.275067194839196]
seed300_kronecker_10 = [3.3102124121881302, 1.4547123908996582, 4.084413199589171, 15.795758760892427, 4.210295601125144]
seed300_kronecker_20 = [3.6847197009671118, 0.7281807661056519, 2.3539452388368804, 3.659083733191857, 2.4615027928888678]
seed300_kronecker_all = [3.2765926238029235, 1.5159224271774292, 2.495941162109375, 7.115067115196815, 2.277248655603951]

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MSE
# dataset: freesolv
# 15
# all_seed_GCN_MSE: 13.501
# all_seed_GCN_se: 1.772
#
# all_seed_EGCN_R_MSE: 14.708
# all_seed_EGCN_R_se: 2.839
#
# all_seed_EGCN_S_MSE: 14.389
# all_seed_EGCN_S_se: 3.304
#
# all_seed_EGCN_S_MSE: 14.562
# all_seed_EGCN_S_se: 3.046
#
# all_seed_Concat_3_MSE: 10.107
# all_seed_Concat_3_se: 1.799
#
# all_seed_Concat_5_MSE: 5.062
# all_seed_Concat_5_se: 1.084
#
# all_seed_Concat_7_MSE: 3.650
# all_seed_Concat_7_se: 0.627
#
# all_seed_Concat_10_MSE: 2.992
# all_seed_Concat_10_se: 0.418
#
# all_seed_Concat_20_MSE: 3.337
# all_seed_Concat_20_se: 0.638
#
# all_seed_Concat_ds_MSE: 4.209
# all_seed_Concat_ds_se: 1.052
#
# all_seed_kronecker_3_MSE: 8.218
# all_seed_kronecker_3_se: 0.964
#
# all_seed_kronecker_5_MSE: 3.898
# all_seed_kronecker_5_se: 0.498
#
# all_seed_kronecker_7_MSE: 3.701
# all_seed_kronecker_7_se: 0.464
#
# all_seed_kronecker_10_MSE: 3.866
# all_seed_kronecker_10_se: 0.937
#
# all_seed_kronecker_20_MSE: 2.566
# all_seed_kronecker_20_se: 0.362
#
# all_seed_kronecker_all_MSE: 2.874
# all_seed_kronecker_all_se: 0.428

# %%
# GAT / Freesolv / MAE / 확인 완료
split = 'scaffold'
backbone = 'GAT'
dataset = 


print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MAE
# dataset: freesolv
# 15
# all_seed_GCN_MAE: 2.792
# all_seed_GCN_se: 0.170
#
# all_seed_EGCN_R_MAE: 2.644
# all_seed_EGCN_R_se: 0.281
#
# all_seed_EGCN_S_MAE: 2.504
# all_seed_EGCN_S_se: 0.271
#
# all_seed_EGCN_S_MAE: 2.524
# all_seed_EGCN_S_se: 0.263
#
# all_seed_Concat_3_MAE: 2.659
# all_seed_Concat_3_se: 0.217
#
# all_seed_Concat_5_MAE: 1.511
# all_seed_Concat_5_se: 0.173
#
# all_seed_Concat_7_MAE: 1.413
# all_seed_Concat_7_se: 0.111
#
# all_seed_Concat_10_MAE: 1.317
# all_seed_Concat_10_se: 0.088
#
# all_seed_Concat_20_MAE: 1.279
# all_seed_Concat_20_se: 0.091
#
# all_seed_Concat_ds_MAE: 1.277
# all_seed_Concat_ds_se: 0.183
#
# all_seed_kronecker_3_MAE: 2.448
# all_seed_kronecker_3_se: 0.196
#
# all_seed_kronecker_5_MAE: 1.509
# all_seed_kronecker_5_se: 0.117
#
# all_seed_kronecker_7_MAE: 1.542
# all_seed_kronecker_7_se: 0.157
#
# all_seed_kronecker_10_MAE: 1.516
# all_seed_kronecker_10_se: 0.231
#
# all_seed_kronecker_20_MAE: 1.074
# all_seed_kronecker_20_se: 0.065
#
# all_seed_kronecker_all_MAE: 1.211
# all_seed_kronecker_all_se: 0.117

# %%
# GAT / ESOL / MSE / 확인 완료
split = 'scaffold'
backbone = 'GAT'
dataset = 'esol'
metric = 'MSE'

seed100_gcn = [5.084571013579497, 3.485965079449593, 3.3309850011553084, 6.931949437792471, 3.8718622784281886]
seed100_egcn_r = [4.115794364739302, 3.4850805182206, 1.4454625909978693, 2.7664087586483714, 1.1418805782701456]
seed100_egcn_s = [1.0219650436110936, 1.404635747273763, 0.9393185528841885, 1.5808532520876093, 0.6980964842380262]
seed100_egcn = [1.408060657506806, 1.0276846049124735, 0.8541818098588423, 1.6032003629005562, 0.684540800458076]
seed100_concat_3 = [1.5097806603807307, 0.8611588896366588, 0.6094908280806108, 1.6045867144051245, 0.9140715131572649]
seed100_concat_5 = [1.2800746026883887, 0.9775094985961914, 0.5722408988259056, 0.8702492633108365, 0.7453635486901975]
seed100_concat_7 = [1.2360562433435487, 0.7733361009965863, 0.5114902843128551, 0.9800584760762877, 0.6420353347179937]
seed100_concat_10 = [1.0992818290632256, 0.9494900619774534, 0.62112154527144, 0.8371922444489043, 0.6720581428677428]
seed100_concat_20 = [1.7481227123545344, 0.7854796208833393, 0.6196850776672364, 0.8387667930732339, 0.8846062293239668]
seed100_concat_ds = [0.6274062655157087, 0.7870581526505319, 0.5872031298550693, 0.7405572180020608, 1.0367313039069082]
seed100_kronecker_3 = [2.5078641729508453, 1.135484636875621, 0.7272721203890714, 1.638466495578572, 0.715627530041863]
seed100_kronecker_5 = [1.2921424505476722, 1.6597914110150254, 0.6862088897011497, 1.354287648605088, 0.5732268632627001]
seed100_kronecker_7 = [1.3038347734364724, 0.9802043479785585, 0.6348581660877575, 1.389137154918606, 0.6034268584905886]
seed100_kronecker_10 = [1.859080589707739, 1.2531160722699082, 0.5983103492043235, 1.396899999198267, 0.6378822326660156]
seed100_kronecker_20 = [1.3127513567141174, 0.9108843134160627, 0.682611491463401, 1.1197490207219527, 0.7302549820320279]
seed100_kronecker_all = [0.8493839999767209, 1.0581275036460476, 0.4948592272671786, 0.9050489522643008, 0.5875771513172224]

seed300_kronecker_3 = [1.1616850586624834, 1.4015633910894394, 0.6069612780820977, 0.6416849569112313, 1.255281611580715]
seed300_kronecker_5 = [1.1318446838103973, 1.4240474104881287, 0.65907636660974, 0.7522181168991644, 0.868848468098685]
seed300_kronecker_7 = [1.0359222910425685, 1.2602067738771439, 0.6821782936170263, 0.622746705341072, 1.622623406280981]
seed300_kronecker_10 = [0.9926590361036696, 1.2249255627393723, 0.6229920340973196, 0.7076886080894149, 1.1646178971941226]
seed300_kronecker_20 = [1.2010891373093064, 1.1126237362623215, 0.6626001561729653, 0.7419345519121956, 0.9459162560578819]
seed300_kronecker_all = [0.894914283408775, 0.707902230322361, 0.4973249643751719, 0.4909266356994458, 0.7503677049529887]

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MSE
# dataset: esol
# 15
# all_seed_GCN_MSE: 4.287
# all_seed_GCN_se: 0.450
#
# all_seed_EGCN_R_MSE: 2.675
# all_seed_EGCN_R_se: 0.324
#
# all_seed_EGCN_S_MSE: 1.039
# all_seed_EGCN_S_se: 0.073
#
# all_seed_EGCN_S_MSE: 1.094
# all_seed_EGCN_S_se: 0.076
#
# all_seed_Concat_3_MSE: 1.046
# all_seed_Concat_3_se: 0.122
#
# all_seed_Concat_5_MSE: 0.882
# all_seed_Concat_5_se: 0.104
#
# all_seed_Concat_7_MSE: 0.771
# all_seed_Concat_7_se: 0.070
#
# all_seed_Concat_10_MSE: 0.886
# all_seed_Concat_10_se: 0.093
#
# all_seed_Concat_20_MSE: 0.842
# all_seed_Concat_20_se: 0.087
#
# all_seed_Concat_ds_MSE: 0.681
# all_seed_Concat_ds_se: 0.046
#
# all_seed_kronecker_3_MSE: 1.145
# all_seed_kronecker_3_se: 0.139
#
# all_seed_kronecker_5_MSE: 1.017
# all_seed_kronecker_5_se: 0.091
#
# all_seed_kronecker_7_MSE: 1.010
# all_seed_kronecker_7_se: 0.100
#
# all_seed_kronecker_10_MSE: 0.993
# all_seed_kronecker_10_se: 0.098
#
# all_seed_kronecker_20_MSE: 0.899
# all_seed_kronecker_20_se: 0.053
#
# all_seed_kronecker_all_MSE: 0.707
# all_seed_kronecker_all_se: 0.045

# %%
# GAT / ESOL / MAE / 확인 완료
split = 'scaffold'
backbone = 'GAT'
dataset = 'esol'
metric = 'MAE'

seed100_gcn = [2.168103063428724, 1.635488307222407, 1.5819417578833443, 2.0053035786058184, 1.3732088665629543]
seed100_egcn_r = [1.2203855723971677, 1.50399887352659, 0.9830672177401456, 1.3687953302415752, 0.9269516912161135]
seed100_egcn_s = [0.802770832447147, 0.7585934254161099, 0.7674712441184304, 0.9725537865848864, 0.7634107528948316]
seed100_egcn = [1.0605602850851168, 0.8221190770467123, 0.7979433059692382, 0.9988514205156747, 0.7029501269845402]
seed100_concat_3 = [0.8538951776038152, 0.6801746518988359, 0.6098382516340776, 0.9184729527618926, 0.6788740251578537]
seed100_concat_5 = [0.788174803749185, 0.6311457198962831, 0.6813506126403809, 0.7826160333924375, 0.577968957377415]
seed100_concat_7 = [0.7185914205771763, 0.6420913160892955, 0.6463923020796343, 0.7727106223672123, 0.6057317350424972]
seed100_concat_10 = [0.6284223335902827, 0.63066383830288, 0.6544326262040572, 0.7526599916361146, 0.6128573885150984]
seed300_egcn_s = [0.8907862654677382, 0.8877388536930084, 0.8679199959467916, 0.6661965406241537, 0.8119865711604324]
seed300_egcn = [0.891674162031294, 0.80900938808918, 0.9011156026599476, 0.6496801817116618, 1.0522124655892915]
seed300_concat_3 = [0.7904617206470387, 0.9349992126226425, 0.5318699438595077, 0.6505406657520797, 0.767725371868811]
seed300_concat_5 = [0.7521876773318729, 0.7370025888085365, 0.5002972871354483, 0.6334350082386776, 0.7966329472087254]
seed300_concat_7 = [0.7326409451596372, 0.7311234772205353, 0.6349466286816643, 0.5820989755689263, 0.7319736569841332]
seed300_concat_10 = [0.942379040761037, 0.7228745222091675, 0.5365533134312306, 0.5710982702025512, 0.6664432298357241]
seed300_concat_20 = [0.7282565005190738, 0.7560878694057465, 0.534805557102833, 0.5399755229469106, 0.5406810279204467]
seed300_concat_ds = [0.7082589639199747, 0.7098181545734406, 0.5372084506507059, 0.5324988398565298, 0.5814151797339181]
seed300_kronecker_3 = [0.8710514962136209, 0.9018478542566299, 0.6123544174490623, 0.6467601364734126, 0.7153272439386243]
seed300_kronecker_5 = [0.8672701517740885, 1.146620273590088, 0.571521453487063, 0.6432146231333414, 0.7077368564694841]
seed300_kronecker_7 = [0.7928047437925596, 0.9166579991579056, 0.6914944417268327, 0.6054652772363829, 0.6183010896789694]
seed300_kronecker_10 = [0.815091304950886, 1.0291926860809326, 0.5974752416888487, 0.656109566782035, 0.7500941753387451]
seed300_kronecker_20 = [0.8691742012092659, 0.7521169111132622, 0.6546354154938633, 0.6545733336974927, 0.6292853076881337]
seed300_kronecker_all = [0.7218492267368076, 0.7091566324234009, 0.5863490058380423, 0.5162203225101075, 0.6508329159745546]

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MAE
# dataset: esol
# 15
# all_seed_GCN_MAE: 1.659
# all_seed_GCN_se: 0.071
#
# all_seed_EGCN_R_MAE: 1.283
# all_seed_EGCN_R_se: 0.073
#
# all_seed_EGCN_S_MAE: 0.804
# all_seed_EGCN_S_se: 0.021
#
# all_seed_EGCN_S_MAE: 0.840
# all_seed_EGCN_S_se: 0.032
#
# all_seed_Concat_3_MAE: 0.728
# all_seed_Concat_3_se: 0.032
#
# all_seed_Concat_5_MAE: 0.670
# all_seed_Concat_5_se: 0.030
#
# all_seed_Concat_7_MAE: 0.658
# all_seed_Concat_7_se: 0.018
#
# all_seed_Concat_10_MAE: 0.666
# all_seed_Concat_10_se: 0.025
#
# all_seed_Concat_20_MAE: 0.626
# all_seed_Concat_20_se: 0.019
#
# all_seed_Concat_ds_MAE: 0.643
# all_seed_Concat_ds_se: 0.021
#
# all_seed_kronecker_3_MAE: 0.767
# all_seed_kronecker_3_se: 0.026
#
# all_seed_kronecker_5_MAE: 0.748
# all_seed_kronecker_5_se: 0.037
#
# all_seed_kronecker_7_MAE: 0.712
# all_seed_kronecker_7_se: 0.025
#
# all_seed_kronecker_10_MAE: 0.728
# all_seed_kronecker_10_se: 0.036
#
# all_seed_kronecker_20_MAE: 0.711
# all_seed_kronecker_20_se: 0.022
#
# all_seed_kronecker_all_MAE: 0.645
# all_seed_kronecker_all_se: 0.020

# %%
# GAT / scgas / MSE 확인 완료
split = 'scaffold'
backbone = 'GAT'
dataset = 
seed200_kronecker_3 = [1.239380948888285, 1.5389653986150569, 1.7795380437096884, 2.121668820002548, 1.3507856003781582]
seed200_kronecker_5 = [1.1312611372473753, 1.0579591974035485, 1.07278868209484, 2.277803289327852, 0.8876837547789229]
seed200_kronecker_7 = [1.036846258226026, 0.9412513150797261, 0.8438764394715775, 1.9203500868398933, 0.9097034210854388]
seed200_kronecker_10 = [0.7498829819596987, 1.1705514734441584, 0.7130727324374887, 1.593287718172589, 0.7492936479284408]
seed200_kronecker_20 = [0.7795084029762018, 0.906862853409408, 0.5950774148453114, 1.0808635334150976, 0.6380811650702294]
seed200_kronecker_all = [0.7065689856342673, 0.9894384532779842, 0.6987352149431095, 1.219977202157568, 0.5769391485985289]

seed300_gcn = [8.287444677108374, 10.718552729628644, 13.26373859666149, 10.790583772479364, 5.1590865905026355]
seed300_egcn_r = [7.4715325019004615, 3.2183378564619773, 5.327987363674497, 3.997794894997133, 5.577204446231618]
seed300_egcn_s = [3.1245974398721423, 1.4100603921692798, 2.1977877008834943, 2.094378690107153, 1.7925695082720587]
seed300_egcn = [3.472003502974337, 1.266223269517918, 2.0743043630715183, 1.5885298142739392, 2.0425718419692096]
seed300_concat_3 = [1.7222283778129122, 1.3268832140543898, 1.2939356861498532, 1.9740432599268922, 1.1742876838235294]
seed300_concat_5 = [1.5646002748227763, 1.2619005882428096, 1.0947972240063968, 1.070991166141055, 1.1167548684512867]
seed300_concat_7 = [1.5989251265352524, 0.9396413644697343, 0.9181241029060927, 0.8183662344556336, 1.1108651553883273]
seed300_concat_10 = [1.1948186196867214, 0.9244953107779614, 0.9206491764759858, 1.0268794068502725, 0.9785605037913603]
seed300_concat_20 = [1.2073820232646266, 0.664260846898553, 0.663935411696466, 0.8294161175369122, 0.7122572057387409]
seed300_concat_ds = [0.9269591998942153, 0.6313520872009764, 0.7139086115280254, 0.8482635218069094, 0.6660005457261029]
seed300_kronecker_3 = [2.2327834170700376, 1.3604282123101314, 1.474397902520711, 1.869531194004444, 1.3033712948069853]
seed300_kronecker_5 = [2.119192787519234, 1.1932506018802438, 0.9792445650036703, 0.8920960732556265, 1.180848424574908]
seed300_kronecker_7 = [2.8073556057034454, 1.288295437722754, 0.8134895683134962, 1.0531530817714305, 1.0065467385684743]
seed300_kronecker_10 = [1.5581895978062261, 0.8206012018440255, 0.747393819309721, 0.7170356260527164, 0.9501907348632812]
seed300_kronecker_20 = [1.0281462853846488, 0.7170662429688055, 0.7122622496329698, 0.6368333309068592, 0.6340540717629826]
seed300_kronecker_all = [1.068209067877963, 0.9209614602914578, 0.7156422762262741, 0.6710830128521, 0.5949764924890855]

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MSE
# dataset: scgas
# 15
# all_seed_GCN_MSE: 8.462
# all_seed_GCN_se: 0.715
#
# all_seed_EGCN_R_MSE: 5.359
# all_seed_EGCN_R_se: 0.433
#
# all_seed_EGCN_S_MSE: 2.000
# all_seed_EGCN_S_se: 0.124
#
# all_seed_EGCN_S_MSE: 1.898
# all_seed_EGCN_S_se: 0.151
#
# all_seed_Concat_3_MSE: 1.579
# all_seed_Concat_3_se: 0.093
#
# all_seed_Concat_5_MSE: 1.237
# all_seed_Concat_5_se: 0.082
#
# all_seed_Concat_7_MSE: 1.091
# all_seed_Concat_7_se: 0.087
#
# all_seed_Concat_10_MSE: 0.945
# all_seed_Concat_10_se: 0.052
#
# all_seed_Concat_20_MSE: 0.771
# all_seed_Concat_20_se: 0.049
#
# all_seed_Concat_ds_MSE: 0.764
# all_seed_Concat_ds_se: 0.043
#
# all_seed_kronecker_3_MSE: 1.697
# all_seed_kronecker_3_se: 0.090
#
# all_seed_kronecker_5_MSE: 1.266
# all_seed_kronecker_5_se: 0.121
#
# all_seed_kronecker_7_MSE: 1.251
# all_seed_kronecker_7_se: 0.166
#
# all_seed_kronecker_10_MSE: 0.940
# all_seed_kronecker_10_se: 0.098
#
# all_seed_kronecker_20_MSE: 0.808
# all_seed_kronecker_20_se: 0.047
#
# all_seed_kronecker_all_MSE: 0.838
# all_seed_kronecker_all_se: 0.059

# %%
# GAT / scags / MAE 확인 완료
split = 'scaffold'
backbone = 'GAT'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [1.9570384132900422, 1.9571458750757678, 2.9596878374451236, 1.8104508272722817, 2.0255356435700667]
seed100_egcn_r = [1.4713476338517775, 1.425932865947872, 2.15922825002833, 2.2110325176122405, 1.7427409165570524]
seed100_egcn_s = [0.9815213614647541, 0.9761546076118172, 1.0010691177316087, 1.223829577583413, 1.1515373956589472]
seed100_egcn = [0.9730417094099413, 0.8909415100302015, 1.0720908519757892, 1.2262936388040735, 0.9792347473352134]
seed100_concat_3 = [1.0968040326319703, 0.8090405671627491, 1.0160995196970657, 1.2475995725939888, 0.9680559327002285]
seed100_concat_5 = [0.8063000495280694, 0.7732396076251934, 0.9330925599706864, 0.9753317020866028, 0.73336513026231]
seed100_concat_7 = [0.7479261695791822, 0.659013814895184, 0.8824277428636779, 0.9478673143678357, 0.7108440464045725]
seed100_concat_10 = [0.7037000743620986, 0.6253828498450192, 0.8437072680129397, 0.933687368334641, 0.7166933332170758]
seed100_concat_20 = [0.6289374150267435, 0.6345523631998471, 0.7158757905233164, 0.6800606740093648, 0.5387071881975446]
seed100_concat_ds = [0.6014950603520105, 0.5907040372297361, 0.6692780461056376, 0.6796859674578671, 0.621092381120539]
seed100_kronecker_3 = [1.1313682696141234, 0.8742030856671271, 1.0817387160994494, 1.1752295348321506, 1.1888258019272162]
seed100_kronecker_5 = [0.8338807132265983, 0.7349767983733834, 1.0615803585117587, 0.8979279630569391, 0.7845387361487564]
seed100_kronecker_7 = [0.7266802131582838, 0.7306617947367878, 1.020322372210853, 0.8343716417337609, 0.6441285399352612]
seed100_kronecker_10 = [0.6213876391769549, 0.7014920470002409, 1.1694498029585179, 0.6604324074291246, 0.5734560700500904]
seed100_kronecker_20 = [0.5970060191023241, 0.7768760231408206, 0.7653627580072014, 0.6864197576930949, 0.5903065220839312]
seed100_kronecker_all = [0.6871826101880555, 0.7503165859680672, 0.8147637081905708, 0.7495028566585358, 0.5082811109062766]

seed200_gcn = [2.239924450309909, 1.599333220837163, 2.678976758203606, 2.4788090806258354, 2.7276963031653203]
seed200_egcn_r = [1.4594510473573483, 1.5964226908497996, 2.0286390615064045, 2.274873195775496, 1.7957026055518617]
seed300_kronecker_7 = [1.0073467759985437, 0.809441437357793, 0.6887208567369705, 0.7200419574702551, 0.7777602251838235]
seed300_kronecker_10 = [0.9168874957497206, 0.6530836276769367, 0.7201904706506921, 0.7576405936424885, 0.6457981782801011]
seed300_kronecker_20 = [0.7795892427003956, 0.6979356229779935, 0.6482273588244547, 0.6566588375546517, 0.5890252057243796]
seed300_kronecker_all = [0.9063334403535546, 0.6836875160399557, 0.6944971788649591, 0.6810659706045729, 0.6229165469898897]

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MAE
# dataset: scgas
# 15
# all_seed_GCN_MAE: 2.307
# all_seed_GCN_se: 0.115
#
# all_seed_EGCN_R_MAE: 1.811
# all_seed_EGCN_R_se: 0.077
#
# all_seed_EGCN_S_MAE: 1.050
# all_seed_EGCN_S_se: 0.027
#
# all_seed_EGCN_S_MAE: 1.051
# all_seed_EGCN_S_se: 0.032
#
# all_seed_Concat_3_MAE: 0.977
# all_seed_Concat_3_se: 0.033
#
# all_seed_Concat_5_MAE: 0.831
# all_seed_Concat_5_se: 0.018
#
# all_seed_Concat_7_MAE: 0.782
# all_seed_Concat_7_se: 0.022
#
# all_seed_Concat_10_MAE: 0.739
# all_seed_Concat_10_se: 0.021
#
# all_seed_Concat_20_MAE: 0.668
# all_seed_Concat_20_se: 0.017
#
# all_seed_Concat_ds_MAE: 0.660
# all_seed_Concat_ds_se: 0.015
#
# all_seed_kronecker_3_MAE: 1.030
# all_seed_kronecker_3_se: 0.031
#
# all_seed_kronecker_5_MAE: 0.873
# all_seed_kronecker_5_se: 0.039
#
# all_seed_kronecker_7_MAE: 0.801
# all_seed_kronecker_7_se: 0.033
#
# all_seed_kronecker_10_MAE: 0.744
# all_seed_kronecker_10_se: 0.044
#
# all_seed_kronecker_20_MAE: 0.688
# all_seed_kronecker_20_se: 0.020
#
# all_seed_kronecker_all_MAE: 0.704
# all_seed_kronecker_all_se: 0.026

# %%
# GAT / solubility / MSE 확인 완료
split = 'scaffold'
backbone = 'GAT'
dataset = 'solubility'
metric = 'MSE'

# 배치 512
seed100_gcn = [3.020313362397498, 2.497898751311451, 3.179689895916951, 2.7675346753275987, 3.9424304363438902]
seed100_egcn_r = [1.8185181578066503, 2.764035081935615, 2.3020342563061003, 2.582599837132151, 2.2094069221951314]
seed100_egcn_s = [1.3229275670107112, 1.6443094121633546, 1.250403383944897, 1.5500776670684646, 1.353833230125983]
seed100_egcn = [1.4416058329298176, 1.67264507203196, 1.2566925211155668, 1.457318900835396, 1.412784652204703]
seed100_concat_3 = [1.1385330733364314, 2.4069736871618264, 1.1776760994119848, 1.2981215540987692, 1.2220190566107136]
seed100_concat_5 = [1.0698047199979202, 1.4365747597168215, 1.1929064405725358, 1.2614670555190284, 1.1435276309385995]
seed100_concat_7 = [1.1205030241345804, 1.8526136041108796, 1.2429475987211187, 1.29686788258904, 1.1423036689000414]
seed100_concat_10 = [1.0626975771988092, 1.3856230826765403, 0.9591857423173621, 1.174208436468647, 1.0782494071303614]
seed100_concat_20 = [0.7795317740289621, 1.3539736659643566, 0.6994951329332717, 0.8353137193602173, 0.8032975733674914]
seed100_concat_ds = [0.8704999520655679, 1.0188434375529938, 0.7182616578771713, 0.8647617721977275, 0.8783324033219293]
seed300_concat_3 = [1.240496987854408, 1.1897792458301863, 1.2851164886969646, 1.188441854470838, 1.410639210928858]
seed300_concat_5 = [1.219904574968957, 1.1852664612887198, 1.277457386482763, 1.1911596355845846, 1.4796231160121682]
seed300_concat_7 = [1.1862764674306705, 1.0682719248777244, 1.2264982926026555, 1.1954710174912875, 1.5014818579749722]
seed300_concat_10 = [1.0263440668977648, 1.0100017384014166, 1.1430707269042504, 1.118456936796184, 1.1792810220633987]
seed300_concat_20 = [0.7734260811710989, 0.7740730618872838, 0.93587546312172, 0.9657910168244135, 1.0010615188463599]
seed300_concat_ds = [0.7087655781120654, 0.8268830639112298, 0.8797976570274993, 0.9684322378729696, 0.8787755240381292]
seed300_kronecker_3 = [1.3180266323468544, 1.0139184873006497, 1.1725766858981765, 1.2928624219901437, 1.3803715528640073]
seed300_kronecker_5 = [1.346217720082264, 1.2084157318167286, 1.2852621460688933, 1.2493506300159474, 1.3137866535017975]
seed300_kronecker_7 = [0.984989999935327, 1.020154641385664, 0.995323030093244, 1.3026881301119004, 1.1391924967808007]
seed300_kronecker_10 = [0.9342648133536837, 0.9004250962367067, 0.9566168657695974, 1.0225244089649925, 1.171258004787749]
seed300_kronecker_20 = [0.6066673430385968, 0.7646255880507112, 0.6202280921790436, 0.7825614649960755, 0.6030823834174502]
seed300_kronecker_all = [0.583368202866308, 0.7326460381348928, 0.6291423080531695, 0.9044759699297431, 0.6511354294498409]

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 +seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MSE
# dataset: solubility
# 15
# all_seed_GCN_MSE: 3.197
# all_seed_GCN_se: 0.146
#
# all_seed_EGCN_R_MSE: 2.437
# all_seed_EGCN_R_se: 0.103
#
# all_seed_EGCN_S_MSE: 1.458
# all_seed_EGCN_S_se: 0.039
#
# all_seed_EGCN_S_MSE: 1.509
# all_seed_EGCN_S_se: 0.047
#
# all_seed_Concat_3_MSE: 1.360
# all_seed_Concat_3_se: 0.095
#
# all_seed_Concat_5_MSE: 1.231
# all_seed_Concat_5_se: 0.030
#
# all_seed_Concat_7_MSE: 1.305
# all_seed_Concat_7_se: 0.076
#
# all_seed_Concat_10_MSE: 1.130
# all_seed_Concat_10_se: 0.041
#
# all_seed_Concat_20_MSE: 0.978
# all_seed_Concat_20_se: 0.128
#
# all_seed_Concat_ds_MSE: 0.895
# all_seed_Concat_ds_se: 0.033
#
# all_seed_kronecker_3_MSE: 1.332
# all_seed_kronecker_3_se: 0.082
#
# all_seed_kronecker_5_MSE: 1.351
# all_seed_kronecker_5_se: 0.129
#
# all_seed_kronecker_7_MSE: 1.060
# all_seed_kronecker_7_se: 0.045
#
# all_seed_kronecker_10_MSE: 0.993
# all_seed_kronecker_10_se: 0.046
#
# all_seed_kronecker_20_MSE: 0.677
# all_seed_kronecker_20_se: 0.029
#
# all_seed_kronecker_all_MSE: 0.672
# all_seed_kronecker_all_se: 0.030

# %%
# GAT / solubility / MAE 확인 완료
split = 'scaffold'
backbone = 'GAT'
dataset = 'solubility'
metric = 'MAE'

# 배치 512
seed100_gcn = [1.3341373222229158, 1.229848250306005, 1.3916750464874135, 1.3457669738336657, 1.5268371059512587]
seed200_kronecker_5 = [0.8394396778226566, 0.8067698243064915, 0.7747571116899589, 0.7249883883467344, 0.7724435711433875]
seed200_kronecker_7 = [0.8186916855456139, 0.7793843834012453, 0.7605815801329189, 0.6462891801495418, 0.7713496833686859]
seed200_kronecker_10 = [0.7056661434231059, 0.7016397289402937, 0.7192465286964123, 0.6266336744076738, 0.6947239105778599]
seed200_kronecker_20 = [0.6005322657111797, 0.6145472496560535, 0.6054426803690187, 0.506035216500826, 0.5347898945435823]
seed200_kronecker_all = [0.5819906759405773, 0.64433976796331, 0.6008397744471333, 0.5060307636439243, 0.5623316956770731]

seed300_gcn = [1.317020856736792, 1.7355356631937084, 1.4051369352293719, 1.286214732160472, 1.4529454710138874]
seed300_egcn_r = [1.313290425483754, 1.0878051339301915, 1.1784023073793368, 1.1103974925420466, 1.2013617321453263]
seed300_egcn_s = [0.9087291187008485, 0.9815924428475995, 0.9516656526172435, 0.9655904074143906, 0.9917278998720962]
seed300_egcn = [0.8553124838317467, 1.0271789074873598, 0.8964003879605359, 0.946452587542795, 0.9861191471066095]
seed300_concat_3 = [0.8323794737556912, 0.7888673413799056, 0.8415246128125955, 0.8097077128167411, 0.8334988551857198]
seed300_concat_5 = [0.8345429073106374, 0.8229265396590354, 0.9090035707895993, 0.8287308050355698, 0.8783743259126107]
seed300_concat_7 = [0.7868194175871792, 0.7769514264186688, 0.8286347425620975, 0.7881279244700511, 0.8717162545803374]
seed300_concat_10 = [0.729026804538752, 0.7207815984071579, 0.8355814100221823, 0.762110515942125, 0.778636020896709]
seed300_concat_20 = [0.626811006053394, 0.6181218245340835, 0.6830821282991016, 0.6922858773973878, 0.6986182558853015]
seed300_concat_ds = [0.6030838517953229, 0.6470933529833371, 0.6907860704960714, 0.6675485279717629, 0.6938384064530905]
seed300_kronecker_3 = [0.8266608231904491, 0.7610608978345845, 0.802271980365724, 0.8322364246777896, 0.8803305026704231]
seed300_kronecker_5 = [0.794289069775714, 0.7358224838100679, 0.8126906620637151, 0.8293014597582367, 0.8422796468819137]
seed300_kronecker_7 = [0.7397296223419392, 0.7057674070547896, 0.7488127300757488, 0.7566491963089728, 0.8338893654072179]
seed300_kronecker_10 = [0.7139769699399835, 0.6709322152081986, 0.7134196994868853, 0.74513598455899, 0.7825994575973105]
seed300_kronecker_20 = [0.5764874793046357, 0.5955407541049155, 0.5621539245124991, 0.6504897565286477, 0.5468505825616617]
seed300_kronecker_all = [0.5458026203888141, 0.5706925723287795, 0.5856447420047439, 0.6513175542686648, 0.60924383855499]

print(f'backbone: {split}')
print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: scaffold
# backbone: GAT
# metric: MAE
# dataset: solubility
# 15
# all_seed_GCN_MAE: 1.414
# all_seed_GCN_se: 0.037
#
# all_seed_EGCN_R_MAE: 1.170
# all_seed_EGCN_R_se: 0.018
#
# all_seed_EGCN_S_MAE: 0.906
# all_seed_EGCN_S_se: 0.014
#
# all_seed_EGCN_S_MAE: 0.917
# all_seed_EGCN_S_se: 0.016
#
# all_seed_Concat_3_MAE: 0.814
# all_seed_Concat_3_se: 0.008
#
# all_seed_Concat_5_MAE: 0.819
# all_seed_Concat_5_se: 0.012
#
# all_seed_Concat_7_MAE: 0.803
# all_seed_Concat_7_se: 0.010
#
# all_seed_Concat_10_MAE: 0.762
# all_seed_Concat_10_se: 0.011
#
# all_seed_Concat_20_MAE: 0.666
# all_seed_Concat_20_se: 0.012
#
# all_seed_Concat_ds_MAE: 0.673
# all_seed_Concat_ds_se: 0.011
#
# all_seed_kronecker_3_MAE: 0.822
# all_seed_kronecker_3_se: 0.013
#
# all_seed_kronecker_5_MAE: 0.796
# all_seed_kronecker_5_se: 0.010
#
# all_seed_kronecker_7_MAE: 0.750
# all_seed_kronecker_7_se: 0.013
#
# all_seed_kronecker_10_MAE: 0.705
# all_seed_kronecker_10_se: 0.010
#
# all_seed_kronecker_20_MAE: 0.575
# all_seed_kronecker_20_se: 0.011
#
# all_seed_kronecker_all_MAE: 0.580
# all_seed_kronecker_all_se: 0.011
