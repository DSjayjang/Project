# %%
import math
import numpy as np
import pandas as pd

# %%
"""
seed100_gcn = 
seed100_egcn_r = 
seed100_egcn_s = 
seed100_egcn = 
seed100_concat_3 = 
seed100_concat_5 = 
seed100_concat_7 = 
seed100_concat_10 = 
seed100_concat_20 = 
seed100_concat_ds = 
seed100_kronecker_3 = 
seed100_kronecker_5 = 
seed100_kronecker_7 = 
seed100_kronecker_10 = 
seed100_kronecker_20 = 
seed100_kronecker_all = 

seed200_gcn = 
seed200_egcn_r = 
seed200_egcn_s = 
seed200_egcn = 
seed200_concat_3 = 
seed200_concat_5 = 
seed200_concat_7 = 
seed200_concat_10 = 
seed200_concat_20 = 
seed200_concat_ds = 
seed200_kronecker_3 = 
seed200_kronecker_5 = 
seed200_kronecker_7 = 
seed200_kronecker_10 = 
seed200_kronecker_20 = 
seed200_kronecker_all = 

seed300_gcn = 
seed300_egcn_r = 
seed300_egcn_s = 
seed300_egcn = 
seed300_concat_3 = 
seed300_concat_5 = 
seed300_concat_7 = 
seed300_concat_10 = 
seed300_concat_20 = 
seed300_concat_ds = 
seed300_kronecker_3 = 
seed300_kronecker_5 = 
seed300_kronecker_7 = 
seed300_kronecker_10 = 
seed300_kronecker_20 = 
seed300_kronecker_all = 
"""
# Out:
# '\nseed100_gcn = \nseed100_egcn_r = \nseed100_egcn_s = \nseed100_egcn = \nseed100_concat_3 = \nseed100_concat_5 = \nseed100_concat_7 = \nseed100_concat_10 = \nseed100_concat_20 = \nseed100_concat_ds = \nseed100_kronecker_3 = \nseed100_kronecker_5 = \nseed100_kronecker_7 = \nseed100_kronecker_10 = \nseed100_kronecker_20 = \nseed100_kronecker_all = \n\nseed200_gcn = \nseed200_egcn_r = \nseed200_egcn_s = \nseed200_egcn = \nseed200_concat_3 = \nseed200_concat_5 = \nseed200_concat_7 = \nseed200_concat_10 = \nseed200_concat_20 = \nseed200_concat_ds = \nseed200_kronecker_3 = \nseed200_kronecker_5 = \nseed200_kronecker_7 = \nseed200_kronecker_10 = \nseed200_kronecker_20 = \nseed200_kronecker_all = \n\nseed300_gcn = \nseed300_egcn_r = \nseed300_egcn_s = \nseed300_egcn = \nseed300_concat_3 = \nseed300_concat_5 = \nseed300_concat_7 = \nseed300_concat_10 = \nseed300_concat_20 = \nseed300_concat_ds = \nseed300_kronecker_3 = \nseed300_kronecker_5 = \nseed300_kronecker_7 = \nseed300_kronecker_10 = \nseed300_kronecker_20 = \nseed300_kronecker_all = \n'

# %%
# GAT / Freesolv / MSE / 확인 완료
backbone = 'GAT'
dataset = 'freesolv'
metric = 'MSE'

seed100_gcn = [6.962656696950357, 7.425777164969857, 4.871581250288355, 6.658351327490619, 4.60243169769986]
seed100_egcn_r = [6.191213772991511, 4.7889779158464565, 3.919316749873124, 6.319493091012549, 3.482653596019017]
seed100_egcn_s = [5.2431913360835996, 5.260970829040047, 4.217202734759473, 5.362135158749077, 3.45912181694089]
seed100_egcn = [6.292416429895115, 4.346340629998155, 3.679638359490342, 5.251160809374231, 2.8653227063535733]
seed200_kronecker_10 = [1.227435795340951, 0.7784920940248985, 1.0934662556085062, 1.1599735199935792, 1.3649311174873178]
seed200_kronecker_20 = [1.6996670970766563, 1.0220962584488036, 1.00511982684999, 0.9221488472044937, 1.0034614228110277]
seed200_kronecker_all = [1.403028863621509, 0.8426201587586891, 0.6891285903810516, 0.9168559247114527, 0.7221406689126983]

seed300_gcn = [7.262803205354946, 4.778846320204847, 6.288647028404896, 5.132391862043246, 5.886767656748532]
seed300_egcn_r = [6.247930571788878, 3.0659807160144714, 4.07370631901298, 3.354097020907665, 5.639008325474863]
seed300_egcn_s = [6.082899799497109, 4.7498857393039495, 3.9319728941429317, 4.401309035894439, 4.209032182475083]
seed300_egcn = [4.946981595257136, 3.56008833036648, 3.912050622654712, 3.6727261280450296, 4.40438826757533]
seed300_concat_3 = [2.8547018456646778, 4.097650542972595, 2.96235248235267, 2.7442812581700604, 2.8021062130236443]
seed300_concat_5 = [1.9928038589597687, 1.8057752293864573, 1.5392985156201942, 1.3989609845979947, 1.743279777410376]
seed300_concat_7 = [1.7073869479922799, 1.576559682530681, 1.2714265688197819, 1.3662636223740465, 1.6726171378870958]
seed300_concat_10 = [1.69903005765179, 1.5574063278558685, 1.1445946580781712, 1.5610197472760057, 1.3468429587269557]
seed300_concat_20 = [1.6357212967759982, 1.4011482479065422, 0.8128246848038801, 1.4163574158676027, 1.3505056383273073]
seed300_concat_ds = [1.2273965670367863, 1.4232547489676888, 0.6795791415717658, 1.298910756749431, 1.0231815267155189]
seed300_kronecker_3 = [3.353387667438177, 3.8330092542753444, 2.8271771528589444, 2.761220916988343, 2.4090672649500022]
seed300_kronecker_5 = [1.7872635248139148, 1.520925717090997, 0.9108276667557363, 1.2227668161467304, 1.1285974633602696]
seed300_kronecker_7 = [1.3921594694843442, 1.8412979906938207, 1.0638215222696619, 1.2120742948036494, 0.9514430212496802]
seed300_kronecker_10 = [1.7464199366531974, 1.194164201030581, 0.78703006233756, 0.9821806779996617, 1.1216396520497234]
seed300_kronecker_20 = [1.2456791194405143, 1.380415248119925, 0.8934195961539201, 1.188329921932671, 1.030833011535743]
seed300_kronecker_all = [1.0710452597910964, 1.2566300489771085, 0.581254057996855, 1.0766666892945298, 1.0028371457152694]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)
all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MSE
# dataset: freesolv
# 15
# all_seed_GCN_MSE: 6.097
# all_seed_GCN_se: 0.329
#
# all_seed_EGCN_R_MSE: 4.545
# all_seed_EGCN_R_se: 0.321
#
# all_seed_EGCN_S_MSE: 4.772
# all_seed_EGCN_S_se: 0.197
#
# all_seed_EGCN_S_MSE: 4.309
# all_seed_EGCN_S_se: 0.258
#
# all_seed_Concat_3_MSE: 3.312
# all_seed_Concat_3_se: 0.115
#
# all_seed_Concat_5_MSE: 1.725
# all_seed_Concat_5_se: 0.136
#
# all_seed_Concat_7_MSE: 1.522
# all_seed_Concat_7_se: 0.067
#
# all_seed_Concat_10_MSE: 1.436
# all_seed_Concat_10_se: 0.063
#
# all_seed_Concat_20_MSE: 1.315
# all_seed_Concat_20_se: 0.081
#
# all_seed_Concat_ds_MSE: 1.120
# all_seed_Concat_ds_se: 0.067
#
# all_seed_kronecker_3_MSE: 3.140
# all_seed_kronecker_3_se: 0.131
#
# all_seed_kronecker_5_MSE: 1.417
# all_seed_kronecker_5_se: 0.095
#
# all_seed_kronecker_7_MSE: 1.291
# all_seed_kronecker_7_se: 0.083
#
# all_seed_kronecker_10_MSE: 1.139
# all_seed_kronecker_10_se: 0.066
#
# all_seed_kronecker_20_MSE: 1.161
# all_seed_kronecker_20_se: 0.074
#
# all_seed_kronecker_all_MSE: 1.042
# all_seed_kronecker_all_se: 0.073

# %%
# GAT / Freesolv / MAE 확인 완료
backbone = 'GAT'
dataset = 'freesolv'
metric = 'MAE'

seed100_gcn = [1.7611141955758642, 1.8987676965908742, 1.8782244704839752, 1.874737506776344, 1.8231979981633544]
seed100_egcn_r = [1.760584883802519, 1.5952616413747231, 1.7008963757612574, 1.6742006437046322, 1.4295701907791254]
seed100_egcn_s = [1.6415167680875522, 1.6404059102216104, 1.704530280406081, 1.7280380969911109, 1.4417249810604649]
seed100_egcn = [1.5815259978527159, 1.5251863134188914, 1.5661791103092704, 1.8573789221095287, 1.4974737968153626]
seed100_concat_3 = [1.5032671230045829, 1.78291281752699, 1.7908142870805395, 1.594051331046998, 1.5418061682286153]
seed100_concat_5 = [0.8122942166065606, 0.9187666975607084, 1.0872191932257704, 0.9218920159527636, 0.9463703213757231]
seed100_concat_7 = [0.9238422423835815, 0.9045378317044476, 1.045367834136242, 0.8300119385005921, 0.9641135494217618]
seed100_concat_10 = [0.7055095837810846, 0.8175698227769747, 1.0100417399969626, 0.8355783177173044, 0.8655516018394296]
seed100_concat_20 = [0.5560023991141733, 0.7237650803693636, 0.9389674419493187, 0.6802813912939838, 0.7205524089682194]
seed100_concat_ds = [0.5428615555049866, 0.7361175507072388, 0.7805361259640671, 0.5788663203322043, 0.5784342866817503]
seed100_kronecker_3 = [1.1506984590545415, 1.4558817946066067, 1.4195384528693251, 1.2764289735809087, 1.4501852925497156]
seed100_kronecker_5 = [0.6925212229330708, 0.9435519421194482, 0.9164422853725163, 0.8567146091010627, 0.8905161009490035]
seed100_kronecker_7 = [0.7618917029673659, 0.8264204610989788, 0.9028688716137503, 0.7838772901399867, 0.867206207213511]
seed100_kronecker_10 = [0.5980644526444082, 0.7327158469853439, 0.7566788440614235, 0.7014215874859667, 0.8115542644762811]
seed100_kronecker_20 = [0.5176634976244349, 0.6471199576310286, 0.7894471085916354, 0.610389078695943, 0.5854370462075444]
seed100_kronecker_all = [0.5619139633779451, 0.6745381092462014, 0.6518700817438561, 0.6008739321250615, 0.600898711508467]

seed200_gcn = [1.9663952804925873, 2.0132804329939713, 1.8721522233617587, 1.8665548910306196, 2.000762726514394]
seed200_egcn_r = [1.4095007228100394, 1.4749119976374108, 1.3568797524519793, 1.423834072323296, 1.4427421056587277]
seed300_kronecker_7 = [0.8465932710902897, 0.7977998388095164, 0.6828200723242572, 0.8009132325179934, 0.7483438089603686]
seed300_kronecker_10 = [0.7275502212404266, 0.7802730620376707, 0.5726565188310277, 0.6719457521213321, 0.7132458234106311]
seed300_kronecker_20 = [0.6704669561911756, 0.6722733655313807, 0.601887657886415, 0.6479190916526975, 0.635545898939817]
seed300_kronecker_all = [0.6528358159102793, 0.5604793894009328, 0.5553216258371909, 0.6305114866241696, 0.5571341414487999]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

n = len(seed100_gcn)
print(n)

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MAE
# dataset: freesolv
# 5
# all_seed_GCN_MAE: 1.867
# all_seed_GCN_se: 0.026
#
# all_seed_EGCN_R_MAE: 1.496
# all_seed_EGCN_R_se: 0.039
#
# all_seed_EGCN_S_MAE: 1.651
# all_seed_EGCN_S_se: 0.021
#
# all_seed_EGCN_S_MAE: 1.512
# all_seed_EGCN_S_se: 0.035
#
# all_seed_Concat_3_MAE: 1.591
# all_seed_Concat_3_se: 0.032
#
# all_seed_Concat_5_MAE: 0.932
# all_seed_Concat_5_se: 0.027
#
# all_seed_Concat_7_MAE: 0.934
# all_seed_Concat_7_se: 0.017
#
# all_seed_Concat_10_MAE: 0.885
# all_seed_Concat_10_se: 0.023
#
# all_seed_Concat_20_MAE: 0.747
# all_seed_Concat_20_se: 0.026
#
# all_seed_Concat_ds_MAE: 0.638
# all_seed_Concat_ds_se: 0.022
#
# all_seed_kronecker_3_MAE: 1.330
# all_seed_kronecker_3_se: 0.025
#
# all_seed_kronecker_5_MAE: 0.817
# all_seed_kronecker_5_se: 0.024
#
# all_seed_kronecker_7_MAE: 0.799
# all_seed_kronecker_7_se: 0.018
#
# all_seed_kronecker_10_MAE: 0.714
# all_seed_kronecker_10_se: 0.020
#
# all_seed_kronecker_20_MAE: 0.631
# all_seed_kronecker_20_se: 0.018
#
# all_seed_kronecker_all_MAE: 0.594
# all_seed_kronecker_all_se: 0.014

# %%
# GAT / ESOL / MSE / 확인 완료
backbone = 'GAT'
dataset = 'esol'
metric = 'MSE'

seed100_gcn = [4.010509200096131, 3.1166435156928167, 2.3051705339219835, 3.6552788786093395, 2.8766478231824966]
seed100_egcn_r = [2.375552126897706, 1.8134336725042925, 1.65563544538286, 2.082961741086393, 2.2506748590175274]
seed100_egcn_s = [0.7350514374838935, 0.6170273979070285, 0.8186795311012409, 1.0385424628853799, 0.9526494042988916]
seed100_egcn = [0.6608601482046975, 0.5871767711639404, 0.8656879926079677, 0.9285280593236287, 0.7256085484038366]
seed100_concat_3 = [0.6111174547672271, 0.6584147935443454, 0.5378213431686163, 0.6346083910597695, 0.6007345443517627]
seed100_concat_5 = [0.5722917913066017, 0.6429524580223693, 0.5045322547687424, 0.4980184586180581, 0.5004283712298859]
seed100_concat_7 = [0.5190422031614516, 0.5777627440624767, 0.46543749446670213, 0.5531274522675408, 0.5116954264661814]
seed100_concat_10 = [0.49482392801178826, 0.5645865268177457, 0.4989674042330848, 0.4390978198581272, 0.5172867234057792]
seed300_gcn = [3.318970269097222, 2.3683651563856336, 2.999586961534288, 2.7873473442925345, 2.596988425906009]
seed300_egcn_r = [1.6013622707790798, 1.9094929673936631, 1.9734329223632812, 1.6880923800998264, 1.8884670240763526]
seed300_egcn_s = [0.5725117577446832, 0.7073353322347006, 0.9191927422417535, 0.682327863905165, 1.0020650283880697]
seed300_egcn = [0.7632139460245768, 0.8770385233561198, 0.9113181644015842, 0.7684795803493923, 0.9756020029210835]
seed300_concat_3 = [0.6333197275797526, 0.5317599402533637, 0.6973570336235894, 0.7149420844184028, 0.7544411814685436]
seed300_concat_5 = [0.524212883843316, 0.4468566724989149, 0.5947644678751628, 0.573127695719401, 0.6425576693160944]
seed300_concat_7 = [0.4933899180094401, 0.41603909386528865, 0.6485000822279189, 0.526761711968316, 0.5535863590660599]
seed300_concat_10 = [0.5374354722764757, 0.5924967024061415, 0.5550745561387804, 0.524032457139757, 0.585591026339762]
seed300_concat_20 = [0.4510029517279731, 0.3993954383002387, 0.4164321263631185, 0.35770269605848526, 0.5020205712003329]
seed300_concat_ds = [0.40113382975260414, 0.38988431718614364, 0.4661066903008355, 0.36635225931803383, 0.48398866947526975]
seed300_kronecker_3 = [0.5943496534559461, 0.5434290228949653, 0.6442028130425347, 0.5523337682088216, 0.574323267663628]
seed300_kronecker_5 = [0.7473880174424913, 0.5689300876193576, 0.6521242819892036, 0.5341747919718425, 0.6707545545132675]
seed300_kronecker_7 = [0.5245581987169053, 0.4031868150499132, 0.5608619986640082, 0.4270548756917318, 0.5455015661432879]
seed300_kronecker_10 = [0.4546297751532661, 0.5448282114664713, 0.5015497673882379, 0.37926546308729386, 0.43972105706840886]
seed300_kronecker_20 = [0.4371934848361545, 0.34012131585015193, 0.3940392557779948, 0.3664473639594184, 0.5049980180379052]
seed300_kronecker_all = [0.3910101318359375, 0.3642429945203993, 0.39246231926812064, 0.36071468777126736, 0.43456465767343666]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MSE
# dataset: esol
# 15
# all_seed_GCN_MSE: 2.975
# all_seed_GCN_se: 0.128
#
# all_seed_EGCN_R_MSE: 1.915
# all_seed_EGCN_R_se: 0.078
#
# all_seed_EGCN_S_MSE: 0.792
# all_seed_EGCN_S_se: 0.036
#
# all_seed_EGCN_S_MSE: 0.793
# all_seed_EGCN_S_se: 0.031
#
# all_seed_Concat_3_MSE: 0.632
# all_seed_Concat_3_se: 0.020
#
# all_seed_Concat_5_MSE: 0.548
# all_seed_Concat_5_se: 0.016
#
# all_seed_Concat_7_MSE: 0.522
# all_seed_Concat_7_se: 0.014
#
# all_seed_Concat_10_MSE: 0.525
# all_seed_Concat_10_se: 0.012
#
# all_seed_Concat_20_MSE: 0.439
# all_seed_Concat_20_se: 0.010
#
# all_seed_Concat_ds_MSE: 0.460
# all_seed_Concat_ds_se: 0.016
#
# all_seed_kronecker_3_MSE: 0.617
# all_seed_kronecker_3_se: 0.022
#
# all_seed_kronecker_5_MSE: 0.591
# all_seed_kronecker_5_se: 0.020
#
# all_seed_kronecker_7_MSE: 0.487
# all_seed_kronecker_7_se: 0.016
#
# all_seed_kronecker_10_MSE: 0.479
# all_seed_kronecker_10_se: 0.014
#
# all_seed_kronecker_20_MSE: 0.445
# all_seed_kronecker_20_se: 0.017
#
# all_seed_kronecker_all_MSE: 0.403
# all_seed_kronecker_all_se: 0.015

# %%
# GAT / ESOL / MAE / 확인 완료
backbone = 'GAT'
dataset = 'esol'
metric = 'MAE'

seed100_gcn = [1.4881497266557482, 1.3671615939670139, 1.2672440497080486, 1.4355417887369792, 1.4568929126084114]
seed100_egcn_r = [1.1409479882982043, 0.9913625081380208, 0.9145362981160482, 1.1641382371054756, 1.1264819237629222]
seed100_egcn_s = [0.654888096915351, 0.6292525842454698, 0.6847648090786405, 0.7458215173085531, 0.6396236220120334]
seed100_egcn = [0.652837036980523, 0.5888636059231228, 0.6805456882052952, 0.7481356604894003, 0.6656305191275307]
seed100_concat_3 = [0.5809993216726514, 0.5863585657543606, 0.5419943523406983, 0.5972449064254761, 0.5759828447770442]
seed100_concat_5 = [0.5980978253152636, 0.5862002660168542, 0.48465779463450115, 0.5396157422330644, 0.5443828057350041]
seed100_concat_7 = [0.5603776706589593, 0.5382424465815226, 0.4885909080505371, 0.5428450028101603, 0.5206918747939727]
seed100_concat_10 = [0.5344316832224528, 0.5253570144706302, 0.517148093647427, 0.48690072298049925, 0.5171655889124597]
seed100_concat_20 = [0.48179148117701215, 0.5047896820969052, 0.4747576438056098, 0.5107172478569878, 0.5060990056277371]
seed100_concat_ds = [0.4766967549588945, 0.49180890685982176, 0.4575082439846463, 0.4697527241706848, 0.5008822978855755]
seed100_kronecker_3 = [0.6513181145985921, 0.6614085960388184, 0.5773886320326064, 0.6170279166433547, 0.5939529929392138]
seed100_kronecker_5 = [0.5855811757511563, 0.6348625527487861, 0.5422360208299425, 0.5725456648402744, 0.5613989157823739]
seed100_kronecker_7 = [0.5513462858729893, 0.511882996029324, 0.4733144855499268, 0.47950473335054183, 0.5158467090602489]
seed100_kronecker_10 = [0.5315425279405382, 0.5129687407281663, 0.5047894827524821, 0.4835549134678311, 0.529433012533818]
seed100_kronecker_20 = [0.5612509102291531, 0.47723094125588733, 0.4757902299033271, 0.5112944465213352, 0.48404972301180665]
seed100_kronecker_all = [0.4650336315896776, 0.4330293791823917, 0.46750406689114044, 0.4619723497496711, 0.4395814745436681]

seed200_gcn = [1.5193049006991917, 1.3585521708594428, 1.4371923870510526, 1.4846355639563666, 1.4481930470151523]
seed200_egcn_r = [1.0797388701968722, 1.081149312125312, 1.0979809453752305, 1.145495169957479, 1.0165037730716924]
seed200_egcn_s = [0.7247000948588054, 0.6932139280107287, 0.6789476511213515, 0.6782615608639188, 0.6541409508247208]
seed200_egcn = [0.7057425996992324, 0.6928840594821506, 0.6557481384277344, 0.6197885523902046, 0.672937425222691]
seed200_concat_3 = [0.5918533812628852, 0.5493030240800646, 0.5959883467356364, 0.6317177115546333, 0.5194822568200234]
seed200_concat_5 = [0.5238583850860595, 0.5523905171288385, 0.5746007166968452, 0.5523165369033813, 0.5093044341923382]


print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MAE
# dataset: esol
# 15
# all_seed_GCN_MAE: 1.401
# all_seed_GCN_se: 0.021
#
# all_seed_EGCN_R_MAE: 1.079
# all_seed_EGCN_R_se: 0.019
#
# all_seed_EGCN_S_MAE: 0.682
# all_seed_EGCN_S_se: 0.011
#
# all_seed_EGCN_S_MAE: 0.679
# all_seed_EGCN_S_se: 0.012
#
# all_seed_Concat_3_MAE: 0.582
# all_seed_Concat_3_se: 0.008
#
# all_seed_Concat_5_MAE: 0.546
# all_seed_Concat_5_se: 0.008
#
# all_seed_Concat_7_MAE: 0.525
# all_seed_Concat_7_se: 0.008
#
# all_seed_Concat_10_MAE: 0.538
# all_seed_Concat_10_se: 0.010
#
# all_seed_Concat_20_MAE: 0.487
# all_seed_Concat_20_se: 0.007
#
# all_seed_Concat_ds_MAE: 0.485
# all_seed_Concat_ds_se: 0.006
#
# all_seed_kronecker_3_MAE: 0.607
# all_seed_kronecker_3_se: 0.012
#
# all_seed_kronecker_5_MAE: 0.585
# all_seed_kronecker_5_se: 0.012
#
# all_seed_kronecker_7_MAE: 0.506
# all_seed_kronecker_7_se: 0.008
#
# all_seed_kronecker_10_MAE: 0.502
# all_seed_kronecker_10_se: 0.008
#
# all_seed_kronecker_20_MAE: 0.488
# all_seed_kronecker_20_se: 0.008
#
# all_seed_kronecker_all_MAE: 0.445
# all_seed_kronecker_all_se: 0.006

# %%
# GAT / scgas / MSE 확인 완료
backbone = 'GAT'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [6.150399525960286, 5.242617876101763, 5.400340447059045, 5.433693421192658, 5.508022710538139]
seed100_egcn_r = [4.615162482628455, 4.094345630743565, 4.049773436326247, 4.3207702147655, 4.478840739582293]
seed100_egcn_s = [1.5318184387989533, 1.3927880311623597, 1.3483553910866761, 1.4474147405379858, 1.3616760302656374]
seed100_egcn = [1.4700837257580879, 1.3075845669477413, 1.1215431262285283, 1.290159286596836, 1.3107098222921452]
seed100_concat_3 = [1.0643840936514049, 0.9756178733630058, 1.2436137199401855, 1.1537723418993828, 1.0131802543664512]
seed100_concat_5 = [0.8260191770700308, 0.7697109197958921, 0.9128370651831994, 0.9161865894611065, 0.8238964507374139]
seed100_concat_7 = [0.7705699113699106, 0.7818471468411959, 0.9158124190110427, 0.8167628263815855, 0.7372816286909695]
seed100_concat_10 = [0.6571551102858323, 0.5966492799612192, 0.8596205833630685, 0.6981388972355769, 0.5866569055916783]
seed100_concat_20 = [0.6094788588010348, 0.5302269886701535, 0.6829146483005621, 0.7580066705361391, 0.5575052572134584]
seed100_concat_ds = [0.5833599750812237, 0.5027688099787786, 0.7091014446356357, 0.6540579306773651, 0.5468462008637742]
seed100_kronecker_3 = [1.064779831812932, 0.9012842056078788, 1.1959038147559533, 1.0770180775569036, 1.1065651646818215]
seed300_concat_3 = [1.3114631603925655, 1.2801087208283253, 1.1659210278437688, 1.033940804310334, 1.1143568483785318]
seed300_concat_5 = [1.119862776536208, 1.141959508260091, 1.0436020141992814, 0.8302752665984325, 0.8513222593849841]
seed300_concat_7 = [0.9062543037610177, 0.8066403560149364, 0.8734045028686523, 0.735103631630922, 0.6732548235323482]
seed300_concat_10 = [0.7458514189108824, 0.8176730840634077, 0.7850909477625138, 0.6704298899723933, 0.6650713107075554]
seed300_concat_20 = [0.6701310475667318, 0.7334633362598908, 0.7224803093152169, 0.5407036267794095, 0.510679446089382]
seed300_concat_ds = [0.6277960630563589, 0.6520721178788406, 0.6868551694429837, 0.5229166348775228, 0.542376058170209]
seed300_kronecker_3 = [1.180438139499762, 1.0375025822566106, 1.116870647821671, 1.012888076977852, 0.9147952021882176]
seed300_kronecker_5 = [0.8552911281585693, 0.7868441557272886, 0.9466871114877554, 0.667836342102442, 0.6489976145588933]
seed300_kronecker_7 = [0.7089885992881579, 0.5990537985777243, 0.6897685588934482, 0.5793262872940454, 0.5668066469625163]
seed300_kronecker_10 = [0.5944371712513459, 0.5322412221859663, 0.5666880363073105, 0.4653654954372308, 0.6105047232045914]
seed300_kronecker_20 = [0.46738455845759463, 0.42947098536369127, 0.4944305358788906, 0.4551035440885104, 0.39841282024931984]
seed300_kronecker_all = [0.4847629437079796, 0.48082737433604705, 0.4876574247311323, 0.39267602944985414, 0.3809546205563286]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MSE
# dataset: scgas
# 15
# all_seed_GCN_MSE: 5.658
# all_seed_GCN_se: 0.117
#
# all_seed_EGCN_R_MSE: 4.189
# all_seed_EGCN_R_se: 0.082
#
# all_seed_EGCN_S_MSE: 1.507
# all_seed_EGCN_S_se: 0.033
#
# all_seed_EGCN_S_MSE: 1.391
# all_seed_EGCN_S_se: 0.028
#
# all_seed_Concat_3_MSE: 1.134
# all_seed_Concat_3_se: 0.025
#
# all_seed_Concat_5_MSE: 0.909
# all_seed_Concat_5_se: 0.028
#
# all_seed_Concat_7_MSE: 0.795
# all_seed_Concat_7_se: 0.018
#
# all_seed_Concat_10_MSE: 0.706
# all_seed_Concat_10_se: 0.019
#
# all_seed_Concat_20_MSE: 0.634
# all_seed_Concat_20_se: 0.020
#
# all_seed_Concat_ds_MSE: 0.593
# all_seed_Concat_ds_se: 0.016
#
# all_seed_kronecker_3_MSE: 1.074
# all_seed_kronecker_3_se: 0.024
#
# all_seed_kronecker_5_MSE: 0.774
# all_seed_kronecker_5_se: 0.022
#
# all_seed_kronecker_7_MSE: 0.611
# all_seed_kronecker_7_se: 0.013
#
# all_seed_kronecker_10_MSE: 0.544
# all_seed_kronecker_10_se: 0.011
#
# all_seed_kronecker_20_MSE: 0.447
# all_seed_kronecker_20_se: 0.011
#
# all_seed_kronecker_all_MSE: 0.449
# all_seed_kronecker_all_se: 0.011

# %%
# GAT / scgas / MAE 확인 완료
backbone = 'GAT'
dataset = 'scgas'
metric = 'MAE'



print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MAE
# dataset: scgas
# 15
# all_seed_GCN_MAE: 1.781
# all_seed_GCN_se: 0.017
#
# all_seed_EGCN_R_MAE: 1.498
# all_seed_EGCN_R_se: 0.011
#
# all_seed_EGCN_S_MAE: 0.928
# all_seed_EGCN_S_se: 0.026
#
# all_seed_EGCN_S_MAE: 0.873
# all_seed_EGCN_S_se: 0.005
#
# all_seed_Concat_3_MAE: 0.788
# all_seed_Concat_3_se: 0.007
#
# all_seed_Concat_5_MAE: 0.686
# all_seed_Concat_5_se: 0.006
#
# all_seed_Concat_7_MAE: 0.650
# all_seed_Concat_7_se: 0.007
#
# all_seed_Concat_10_MAE: 0.618
# all_seed_Concat_10_se: 0.007
#
# all_seed_Concat_20_MAE: 0.561
# all_seed_Concat_20_se: 0.005
#
# all_seed_Concat_ds_MAE: 0.551
# all_seed_Concat_ds_se: 0.006
#
# all_seed_kronecker_3_MAE: 0.785
# all_seed_kronecker_3_se: 0.010
#
# all_seed_kronecker_5_MAE: 0.654
# all_seed_kronecker_5_se: 0.007
#
# all_seed_kronecker_7_MAE: 0.585
# all_seed_kronecker_7_se: 0.008
#
# all_seed_kronecker_10_MAE: 0.536
# all_seed_kronecker_10_se: 0.005
#
# all_seed_kronecker_20_MAE: 0.485
# all_seed_kronecker_20_se: 0.006
#
# all_seed_kronecker_all_MAE: 0.498
# all_seed_kronecker_all_se: 0.006

# %%
# GAT / solubility / MSE 확인 완료
backbone = 'GAT'
dataset = 'solubility'
metric = 'MSE'

seed100_gcn = [2.950183640438247, 2.876849083854315, 2.831827509993508, 2.6925079397810543, 2.8219556900745233]
seed100_egcn_r = [2.2942096360651147, 2.060461887800361, 2.387421713814385, 2.2418411419889637, 2.149732525672978]
seed100_egcn_s = [1.1700727780840923, 1.0752903477468474, 1.1892653559172908, 1.1102803837662742, 1.3116539752680128]
seed100_egcn = [1.1704822381789806, 1.138716739487363, 1.178696764282157, 1.0608138299897507, 1.3314801272032406]
seed100_concat_3 = [1.1798128357107285, 1.0682684128163684, 1.0684603331234215, 1.031580308926126, 1.0834181671055731]
seed100_concat_5 = [1.1360063286891497, 1.0360946264467799, 1.0804814364195006, 1.0161112751143861, 0.918234410988857]
seed100_concat_7 = [1.085341217440506, 0.9701887205641719, 0.9903749955535003, 1.0513009259696704, 0.9512520683171333]
seed100_concat_10 = [0.988723416184592, 0.913278969431982, 0.8821864293662404, 0.9618938013987577, 0.8890887256637513]
seed100_concat_20 = [0.7476131762709208, 0.6943108130396939, 0.6732480478476718, 0.7038497577421897, 0.6452259200502677]
seed100_concat_ds = [0.915337742223072, 0.6948348226096729, 0.7231715836847921, 0.71604981962496, 0.727936755002868]
seed100_kronecker_3 = [1.1256621463365288, 1.0486406511926625, 0.9407103033179781, 0.9713980555873604, 1.118506217179274]
seed100_kronecker_5 = [0.9701936620843634, 0.8021769385210274, 0.8171810265217033, 0.8163787112293015, 0.8026107154112345]
seed100_kronecker_7 = [0.7983503260256963, 0.6645322961432729, 0.7093582457280254, 0.7802193065767066, 0.7166304699588921]
seed100_kronecker_10 = [0.6937777628325982, 0.6113765197649691, 0.6602408985014184, 0.6061464330318236, 0.7644710725318592]
seed100_kronecker_20 = [0.434018390722823, 0.44678510775536245, 0.41794018645007025, 0.4564778149365429, 0.4523011426323167]
seed300_concat_20 = [0.7392754942840246, 0.7394464066168362, 0.786430953779747, 0.7884681193612826, 0.8143902313458221]
seed300_concat_ds = [0.6393802493013437, 0.709083135927273, 0.7491869940022277, 0.7620946529173485, 0.7981846331193084]
seed300_kronecker_3 = [0.9020850192978087, 1.0443243244933214, 1.0354276949123151, 1.121734375972672, 1.0013947245337844]
seed300_kronecker_5 = [0.9667058780780894, 1.036795844662644, 1.120804744887637, 1.0244877597589552, 1.1610977442073225]
seed300_kronecker_7 = [0.6544477780840922, 0.6875341043054345, 0.6685119828651355, 0.7270742556420523, 0.7574644398132915]
seed300_kronecker_10 = [0.6025254972020401, 0.6844373777907344, 0.7323797808903894, 0.7405510317824684, 0.7101931455261543]
seed300_kronecker_20 = [0.40624329551214783, 0.4179554105008537, 0.3686901520244357, 0.4439887370856974, 0.43806135104879035]
seed300_kronecker_all = [0.407806717813456, 0.45501489698988645, 0.37902133791841564, 0.42647678850724335, 0.44322007015881787]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MSE
# dataset: solubility
# 15
# all_seed_GCN_MSE: 2.918
# all_seed_GCN_se: 0.049
#
# all_seed_EGCN_R_MSE: 2.236
# all_seed_EGCN_R_se: 0.036
#
# all_seed_EGCN_S_MSE: 1.300
# all_seed_EGCN_S_se: 0.043
#
# all_seed_EGCN_S_MSE: 1.300
# all_seed_EGCN_S_se: 0.037
#
# all_seed_Concat_3_MSE: 1.106
# all_seed_Concat_3_se: 0.022
#
# all_seed_Concat_5_MSE: 1.050
# all_seed_Concat_5_se: 0.023
#
# all_seed_Concat_7_MSE: 1.041
# all_seed_Concat_7_se: 0.026
#
# all_seed_Concat_10_MSE: 0.958
# all_seed_Concat_10_se: 0.022
#
# all_seed_Concat_20_MSE: 0.744
# all_seed_Concat_20_se: 0.022
#
# all_seed_Concat_ds_MSE: 0.781
# all_seed_Concat_ds_se: 0.030
#
# all_seed_kronecker_3_MSE: 1.054
# all_seed_kronecker_3_se: 0.026
#
# all_seed_kronecker_5_MSE: 0.950
# all_seed_kronecker_5_se: 0.036
#
# all_seed_kronecker_7_MSE: 0.750
# all_seed_kronecker_7_se: 0.027
#
# all_seed_kronecker_10_MSE: 0.692
# all_seed_kronecker_10_se: 0.022
#
# all_seed_kronecker_20_MSE: 0.444
# all_seed_kronecker_20_se: 0.016
#
# all_seed_kronecker_all_MSE: 0.444
# all_seed_kronecker_all_se: 0.012

# %%
# GAT / solubility / MAE 확인 완료
backbone = 'GAT'
dataset = 'solubility'
metric = 'MAE'

seed100_gcn = [1.3223064772161355, 1.3407836983539059, 1.332321036723641, 1.3691665571252936, 1.367736173748088]
seed100_egcn_r = [1.125401435552433, 1.1197384360437714, 1.1633904879922274, 1.0884238141602118, 1.089014321480818]
seed100_egcn_s = [0.8441954576365298, 0.7789973181353825, 0.8236024929300655, 0.7898913119147295, 0.9319427698664049]
seed100_egcn = [0.820433962392617, 0.7568079818699532, 0.81377852499044, 0.7557610569857846, 0.8253583652971818]
seed200_kronecker_10 = [0.6129670943736216, 0.5875817843303127, 0.5518846766950057, 0.5553837115613995, 0.5863918072131118]
seed200_kronecker_20 = [0.46985611891163026, 0.4160472238070597, 0.4243697034545968, 0.4167909790455922, 0.44421863501629644]
seed200_kronecker_all = [0.4623606578151679, 0.4420684701553718, 0.4370279762645845, 0.4339232165228595, 0.4386007431629509]

seed300_gcn = [1.3018203587713877, 1.3293997906254447, 1.311945472851896, 1.3451815992169713, 1.301543442580126]
seed300_egcn_r = [1.0741519396048618, 1.1404153544860736, 1.0894884121438353, 1.152917053187918, 1.065475411759769]
seed300_egcn_s = [0.9170001773041762, 0.9246982754667713, 0.9055583695491471, 0.8309452358673565, 0.9124052843453196]
seed300_egcn = [0.8255860139242138, 0.8208334352322851, 0.8818420861753877, 0.8755600157961902, 0.81954830996883]
seed300_concat_3 = [0.7078752946500827, 0.7689810477676349, 0.7865535799047115, 0.8240724323687393, 0.7756154337727216]
seed300_concat_5 = [0.7183366057950119, 0.8084398854776208, 0.7983075458350749, 0.8187297024235647, 0.7635145279651483]
seed300_concat_7 = [0.6978567228713495, 0.7393536554118348, 0.7331585523141808, 0.7691760858352306, 0.7232172645217123]
seed300_concat_10 = [0.6809416995105515, 0.6801836407856298, 0.7330052696579752, 0.7214136009672248, 0.7440364883240476]
seed300_concat_20 = [0.6192376663824612, 0.6275610448829682, 0.6011923115295514, 0.6168118923580233, 0.6272110393526341]
seed300_concat_ds = [0.571945529127908, 0.5823780943469425, 0.5923733002907455, 0.5733271139076507, 0.5769158386682066]
seed300_kronecker_3 = [0.6749359721410119, 0.7105878244833167, 0.7278700314534273, 0.7449461535832118, 0.7189488940165677]
seed300_kronecker_5 = [0.6755025274182289, 0.7044603394457882, 0.7595571432184209, 0.7277958912814145, 0.6746716312067578]
seed300_kronecker_7 = [0.5823817158125312, 0.6132550833913231, 0.6086057468646618, 0.6383670987089588, 0.6044692298398482]
seed300_kronecker_10 = [0.5745354111247533, 0.5618972083554732, 0.5894627492402044, 0.5877023348431053, 0.5909124080199848]
seed300_kronecker_20 = [0.4207155317763544, 0.4310816383253259, 0.41423125855951193, 0.4416354531650185, 0.44794547917426275]
seed300_kronecker_all = [0.42350094251898657, 0.43452627304676383, 0.43123231126831957, 0.43792613881110604, 0.4419561048495749]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")

# EGCN_R
all_seed_egcn_r = seed100_egcn_r + seed200_egcn_r + seed300_egcn_r
all_seed_egcn_r_avg = np.mean(all_seed_egcn_r)
std_dev = np.std(all_seed_egcn_r, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_R_{metric}:', f'{all_seed_egcn_r_avg:.3f}')
print(f"all_seed_EGCN_R_se: {standard_error:.3f}\n")

# EGCN_S
all_seed_egcn_s = seed100_egcn_s + seed200_egcn_s + seed300_egcn_s
all_seed_egcn_s_avg = np.mean(all_seed_egcn_s)
std_dev = np.std(all_seed_egcn_s, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_s_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# EGCN
all_seed_egcn = seed100_egcn + seed200_egcn + seed300_egcn
all_seed_egcn_avg = np.mean(all_seed_egcn)
std_dev = np.std(all_seed_egcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_EGCN_S_{metric}:', f'{all_seed_egcn_avg:.3f}')
print(f"all_seed_EGCN_S_se: {standard_error:.3f}\n")

# Concat_3
all_seed_concat_3 = seed100_concat_3 + seed200_concat_3 + seed300_concat_3
all_seed_concat_3_avg = np.mean(all_seed_concat_3)
std_dev = np.std(all_seed_concat_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_3_{metric}:', f'{all_seed_concat_3_avg:.3f}')
print(f"all_seed_Concat_3_se: {standard_error:.3f}\n")

# Concat_5
all_seed_concat_5 = seed100_concat_5 + seed200_concat_5 + seed300_concat_5
all_seed_concat_5_avg = np.mean(all_seed_concat_5)
std_dev = np.std(all_seed_concat_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_5_{metric}:', f'{all_seed_concat_5_avg:.3f}')
print(f"all_seed_Concat_5_se: {standard_error:.3f}\n")

# Concat_7
all_seed_concat_7 = seed100_concat_7 + seed200_concat_7 + seed300_concat_7
all_seed_concat_7_avg = np.mean(all_seed_concat_7)
std_dev = np.std(all_seed_concat_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_7_{metric}:', f'{all_seed_concat_7_avg:.3f}')
print(f"all_seed_Concat_7_se: {standard_error:.3f}\n")

# Concat_10
all_seed_concat_10 = seed100_concat_10 + seed200_concat_10 + seed300_concat_10
all_seed_concat_10_avg = np.mean(all_seed_concat_10)
std_dev = np.std(all_seed_concat_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_10_{metric}:', f'{all_seed_concat_10_avg:.3f}')
print(f"all_seed_Concat_10_se: {standard_error:.3f}\n")

# Concat_20
all_seed_concat_20 = seed100_concat_20 + seed200_concat_20 + seed300_concat_20
all_seed_concat_20_avg = np.mean(all_seed_concat_20)
std_dev = np.std(all_seed_concat_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_20_{metric}:', f'{all_seed_concat_20_avg:.3f}')
print(f"all_seed_Concat_20_se: {standard_error:.3f}\n")

# Concat_DS
all_seed_concat_ds = seed100_concat_ds + seed200_concat_ds + seed300_concat_ds
all_seed_concat_ds_avg = np.mean(all_seed_concat_ds)
std_dev = np.std(all_seed_concat_ds, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_Concat_ds_{metric}:', f'{all_seed_concat_ds_avg:.3f}')
print(f"all_seed_Concat_ds_se: {standard_error:.3f}\n")

# kronecker_3
all_seed_kronecker_3 = seed100_kronecker_3 + seed200_kronecker_3 + seed300_kronecker_3
all_seed_kronecker_3_avg = np.mean(all_seed_kronecker_3)
std_dev = np.std(all_seed_kronecker_3, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_3_{metric}:', f'{all_seed_kronecker_3_avg:.3f}')
print(f"all_seed_kronecker_3_se: {standard_error:.3f}\n")

# kronecker_5
all_seed_kronecker_5 = seed100_kronecker_5 + seed200_kronecker_5 + seed300_kronecker_5
all_seed_kronecker_5_avg = np.mean(all_seed_kronecker_5)
std_dev = np.std(all_seed_kronecker_5, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_5_{metric}:', f'{all_seed_kronecker_5_avg:.3f}')
print(f"all_seed_kronecker_5_se: {standard_error:.3f}\n")

# kronecker_7
all_seed_kronecker_7 = seed100_kronecker_7 + seed200_kronecker_7 + seed300_kronecker_7
all_seed_kronecker_7_avg = np.mean(all_seed_kronecker_7)
std_dev = np.std(all_seed_kronecker_7, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_7_{metric}:', f'{all_seed_kronecker_7_avg:.3f}')
print(f"all_seed_kronecker_7_se: {standard_error:.3f}\n")

# kronecker_10
all_seed_kronecker_10 = seed100_kronecker_10 + seed200_kronecker_10 + seed300_kronecker_10
all_seed_kronecker_10_avg = np.mean(all_seed_kronecker_10)
std_dev = np.std(all_seed_kronecker_10, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_10_{metric}:', f'{all_seed_kronecker_10_avg:.3f}')
print(f"all_seed_kronecker_10_se: {standard_error:.3f}\n")

# kronecker_20
all_seed_kronecker_20 = seed100_kronecker_20 + seed200_kronecker_20 + seed300_kronecker_20
all_seed_kronecker_20_avg = np.mean(all_seed_kronecker_20)
std_dev = np.std(all_seed_kronecker_20, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_20_{metric}:', f'{all_seed_kronecker_20_avg:.3f}')
print(f"all_seed_kronecker_20_se: {standard_error:.3f}\n")

# kronecker_all
all_seed_kronecker_all = seed100_kronecker_all + seed200_kronecker_all + seed300_kronecker_all
all_seed_kronecker_all_avg = np.mean(all_seed_kronecker_all)
std_dev = np.std(all_seed_kronecker_all, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_kronecker_all_{metric}:', f'{all_seed_kronecker_all_avg:.3f}')
print(f"all_seed_kronecker_all_se: {standard_error:.3f}\n")
# Out:
# backbone: GAT
# metric: MAE
# dataset: solubility
# 15
# all_seed_GCN_MAE: 1.347
# all_seed_GCN_se: 0.009
#
# all_seed_EGCN_R_MAE: 1.120
# all_seed_EGCN_R_se: 0.008
#
# all_seed_EGCN_S_MAE: 0.849
# all_seed_EGCN_S_se: 0.014
#
# all_seed_EGCN_S_MAE: 0.832
# all_seed_EGCN_S_se: 0.013
#
# all_seed_Concat_3_MAE: 0.762
# all_seed_Concat_3_se: 0.011
#
# all_seed_Concat_5_MAE: 0.756
# all_seed_Concat_5_se: 0.011
#
# all_seed_Concat_7_MAE: 0.726
# all_seed_Concat_7_se: 0.007
#
# all_seed_Concat_10_MAE: 0.699
# all_seed_Concat_10_se: 0.007
#
# all_seed_Concat_20_MAE: 0.601
# all_seed_Concat_20_se: 0.007
#
# all_seed_Concat_ds_MAE: 0.598
# all_seed_Concat_ds_se: 0.007
#
# all_seed_kronecker_3_MAE: 0.726
# all_seed_kronecker_3_se: 0.007
#
# all_seed_kronecker_5_MAE: 0.693
# all_seed_kronecker_5_se: 0.008
#
# all_seed_kronecker_7_MAE: 0.610
# all_seed_kronecker_7_se: 0.006
#
# all_seed_kronecker_10_MAE: 0.577
# all_seed_kronecker_10_se: 0.005
#
# all_seed_kronecker_20_MAE: 0.435
# all_seed_kronecker_20_se: 0.004
#
# all_seed_kronecker_all_MAE: 0.438
# all_seed_kronecker_all_se: 0.002
