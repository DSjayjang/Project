# %%
import math
import numpy as np
import pandas as pd

# %% [markdown]
# # Freesolv

# %%
# Bilinear / Freesolv / MSE 확인 완료
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [1.3743253617774782, 0.7101169646255613, 0.9820521497350978, 0.6648769078292246, 0.9860572292974205]
seed200_gcn = [1.6882214433564915, 0.8233152149230476, 1.2841597429410678, 0.913155585762084, 0.7374123871781444]
seed300_gcn = [0.8152606693778451, 1.5549720553901252, 0.7487402112465206, 1.0405487300842766, 1.0499248571750772]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# 15
# all_seed_GCN_MSE: 1.025
# all_seed_GCN_se: 0.082

# %%
# Bilinear / Freesolv / MAE 확인 완료
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

seed100_gcn = [0.518971615888941, 0.5311851126002515, 0.6686943684975932, 0.6020943949541707, 0.5998866048477988]
seed200_gcn = [0.6503521326020008, 0.4764104828121155, 0.5964107663612667, 0.5599572940135565, 0.5431945269344417]
seed300_gcn = [0.65371161933959, 0.6473466017114835, 0.5918807833213505, 0.5503136642335906, 0.6210098466800369]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Freesolv
# 15
# all_seed_GCN_MAE: 0.587
# all_seed_GCN_se: 0.015

# %%
# Bilinear / Freesolv / MSE / scaffold 확인 완료
split = 'scaffold'
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MSE'

seed100_gcn = [0.8586444389529344, 6.1598358154296875, 2.430981473046906, 3.0389622632194966, 2.1181451706659224]
seed200_gcn = [2.827196155894886, 2.030714283818784, 3.0393382325464366, 4.7667388916015625, 1.5766122717606394]
seed300_gcn = [4.727922008883569, 1.1184003353118896, 3.2086013267780173, 7.001527052659255, 3.7839112701103974]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: Freesolv
# 15
# all_seed_GCN_MSE: 3.246
# all_seed_GCN_se: 0.458

# %%
# Bilinear / Freesolv / MAE / scaffold 확인 완료
split = 'scaffold'
backbone = 'GCN'
dataset = 'Freesolv'
metric = 'MAE'

seed100_gcn = [1.0325111761325743, 1.5528261184692382, 1.180582348181277, 1.1808731527889476, 0.6449402854556129]
seed200_gcn = [1.1434409401633523, 0.8799639162809952, 1.0887227272500797, 1.8104963631465518, 0.9571850425318668]
seed300_gcn = [1.604704333889869, 0.6520708203315735, 1.1284467762914197, 2.2608363811786356, 1.2757999443569066]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: Freesolv
# 15
# all_seed_GCN_MAE: 1.226
# all_seed_GCN_se: 0.111

# %% [markdown]
# # ESOL

# %%
# Bilinear / ESOL / MSE 확인
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [0.4733346260918511, 0.3568834813435872, 0.4373865509033203, 0.39078880733913846, 0.3354481768503063]
seed200_gcn = [0.41565630594889325, 0.3664889865451389, 0.35853346082899307, 0.41444158766004774, 0.417586003106071]
seed300_gcn = [0.3453022978040907, 0.3437831836276584, 0.38725193871392144, 0.3880326716105143, 0.43220940980617173]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# 15
# all_seed_GCN_MSE: 0.391
# all_seed_GCN_se: 0.010

# %%
# 확인
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [0.4786090766059028, 0.46114918178982206, 0.44390496995713974, 0.43324195014105904, 0.43390412267609313]
seed200_gcn = [0.4458315022786458, 0.4289829550849067, 0.46222879197862415, 0.48438265482584636, 0.4477249473202071]
seed300_gcn = [0.43821609497070313, 0.4385963736640082, 0.4262471940782335, 0.45489964803059896, 0.4698783563622294]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# 15
# all_seed_GCN_MAE: 0.450
# all_seed_GCN_se: 0.005

# %%
# ESOL / MSE / Scaffold 확인 완료
# scaffold
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MSE'

seed100_gcn = [1.0058397094815925, 1.0759353637695312, 0.5595072312788529, 0.8423055551819882, 0.539422446606206]
seed200_gcn = [0.6136931251077091, 0.7701613573651565, 0.6915524058871799, 0.7413819714596397, 0.631403510731862]
seed300_gcn = [1.0061405972317532, 1.080255925655365, 0.42376755279244727, 0.6620627277705515, 0.6872461978520188]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

# GAT
all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: ESOL
# 15
# all_seed_GCN_MSE: 0.755
# all_seed_GCN_se: 0.053

# %%
# ESOL / MAE / Scaffold 확인 완료
backbone = 'GCN'
dataset = 'ESOL'
metric = 'MAE'

seed100_gcn = [0.8058947790768625, 0.6797816125970138, 0.5674508181485263, 0.7366914587505793, 0.5579601362639782]
seed200_gcn = [0.5543101067636528, 0.6658476538825453, 0.6516821013556586, 0.7140321982534308, 0.57065136629836]
seed300_gcn = [0.8060622344145904, 0.7303847372531891, 0.5137617611190648, 0.5935117310168696, 0.6161951528531369]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: ESOL
# 15
# all_seed_GCN_MAE: 0.651
# all_seed_GCN_se: 0.024

# %% [markdown]
# # Vapor pressure

# %%
# scgas / MSE 확인 완료
backbone = 'GCN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [0.44150238159375316, 0.42690362685765976, 0.6116655056293194, 0.6052765479454627, 0.39233498375255843]
seed200_gcn = [0.4489454000424116, 0.5981141726175944, 0.4889890964214618, 0.5194019659971579, 0.3996374721344287]
seed300_gcn = [0.5556226693666898, 0.4728424060039031, 0.5678607317117544, 0.39418530464172363, 0.3740974523769781]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: scgas
# 15
# all_seed_GCN_MSE: 0.486
# all_seed_GCN_se: 0.022

# %%
# scgas / MAE 확인 완료
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [0.48182260073148286, 0.46562976103562576, 0.5159320403368045, 0.5209827178563827, 0.4477695550400609]
seed200_gcn = [0.47118554359827286, 0.5373211762843988, 0.4797084637177296, 0.5057375369927822, 0.45816654290634984]
seed300_gcn = [0.49697075745998287, 0.47055292740846294, 0.503635571553157, 0.4423535053546612, 0.46641271792280786]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: scgas
# 15
# all_seed_GCN_MAE: 0.484
# all_seed_GCN_se: 0.007

# %%
# scgas / MSE / scaffold 확인 완료
split = 'scaffold'
backbone = 'GCN'
dataset = 'scgas'
metric = 'MSE'

seed100_gcn = [0.7218272357905676, 0.6724356285453617, 0.9221571140050617, 1.1037795554081946, 0.679466403260523]
seed200_gcn = [0.7210237403396847, 0.8345957173929586, 0.8402515677518623, 1.0054789851532158, 1.1044425802027926]
seed300_gcn = [0.8401794344151845, 0.8512146985571539, 0.7385288212923395, 1.2896167160174168, 0.8536138197954963]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: scgas
# 15
# all_seed_GCN_MSE: 0.879
# all_seed_GCN_se: 0.046

# %%
# scgas / MAE / scaffold 확인 완료
split = 'scaffold'
backbone = 'GCN'
dataset = 'scgas'
metric = 'MAE'

seed100_gcn = [0.6495771495574111, 0.6449899373116431, 0.6891073545905103, 0.8010806954063182, 0.5383558208439626]
seed200_gcn = [0.6156449439603822, 0.7311441000405844, 0.5927326291106468, 0.7216239376090064, 0.7662530127992021]
seed300_gcn = [0.6887689212562051, 0.6831172383279117, 0.6612604128434354, 0.8404167945231866, 0.6078532499425552]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: scgas
# 15
# all_seed_GCN_MAE: 0.682
# all_seed_GCN_se: 0.021

# %% [markdown]
# # Solubility

# %%
# 확인완료 성능너무좋은ㅁ
backbone = 'GCN'
dataset = 'solubility'
metric = 'MSE'

seed100_gcn = [0.42060794732620854, 0.41864341514383313, 0.361183817846638, 0.4360448048069997, 0.3658117165128548]
seed200_gcn = [0.5367599687049792, 0.3736515034310303, 0.4976176054014967, 0.39348919715946484, 0.3902912085614017]
seed300_gcn = [0.3489046091373902, 0.4323616223234851, 0.3413887783825635, 0.4385521139145983, 0.37963740392781553]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: solubility
# 15
# all_seed_GCN_MSE: 0.409
# all_seed_GCN_se: 0.014

# %%
# # (재) 쓰지마 걍
# backbone = 'GCN'
# dataset = 'solubility'
# metric = 'MSE'

# seed100_gcn = [0.44433196865162117, 0.4240878457431435, 0.3923906946155112, 0.4211459737917749, 0.39044354459950376]
# seed200_gcn = [0.494721210199659, 0.3478979024957647, 0.501052126941453, 0.3500527613666428, 0.39694434889487806]
# seed300_gcn = [0.40139440928390235, 0.4033835144564043, 0.35242690562387724, 0.4045934747686153, 0.3761587083237919]

# print(f'backbone: {backbone}')
# print(f'metric: {metric}')
# print(f'dataset: {dataset}')

# all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
# n = len(all_seed_gcn)
# print(n)

# all_seed_gcn_avg = np.mean(all_seed_gcn)
# std_dev = np.std(all_seed_gcn, ddof = 1)
# standard_error = std_dev / math.sqrt(n)
# print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
# print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: solubility
# 15
# all_seed_GCN_MSE: 0.407
# all_seed_GCN_se: 0.012

# %%
# 확완 성능좋음;
backbone = 'GCN'
dataset = 'solubility'
metric = 'MAE'

seed100_gcn = [0.41159867019088825, 0.4030154623901159, 0.3998784611831691, 0.41906110386856593, 0.4044545867867814]
seed200_gcn = [0.41722861622705604, 0.41197941041359115, 0.41744203952882664, 0.4151571292258422, 0.4138078163073154]
seed300_gcn = [0.4005481674376712, 0.40317198873312554, 0.4065138980211965, 0.4338059965425686, 0.40182105180005423]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: solubility
# 15
# all_seed_GCN_MAE: 0.411
# all_seed_GCN_se: 0.002

# %%
split = 'scaffold'
backbone = 'GCN'
dataset = 'solubility'
metric = 'MSE'

seed100_gcn = [0.5277301959705829, 0.6357483803654247, 0.5268483872109271, 0.46860056794253646, 0.5866695871416306]
seed200_gcn = [0.6996566174721031, 0.6891077903617318, 0.5941607613329235, 0.4629822419068524, 0.6377869013641044]
seed300_gcn = [0.6293192073998862, 0.646030758614661, 0.6284459165034403, 0.605654437956017, 0.5575235484975629]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MSE
# dataset: solubility
# 15
# all_seed_GCN_MSE: 0.593
# all_seed_GCN_se: 0.019

# %%
split = 'scaffold'
backbone = 'GCN'
dataset = 'solubility'
metric = 'MAE'

seed100_gcn = [0.5152832894476004, 0.5290984221626447, 0.5015052125809041, 0.5094372169150508, 0.5069790518047005]
seed200_gcn = [0.5185135321220959, 0.6018356021630903, 0.5674255340697756, 0.467566420653156, 0.5122587208495708]
seed300_gcn = [0.5285927475682947, 0.5276132949263032, 0.5188092857826757, 0.5370547454616591, 0.5224883020451638]

print(f'backbone: {backbone}')
print(f'metric: {metric}')
print(f'dataset: {dataset}')

all_seed_gcn = seed100_gcn + seed200_gcn + seed300_gcn
n = len(all_seed_gcn)
print(n)

all_seed_gcn_avg = np.mean(all_seed_gcn)
std_dev = np.std(all_seed_gcn, ddof = 1)
standard_error = std_dev / math.sqrt(n)
print(f'all_seed_GCN_{metric}:', f'{all_seed_gcn_avg:.3f}')
print(f"all_seed_GCN_se: {standard_error:.3f}\n")
# Out:
# backbone: GCN
# metric: MAE
# dataset: solubility
# 15
# all_seed_GCN_MAE: 0.524
# all_seed_GCN_se: 0.008
